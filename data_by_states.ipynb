# %%
import pandas as pd

# %%
df = pd.read_feather('agent_comments.fea')
df_sale = df[(df['rentsale'] == 'S') & (df['state'] == 'GA')]
df_sale.reset_index().to_feather('agent_comments_sales_GA.fea')

# %%
df_sale
# Out:
#          listingid    asgpropid     qtr  tax_year cbsa_div   cbsa state  \
# 128      226661582   27649366.0  202008    2020.0    23580  23580    GA
# 190      226786904   27628370.0  202008    2020.0    29300  29300    GA
# 232      226142320   27963359.0  202005    2020.0    27600  27600    GA
# 308      226738459   27516267.0  202008    2020.0    29300  29300    GA
# 467      226850183   27791872.0  202008    2020.0    23580  23580    GA
# ...            ...          ...     ...       ...      ...    ...   ...
# 6908610   77898274  106321613.0  200708    2013.0    27600  27600    GA
# 6912211   77863520  131534737.0  200705    2013.0    23580  23580    GA
# 6912289   77900119  131589092.0  200708    2013.0    23580  23580    GA
# 6912290   77861631  131589103.0  200702    2013.0    23580  23580    GA
# 6912291   77883696  131589105.0  200705    2013.0    23580  23580    GA
#
#          Transdate  Transprice  bedrooms  ...  fips_code  census_tract    zip  \
# ...

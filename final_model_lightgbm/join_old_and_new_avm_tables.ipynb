# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
state = 'GA'

# %%
file_symptoms = 'agent_comments_'+state+\
                        '_for_Thu_01_new.fea'
df_Thu_new = pd.read_feather(file_symptoms)

# %%
df_Thu_new.columns
# Out:
# Index(['index', 'listingid', 'qtr', 'state', 'cbsa', 'cj_living_area',
#        'census_tract', 'Transdate', 'Transprice', 'ListingPrice',
#        'new_avmValue', 'new_avmerror', 'Train/Test', 'new_avmValue-cbsa',
#        'new_avmValue-cbsa-cj_living_area',
#        'new_avmValue-cbsa-cj_living_area-census_tract',
#        'new_avmValue-cbsa-cj_living_area-census_tract-Transdate',
#        'new_avmValue-cbsa-cj_living_area-census_tract-comments',
#        'new_avmValue-cbsa-cj_living_area-comments',
#        'new_avmValue-cbsa-cj_living_area-comments-Transdate',
#        'new_avmValue-cbsa-cj_living_area-comments-census_tract-Transdate'],
#       dtype='object')

# %%
file_symptoms = 'agent_comments_'+state+\
                        '_for_Thu_01.fea'
df_Thu_old = pd.read_feather(file_symptoms)

# %%
df_Thu = df_Thu_old.copy(deep=True)

# %%
df_Thu_new = df_Thu_new.loc[:,['listingid','new_avmValue-cbsa',
       'new_avmValue-cbsa-cj_living_area',
       'new_avmValue-cbsa-cj_living_area-census_tract',
       'new_avmValue-cbsa-cj_living_area-census_tract-Transdate',
       'new_avmValue-cbsa-cj_living_area-census_tract-comments',
       'new_avmValue-cbsa-cj_living_area-comments',
       'new_avmValue-cbsa-cj_living_area-comments-Transdate',
       'new_avmValue-cbsa-cj_living_area-comments-census_tract-Transdate']]

# %%
df_Thu = pd.merge(left=df_Thu_old, right=df_Thu_new, left_on='listingid', right_on='listingid')

# %%
len(df_Thu)
# Out:
# 189177

# %%
df_Thu.columns
# Out:
# Index(['index', 'listingid', 'qtr', 'state', 'cbsa', 'cj_living_area',
#        'census_tract', 'Transdate', 'Transprice', 'ListingPrice', 'avmValue',
#        'avmerror', 'Train/Test', 'avmValue-cbsa',
#        'avmValue-cbsa-cj_living_area',
#        'avmValue-cbsa-cj_living_area-census_tract',
#        'avmValue-cbsa-cj_living_area-census_tract-Transdate',
#        'avmValue-cbsa-cj_living_area-census_tract-comments',
#        'avmValue-cbsa-cj_living_area-comments',
#        'avmValue-cbsa-cj_living_area-comments-Transdate',
#        'avmValue-cbsa-cj_living_area-comments-census_tract-Transdate',
#        'new_avmValue-cbsa', 'new_avmValue-cbsa-cj_living_area',
#        'new_avmValue-cbsa-cj_living_area-census_tract',
#        'new_avmValue-cbsa-cj_living_area-census_tract-Transdate',
#        'new_avmValue-cbsa-cj_living_area-census_tract-comments',
#        'new_avmValue-cbsa-cj_living_area-comments',
#        'new_avmValue-cbsa-cj_living_area-comments-Transdate',
#        'new_avmValue-cbsa-cj_living_area-comments-census_tract-Transdate'],
#       dtype='object')

# %%
df_Thu.reset_index().drop(columns=['level_0','index'])
# Out:
#         listingid       qtr state   cbsa  cj_living_area census_tract  \
# 0         1654110  201802.0    GA  12060          2600.0  13117130405
# 1         2148517  201802.0    GA  12060          1959.0  13089023212
# 2         8123923  201802.0    GA  12060          6500.0  13089021415
# 3       127411995  201802.0    GA  12060           884.0  13057091102
# 4         5033811  201802.0    GA  12060          1422.0  13067031312
# ...           ...       ...   ...    ...             ...          ...
# 189172  238048745  202105.0    GA  12060          2967.0  13223120103
# 189173  237920865  202105.0    GA  12060          8828.0  13135050321
# 189174  250482890  202105.0    GA  12060          1624.0  13013180301
# 189175  249189043  202105.0    GA  12060          6639.0  13121011504
# 189176  250597538  202105.0    GA  12060          4665.0  13135050212
#
#          Transdate  Transprice  ListingPrice    avmValue  ...  \
# 0       20180102.0    271000.0      275000.0   288265.01  ...
# 1       20180102.0    145000.0      149900.0   111842.66  ...
# 2       20180102.0    805000.0      949000.0   910085.54  ...
# 3       20180102.0    147000.0      153000.0   155697.65  ...
# 4       20180102.0     85000.0       92000.0   149706.16  ...
# ...            ...         ...           ...         ...  ...
# 189172  20210630.0    379000.0      379900.0   363707.25  ...
# 189173  20210630.0   1405000.0     1500000.0  1538213.78  ...
# 189174  20210630.0    285000.0      270000.0   244216.17  ...
# 189175  20210630.0   2520000.0     2495000.0  2057520.42  ...
# 189176  20210630.0    750000.0      757000.0   694672.35  ...
#
#         avmValue-cbsa-cj_living_area-comments-Transdate  \
# 0                                          2.818620e+05
# 1                                          1.268288e+05
# 2                                          7.753654e+05
# 3                                          1.582827e+05
# 4                                          1.395635e+05
# ...                                                 ...
# 189172                                     3.792017e+05
# 189173                                     1.558636e+06
# 189174                                     2.594632e+05
# 189175                                     2.287101e+06
# 189176                                     7.480652e+05
#
#        avmValue-cbsa-cj_living_area-comments-census_tract-Transdate  \
# 0                                            2.828118e+05
# 1                                            1.360521e+05
# 2                                            7.574671e+05
# 3                                            1.517853e+05
# 4                                            1.433766e+05
# ...                                                   ...
# 189172                                       3.789473e+05
# 189173                                       1.630020e+06
# 189174                                       2.586020e+05
# 189175                                       2.318096e+06
# 189176                                       7.315729e+05
#
#         new_avmValue-cbsa  new_avmValue-cbsa-cj_living_area  \
# 0            2.784755e+05                      2.784046e+05
# 1            1.519934e+05                      1.481696e+05
# 2            8.002716e+05                      8.014649e+05
# 3            1.288143e+05                      1.163775e+05
# 4            1.664739e+05                      1.667001e+05
# ...                   ...                               ...
# 189172       3.728267e+05                      3.718859e+05
# 189173       1.283320e+06                      1.322282e+06
# 189174       2.381354e+05                      2.366653e+05
# 189175       2.124238e+06                      2.043956e+06
# 189176       7.086709e+05                      7.150995e+05
#
#         new_avmValue-cbsa-cj_living_area-census_tract  \
# 0                                        2.776335e+05
# 1                                        1.446957e+05
# 2                                        8.362236e+05
# 3                                        1.308048e+05
# 4                                        1.655003e+05
# ...                                               ...
# 189172                                   3.719717e+05
# 189173                                   1.530133e+06
# 189174                                   2.272775e+05
# 189175                                   2.154698e+06
# 189176                                   7.068633e+05
#
#         new_avmValue-cbsa-cj_living_area-census_tract-Transdate  \
# 0                                            2.792672e+05
# 1                                            1.367409e+05
# 2                                            8.010010e+05
# 3                                            1.269193e+05
# 4                                            1.393030e+05
# ...                                                   ...
# 189172                                       3.837342e+05
# 189173                                       1.504705e+06
# 189174                                       2.432168e+05
# 189175                                       2.365073e+06
# 189176                                       7.756991e+05
#
#         new_avmValue-cbsa-cj_living_area-census_tract-comments  \
# 0                                            2.902158e+05
# 1                                            1.409623e+05
# 2                                            7.341326e+05
# 3                                            1.323879e+05
# 4                                            1.442621e+05
# ...                                                   ...
# 189172                                       3.840027e+05
# 189173                                       1.373374e+06
# 189174                                       2.488368e+05
# 189175                                       2.322089e+06
# 189176                                       7.571302e+05
#
#         new_avmValue-cbsa-cj_living_area-comments  \
# 0                                    2.915093e+05
# 1                                    1.471820e+05
# 2                                    6.946116e+05
# 3                                    1.201419e+05
# 4                                    1.449928e+05
# ...                                           ...
# 189172                               3.819385e+05
# 189173                               1.355526e+06
# 189174                               2.527565e+05
# 189175                               2.402121e+06
# 189176                               7.213997e+05
#
#         new_avmValue-cbsa-cj_living_area-comments-Transdate  \
# 0                                            2.824067e+05
# 1                                            1.487679e+05
# 2                                            7.106908e+05
# 3                                            1.256627e+05
# 4                                            1.531443e+05
# ...                                                   ...
# 189172                                       3.872007e+05
# 189173                                       1.603436e+06
# 189174                                       2.545224e+05
# 189175                                       2.373215e+06
# 189176                                       7.521732e+05
#
#         new_avmValue-cbsa-cj_living_area-comments-census_tract-Transdate
# 0                                            2.838845e+05
# 1                                            1.476480e+05
# 2                                            7.426485e+05
# 3                                            1.267268e+05
# 4                                            1.461568e+05
# ...                                                   ...
# 189172                                       3.849363e+05
# 189173                                       1.459595e+06
# 189174                                       2.545463e+05
# 189175                                       2.365138e+06
# 189176                                       7.588150e+05
#
# [189177 rows x 28 columns]

# %%
file_symptoms = 'agent_comments_'+state+\
                        '_for_Thu_01_merged.fea'
df_Thu.reset_index().drop(columns=['level_0','index']).to_feather(file_symptoms)

# %%
file_symptoms = 'agent_comments_'+state+\
                        '_for_Thu_01_merged.csv'
df_Thu.reset_index().drop(columns=['level_0','index']).to_csv(file_symptoms)

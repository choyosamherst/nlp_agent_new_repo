# %%
import numpy as np
import pandas as pd

import time

import matplotlib.pyplot as plt
import os
import re
import seaborn as sns

# %%
import json
import time
import re

# %%
def df_lambda_replace_characters(df, column_name, new_column, dictionary):
    df[new_column] = df[column_name].apply(lambda x: replace_words(x, dictionary))       
    return df

# %%
def replace_words(strtext, dictionary):
    pattern = re.compile(r'(?<!\w)(' + '|'.join(re.escape(key) for key in dictionary.keys()) + r')(?!\w)')
    result = pattern.sub(lambda x: dictionary[x.group()], strtext)
    return result

# %%
from scipy.stats import moment
from scipy.stats import describe

# %%
import nltk
nltk.download('brown')
# Out:
# [nltk_data] Downloading package brown to /home/cdsw/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# True

# %%
from textblob import TextBlob

# %%
from scipy.stats import moment
from scipy.stats import describe

# %%
def basic_stats_error(datalist):
    
    if len(datalist)>1:
        result_describe = list(describe(datalist)[2:])
        result_percentile = result_describe + list(np.percentile(datalist,[10,25,50,75,90]))
        array = np.array(datalist)
        result_percentile = result_percentile+[len(array),len(array[np.where(array>0)[0]])/len(array)*100,
                                               len(array[np.where(array<0)[0]])/len(array)*100]
    else:
        result_percentile = []

    return result_percentile

# %%
def explode(df, lst_cols, fill_value=''):
    # make sure `lst_cols` is a list
    if lst_cols and not isinstance(lst_cols, list):
        lst_cols = [lst_cols]
    # all columns except `lst_cols`
    idx_cols = df.columns.difference(lst_cols)

    # calculate lengths of lists
    lens = df[lst_cols[0]].str.len()

    if (lens > 0).all():
        # ALL lists in cells aren't empty
        return pd.DataFrame({
            col:np.repeat(df[col].values, df[lst_cols[0]].str.len())
            for col in idx_cols
        }).assign(**{col:np.concatenate(df[col].values) for col in lst_cols}) \
          .loc[:, df.columns]
    else:
        # at least one list in cells is empty
        return pd.DataFrame({
            col:np.repeat(df[col].values, df[lst_cols[0]].str.len())
            for col in idx_cols
        }).assign(**{col:np.concatenate(df[col].values) for col in lst_cols}) \
          .append(df.loc[lens==0, idx_cols]).fillna(fill_value) \
          .loc[:, df.columns]

# %%
import seaborn as sns

# %%
sns.set(style="whitegrid")

# %%
from importlib import reload

from nlp_pandas_functions import ngram_analysis
from nlp_pandas_functions import noun_sentences

reload(ngram_analysis)
reload(noun_sentences)
dir(ngram_analysis)
# Out:
# module https://tfhub.dev/google/universal-sentence-encoder/4 loaded
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'bigrams_join',
#  'count_n_grams',
#  'defaultdict',
#  'df_get_n_grams_count',
#  'df_lambda_ngram',
#  'generate_n_grams',
#  'get_imp',
#  'get_n_grams_count',
#  'get_n_grams_probability',
#  'kg',
#  'ngrams',
#  'np',
#  'pd',
#  'text']

# %%
column = 'clean_publicremarks'

# %%
#from nlp_pandas_functions import ngram_analysis
from nlp_pandas_functions import noun_sentences

#reload(ngram_analysis)
reload(noun_sentences)
#dir(ngram_analysis)
# Out:
# module https://tfhub.dev/google/universal-sentence-encoder/4 loaded
# <module 'nlp_pandas_functions.noun_sentences' from '/home/cdsw/final_model_lightgbm/nlp_pandas_functions/noun_sentences.py'>

# %%
import glob
filtered_files = glob.glob("new_avm_df__full_data_state_*_noun_sentences_by_listingid_CJ.fea")

# %%
filtered_files
# Out:
# ['new_avm_df__full_data_state_KS_noun_sentences_noun_sentences_by_listingid_CJ.fea',
#  'new_avm_df__full_data_state_AZ_noun_sentences_noun_sentences_by_listingid_CJ.fea',
#  'new_avm_df__full_data_state_TN_noun_sentences_noun_sentences_by_listingid_CJ.fea',
#  'new_avm_df__full_data_state_FL_noun_sentences_noun_sentences_by_listingid_CJ.fea',
#  'new_avm_df__full_data_state_GA_noun_sentences_noun_sentences_by_listingid_CJ.fea',
#  'new_avm_df__full_data_state_OK_noun_sentences_noun_sentences_by_listingid_CJ.fea',
#  'new_avm_df__full_data_state_UT_noun_sentences_noun_sentences_by_listingid_CJ.fea',
#  'new_avm_df__full_data_state_ME_noun_sentences_noun_sentences_by_listingid_CJ.fea',
#  'new_avm_df__full_data_state_CA_noun_sentences_noun_sentences_by_listingid_CJ.fea',
#  'new_avm_df__full_data_state_MS_noun_sentences_noun_sentences_by_listingid_CJ.fea',
#  'new_avm_df__full_data_state_WA_noun_sentences_noun_sentences_by_listingid_CJ.fea',
# ...

# %%
noun_sentence_df_T_ri_filtered_thu_list_base= pd.read_csv(filtered_files[0])

# %%
filtered_files[0].split('_')[7]
# Out:
# 'KS'

# %%
noun_sentence_df_T_ri_filtered_thu_list_base['state'] = filtered_files[0].split('_')[7]

# %%
noun_sentence_df_T_ri_filtered_thu_list_base
# Out:
#         Unnamed: 0               noun_sentence  listingid state
# 0            56570           main level boasts       4002    KS
# 1            55500              walk-in pantry       4002    KS
# 2            62137             enormous closet       4002    KS
# 3            85185        huge recreation room       4002    KS
# 4            23537  stainless steel appliances       4002    KS
# ...            ...                         ...        ...   ...
# 220727      136147           spacious bedrooms  277148393    KS
# 220728        4539               new hardwoods  277148393    KS
# 220729      102091                   full bath  277148393    KS
# 220730      112009                  new carpet  277148393    KS
# 220731      166753                  yard patio  277148393    KS
#
# [220732 rows x 4 columns]

# %%
for file in filtered_files[1:]:
    
    print(file)    
    noun_sentence_df_T_ri_filtered_thu_list= pd.read_csv(file)
    print(len(noun_sentence_df_T_ri_filtered_thu_list))
    noun_sentence_df_T_ri_filtered_thu_list['state'] = file.split('_')[7]
    noun_sentence_df_T_ri_filtered_thu_list_base = noun_sentence_df_T_ri_filtered_thu_list_base.append(noun_sentence_df_T_ri_filtered_thu_list)
# Out:
# new_avm_df__full_data_state_AZ_noun_sentences_noun_sentences_by_listingid_CJ.fea
# 354358
# new_avm_df__full_data_state_TN_noun_sentences_noun_sentences_by_listingid_CJ.fea
# 514024
# new_avm_df__full_data_state_FL_noun_sentences_noun_sentences_by_listingid_CJ.fea
# 5375668
# new_avm_df__full_data_state_GA_noun_sentences_noun_sentences_by_listingid_CJ.fea
# 2461559
# new_avm_df__full_data_state_OK_noun_sentences_noun_sentences_by_listingid_CJ.fea
# 363710
# new_avm_df__full_data_state_UT_noun_sentences_noun_sentences_by_listingid_CJ.fea
# 421153
# new_avm_df__full_data_state_ME_noun_sentences_noun_sentences_by_listingid_CJ.fea
# 11
# new_avm_df__full_data_state_CA_noun_sentences_noun_sentences_by_listingid_CJ.fea
# 4005
# new_avm_df__full_data_state_MS_noun_sentences_noun_sentences_by_listingid_CJ.fea
# 97789
# new_avm_df__full_data_state_WA_noun_sentences_noun_sentences_by_listingid_CJ.fea
# 1091989
# new_avm_df__full_data_state_OH_noun_sentences_noun_sentences_by_listingid_CJ.fea
# ...

# %%
noun_sentence_df_T_ri_filtered_thu_list_base = noun_sentence_df_T_ri_filtered_thu_list_base.drop(columns=['Unnamed: 0'])

# %%
len(noun_sentence_df_T_ri_filtered_thu_list_base)
# Out:
# 19491527

# %%
noun_sentence_df_T_ri_filtered_thu_list_base
# Out:
#                       noun_sentence  listingid state
# 0                 main level boasts       4002    KS
# 1                    walk-in pantry       4002    KS
# 2                   enormous closet       4002    KS
# 3              huge recreation room       4002    KS
# 4        stainless steel appliances       4002    KS
# ...                             ...        ...   ...
# 3604933                 canyon lake  290220824    TX
# 3604934                  floor plan  290220824    TX
# 3604935                 shade trees  290221239    TX
# 3604936                    new deck  290221239    TX
# 3604937                  large yard  290221239    TX
#
# [19491527 rows x 3 columns]

# %%
9711296
# Out:
# 9711296

# %%
noun_sentence_df_T_ri_filtered_thu_list_base.iloc[9711290:9711299]
# Out:
#                             noun_sentence  listingid state
# 75                         amazing pardee  234932351    CA
# 76                            backs ebmud  234932351    CA
# 77                            tile cement  234932351    CA
# 78                       full view pardee  234932351    CA
# 79                       4/3,2 story barn  234932351    CA
# 80                    formal dinning room  234932351    CA
# 81                      upstairs features  235080616    CA
# 82  kitchen w/expansive island heart home  235080616    CA
# 83                full bed/bath dwnstairs  235080616    CA

# %%
from nlp_pandas_functions import nlp_pandas_functions
reload(nlp_pandas_functions)
dir(nlp_pandas_functions)
# Out:
# ['PorterStemmer',
#  'SnowballStemmer',
#  'TextBlob',
#  'WordNetLemmatizer',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'define_stop_words',
#  'df_column_prepare',
#  'df_column_remove_punctuation',
#  'df_column_remove_unicode',
#  'df_column_simple_prepare',
#  'df_column_stemmer',
#  'df_lambda_lemmatizer',
#  'df_lambda_remove_punctuation',
#  'df_lambda_remove_stop_words',
#  'df_lambda_remove_unicode',
#  'df_lambda_stemmer',
#  'df_lambda_to_lowercase',
#  'df_spell_check',
#  'nltk',
#  're',
#  'single_entry_lambda_stemmer',
#  'single_entry_lemmatizer',
#  'single_entry_prepare',
#  'single_entry_remove_punctuation',
#  'single_entry_remove_stop_words',
#  'single_entry_remove_unicode',
#  'single_entry_spell_check',
#  'string',
#  'word_tokenize']

# %%
#tic = time.time()
#noun_sentence_df_T_ri_filtered_thu_list_base = nlp_pandas_functions.df_lambda_remove_unicode(noun_sentence_df_T_ri_filtered_thu_list_base, 'noun_sentence', 'noun_sentence_np')
#toc = time.time()
#print(toc - tic)

# %%
#noun_sentence_df_T_ri_filtered_thu_list_base = noun_sentence_df_T_ri_filtered_thu_list_base.drop(columns='noun_sentence')

# %%
#noun_sentence_df_T_ri_filtered_thu_list_base = noun_sentence_df_T_ri_filtered_thu_list_base.rename(columns={'noun_sentence_np':'noun_sentence'})

# %%
noun_sentence_df_T_ri_filtered_thu_list_base
# Out:
#                       noun_sentence  listingid state
# 0                 main level boasts       4002    KS
# 1                    walk-in pantry       4002    KS
# 2                   enormous closet       4002    KS
# 3              huge recreation room       4002    KS
# 4        stainless steel appliances       4002    KS
# ...                             ...        ...   ...
# 3604933                 canyon lake  290220824    TX
# 3604934                  floor plan  290220824    TX
# 3604935                 shade trees  290221239    TX
# 3604936                    new deck  290221239    TX
# 3604937                  large yard  290221239    TX
#
# [19491527 rows x 3 columns]

# %%
file_join = 'ch_noun_sentences_by_listingid_CJ_2_full.csv'
noun_sentence_df_T_ri_filtered_thu_list_base.to_csv(file_join)

# %%
noun_sentence_df_T_ri_filtered_thu_list_base
# Out:
#                       noun_sentence  listingid state
# 0                 main level boasts       4002    KS
# 1                    walk-in pantry       4002    KS
# 2                   enormous closet       4002    KS
# 3              huge recreation room       4002    KS
# 4        stainless steel appliances       4002    KS
# ...                             ...        ...   ...
# 3604933                 canyon lake  290220824    TX
# 3604934                  floor plan  290220824    TX
# 3604935                 shade trees  290221239    TX
# 3604936                    new deck  290221239    TX
# 3604937                  large yard  290221239    TX
#
# [19491527 rows x 3 columns]

# %%
#[ch_noun_phrases_by_listingid_for_Thu]

# %%
noun_sentence_df_T_ri_filtered_thu_list_base = noun_sentence_df_T_ri_filtered_thu_list_base.reset_index()

# %%
file_join = 'ch_noun_sentences_by_listingid_CJ_2_full.csv'
noun_sentence_df_T_ri_filtered_thu_list_base.to_csv(file_join)

# %%
file_join = 'ch_noun_sentences_by_listingid_CJ_2_full_part1.csv'
noun_sentence_df_T_ri_filtered_thu_list_base.iloc[0:9662890].to_csv(file_join)

# %%
noun_sentence_df_T_ri_filtered_thu_list_base.iloc[0:9662890]
# Out:
#           index               noun_sentence  listingid state
# 0             0           main level boasts       4002    KS
# 1             1              walk-in pantry       4002    KS
# 2             2             enormous closet       4002    KS
# 3             3        huge recreation room       4002    KS
# 4             4  stainless steel appliances       4002    KS
# ...         ...                         ...        ...   ...
# 9662885  372834                laundry area  246084836    UT
# 9662886  372835                 fresh paint  246084836    UT
# 9662887  372836            private entrance  246084836    UT
# 9662888  372837             tile backsplash  246084836    UT
# 9662889  372838            private backyard  246084836    UT
#
# [9662890 rows x 4 columns]

# %%
len(noun_sentence_df_T_ri_filtered_thu_list_base)
# Out:
# 19491527

# %%
noun_sentence_df_T_ri_filtered_thu_list_base.iloc[9662890:9662890+2000000]
# Out:
#            index         noun_sentence  listingid state
# 9662890   372839              new roof  246084836    UT
# 9662891   372840        county records  246084837    UT
# 9662892   372841       summer evenings  246084837    UT
# 9662893   372842          solar panels  246084837    UT
# 9662894   372843            tone paint  246084837    UT
# ...          ...                   ...        ...   ...
# 11662885  115662       separate shower  150567827    NC
# 11662886  115663  spacious family room  150567831    NC
# 11662887  115664        full bathrooms  150567831    NC
# 11662888  115665         bedroom ranch  150567831    NC
# 11662889  115666           fresh paint  150567831    NC
#
# [2000000 rows x 4 columns]

# %%
file_join = 'ch_noun_sentences_by_listingid_CJ_2_full_part2.csv'
noun_sentence_df_T_ri_filtered_thu_list_base.iloc[9662890:9662890+2000000].to_csv(file_join)

# %%
noun_sentence_df_T_ri_filtered_thu_list_base.iloc[9662890:9662890+2000000].iloc[48404:48408]
# Out:
#          index                          noun_sentence  listingid state
# 9711294     79                       4/3,2 story barn  234932351    CA
# 9711295     80                    formal dinning room  234932351    CA
# 9711296     81                      upstairs features  235080616    CA
# 9711297     82  kitchen w/expansive island heart home  235080616    CA

# %%
noun_sentence_df_T_ri_filtered_thu_list_base[\
                (noun_sentence_df_T_ri_filtered_thu_list_base['noun_sentence']=='private backyard')\
            & (noun_sentence_df_T_ri_filtered_thu_list_base['listingid']==246084836)]
# Out:
#           index     noun_sentence  listingid state
# 9662889  372838  private backyard  246084836    UT

# %%
noun_sentence_df_T_ri_filtered_thu_list_base.loc[372839,:]
# Out:
#                noun_sentence  listingid state
# 372839   high end appliances  266576581    TN
# 372839          master suite  139753925    FL
# 372839       great room with  166177522    GA
# 372839              new roof  246084836    UT
# 372839              old roof  218928967    WA
# 372839           paver patio  220412277    OH
# 372839   comparison purposes  192241381    NC
# 372839           upper level  198080926    CO
# 372839      smooth top range  210941307    MO
# 372839  schedule appointment  189473288    TX

# %%
noun_sentence_df_T_ri_filtered_thu_list_base.loc[9662950:9663000,:]
# Out:
#           index               noun_sentence  listingid state
# 9662950  372899      square footage figures  246084868    UT
# 9662951  372900           courtesy estimate  246084868    UT
# 9662952  372901             open floor plan  246084868    UT
# 9662953  372902        new kitchen cabinets  246084868    UT
# 9662954  372903     independent measurement  246084868    UT
# 9662955  372904         easy freeway access  246084872    UT
# 9662956  372905                bedroom home  246084872    UT
# 9662957  372906                  main level  246084872    UT
# 9662958  372907                  main floor  246084872    UT
# 9662959  372908              house saturday  246084872    UT
# 9662960  372909               large windows  246084872    UT
# 9662961  372910     independent measurement  246084876    UT
# 9662962  372911              county records  246084876    UT
# 9662963  372912      square footage figures  246084876    UT
# ...

# %%
noun_sentence_df_T_ri_filtered_thu = noun_sentence_df_T_ri_filtered.loc[:,['noun_sentence','Listingid_List']]

# %%
noun_sentence_df_T_ri_filtered_thu

# %%
noun_sentence_df_T_ri_filtered_thu_list = explode(noun_sentence_df_T_ri_filtered_thu,
                                           lst_cols=['Listingid_List'])

# %%
noun_sentence_df_T_ri_filtered_thu_list

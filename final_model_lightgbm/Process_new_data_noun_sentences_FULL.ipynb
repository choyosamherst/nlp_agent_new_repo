# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def basic_stats_error(datalist):
    
    if len(datalist)>1:
        result_describe = list(describe(datalist)[2:])
        result_percentile = result_describe + list(np.percentile(datalist,[10,25,50,75,90]))
        array = np.array(datalist)
        result_percentile = result_percentile+[len(array),len(array[np.where(array>0)[0]])/len(array)*100,
                                               len(array[np.where(array<0)[0]])/len(array)*100]
    else:
        result_percentile = []

    return result_percentile

# %%
from scipy.stats import moment
from scipy.stats import describe

# %%
file = 'NEW_AVM_DATA.fea'

new_avm_df = pd.read_feather(file)

# %%
new_avm_df = new_avm_df.rename(columns={'avmvalue':'new_avmValue', 'avmerror':'new_avmerror'})

# %%
new_avm_df = new_avm_df.set_index('listingid')

# %%
import time

# %%
import glob

# %%
len(new_avm_df)
# Out:
# 3670135

# %%
new_avm_df.publicremarks = new_avm_df.publicremarks.astype(str)

# %%
from importlib import reload

# %%
#from nlp_pandas_functions import ngram_analysis
from nlp_pandas_functions import noun_sentences

#reload(ngram_analysis)
reload(noun_sentences)
#dir(ngram_analysis)
# Out:
# 2022-05-24 13:47:33,793 loading file /home/cdsw/.flair/models/sentiment-en-mix-distillbert_4.pt
# INFO:absl:Using /tmp/tfhub_modules to cache modules.
# module https://tfhub.dev/google/universal-sentence-encoder/4 loaded
# module https://tfhub.dev/google/universal-sentence-encoder/4 loaded
# <module 'nlp_pandas_functions.noun_sentences' from '/home/cdsw/final_model_lightgbm/nlp_pandas_functions/noun_sentences.py'>

# %%
from nlp_pandas_functions import nlp_pandas_functions
reload(nlp_pandas_functions)
dir(nlp_pandas_functions)
# Out:
# ['PorterStemmer',
#  'SnowballStemmer',
#  'TextBlob',
#  'WordNetLemmatizer',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'define_stop_words',
#  'df_column_prepare',
#  'df_column_remove_punctuation',
#  'df_column_remove_unicode',
#  'df_column_simple_prepare',
#  'df_column_stemmer',
#  'df_lambda_lemmatizer',
#  'df_lambda_remove_punctuation',
#  'df_lambda_remove_stop_words',
#  'df_lambda_remove_unicode',
#  'df_lambda_stemmer',
#  'df_lambda_to_lowercase',
#  'df_spell_check',
#  'nltk',
#  're',
#  'single_entry_lambda_stemmer',
#  'single_entry_lemmatizer',
#  'single_entry_prepare',
#  'single_entry_remove_punctuation',
#  'single_entry_remove_stop_words',
#  'single_entry_remove_unicode',
#  'single_entry_spell_check',
#  'string',
#  'word_tokenize']

# %%
tic = time.time()
new_avm_df = nlp_pandas_functions.df_column_simple_prepare(new_avm_df, 'publicremarks', 'publicremarks_prepared')
toc = time.time()
print(toc - tic)
# Out:
# 87.27137804031372

# %%
tic = time.time()
new_avm_df = nlp_pandas_functions.df_lambda_remove_unicode(new_avm_df, 'publicremarks_prepared', 'publicremarks_prepared_unicode')
toc = time.time()
print(toc - tic)
# Out:
# 51.01945662498474

# %%
tic = time.time()
new_avm_df = nlp_pandas_functions.df_lambda_remove_stop_words(new_avm_df, nlp_pandas_functions.define_stop_words([]), 
                                           'publicremarks_prepared_unicode', 'clean_publicremarks')
toc = time.time()
print(toc - tic)
# Out:
# 753.4332094192505

# %%
new_avm_df.reset_index()
# Out:
#          listingid  asgpropid       qtr   new_avmValue cbsa_div   cbsa state  \
# 0        283207557   67042149  202108.0  263274.890918    19124  19100    TX
# 1        283255837   67042153  201908.0  202716.233802    19124  19100    TX
# 2        282878450   67042155  202105.0  243683.638611    19124  19100    TX
# 3        283514326   67042161  202008.0  237251.641833    19124  19100    TX
# 4        283453974   67042163  202008.0  222607.270422    19124  19100    TX
# ...            ...        ...       ...            ...      ...    ...   ...
# 3670130  140952556   92049945  201805.0  451405.700112    45104  42660    WA
# 3670131  264393967   92050002  201911.0  529434.425685    45104  42660    WA
# 3670132  127489122   92050165  201802.0  409940.477586    45104  42660    WA
# 3670133  216294252   74882304  201805.0  484072.490284    19740  19740    CO
# 3670134  217085861   74882393  201911.0  394582.314934    19740  19740    CO
#
#            Zip fips_Code census_tract  ...  transprice  bedrooms  \
# 0        75044     48113  48113019029  ...    238000.0       2.0
# 1        75044     48113  48113019029  ...    202000.0       3.0
# 2        75044     48113  48113019029  ...    268000.0       2.0
# 3        75044     48113  48113019029  ...    196000.0       3.0
# 4        75044     48113  48113019029  ...    215000.0       3.0
# ...        ...       ...          ...  ...         ...       ...
# 3670130  98338     53053  53053073118  ...    425000.0       3.0
# 3670131  98338     53053  53053073118  ...    550000.0       3.0
# 3670132  98338     53053  53053073118  ...    384000.0       3.0
# 3670133  80207     08031  08031004104  ...    455000.0       3.0
# 3670134  80207     08031  08031004104  ...    410000.0       2.0
#
#         cj_living_area                                      publicremarks  \
# 0               1440.0  ***OFFER DEADLINE SATURDAY 12PM*** Tip the sca...
# 1               1611.0  Terrific location. Near George Bush 190 Toll R...
# 2               1664.0  This stunning, peaceful, and well maintained 3...
# 3               1643.0  Beautiful community with a great location. New...
# 4               1619.0  Situated within a quiet, secure and tree-fille...
# ...                ...                                                ...
# 3670130         1992.0  Majestic Mt Rainier views from oversized deck ...
# 3670131         2784.0  Gorgeous Equestrian home.The views are magnifi...
# 3670132         1792.0  Beautiful Single Family 3 Bed/2 Bath on a Larg...
# 3670133         2224.0  Open House Sat/Sun April 14th & 15th 11:00-2:0...
# 3670134         1756.0  UNBELIEVABLE value in UNBEATABLE Park Hill loc...
#
#          listingPrice  new_avmerror rentsale  \
# 0            225000.0     -0.106197        S
# 1            210000.0     -0.003546        S
# 2            240000.0      0.090733        S
# 3            199000.0     -0.210468        S
# 4            213000.0     -0.035383        S
# ...               ...           ...      ...
# 3670130      425000.0     -0.062131        S
# 3670131      599999.0      0.037392        S
# 3670132      424900.0     -0.067553        S
# 3670133      475000.0     -0.063896        S
# 3670134      420000.0      0.037604        S
#
#                                     publicremarks_prepared  \
# 0        ***offer deadline saturday 12pm*** tip the sca...
# 1        terrific location. near george bush 190 toll r...
# 2        this stunning, peaceful, and well maintained 3...
# 3        beautiful community with a great location. new...
# 4        situated within a quiet, secure and tree-fille...
# ...                                                    ...
# 3670130  majestic mt rainier views from oversized deck ...
# 3670131  gorgeous equestrian home.the views are magnifi...
# 3670132  beautiful single family 3 bed/2 bath on a larg...
# 3670133  open house sat/sun april 14th & 15th 11:00-2:0...
# 3670134  unbelievable value in unbeatable park hill loc...
#
#                             publicremarks_prepared_unicode  \
# 0        ***offer deadline saturday 12pm*** tip the sca...
# 1        terrific location. near george bush 190 toll r...
# 2        this stunning, peaceful, and well maintained 3...
# 3        beautiful community with a great location. new...
# 4        situated within a quiet, secure and tree-fille...
# ...                                                    ...
# 3670130  majestic mt rainier views from oversized deck ...
# 3670131  gorgeous equestrian home.the views are magnifi...
# 3670132  beautiful single family 3 bed/2 bath on a larg...
# 3670133  open house sat/sun april 14th & 15th 11:00-2:0...
# 3670134  unbelievable value in unbeatable park hill loc...
#
#                                        clean_publicremarks
# 0        ***offer deadline saturday 12pm*** tip scales ...
# 1        terrific location. near george bush 190 toll r...
# 2        stunning, peaceful, well maintained 3 bedroom ...
# 3        beautiful community great location. new carpet...
# 4        situated within quiet, secure tree-filled neig...
# ...                                                    ...
# 3670130  majestic mt rainier views oversized deck situa...
# 3670131  gorgeous equestrian home.the views magnificent...
# 3670132  beautiful single family 3 bed/2 bath large lot...
# 3670133  open house sat/sun april 14th & 15th 11:00-2:0...
# 3670134  unbelievable value unbeatable park hill locati...
#
# [3670135 rows x 23 columns]

# %%
states = ['TX', 'KS', 'AZ', 'TN', 'FL', 'GA', 'OK', 'UT', 'ME', 'CA', 'MS',
       'WA', 'OH', 'MA', 'AL', 'NC', 'CO', 'MO', 'KY', 'NE', 'NY',
       'VA', 'MD', 'HI', 'WV', 'MN', 'AK', 'IN', 'PA', 'SC', 'LA', 'NJ',
       'RI', 'WY']

# %%
len(states)
# Out:
# 34

# %%
new_avm_df.columns
# Out:
# Index(['asgpropid', 'qtr', 'new_avmValue', 'cbsa_div', 'cbsa', 'state', 'Zip',
#        'fips_Code', 'census_tract', 'story', 'effective_year_built',
#        'transdate', 'transprice', 'bedrooms', 'cj_living_area',
#        'publicremarks', 'listingPrice', 'new_avmerror', 'rentsale',
#        'publicremarks_prepared', 'publicremarks_prepared_unicode',
#        'clean_publicremarks'],
#       dtype='object')

# %%
len(new_avm_df.state.unique())
# Out:
# 35

# %%
column = 'clean_publicremarks'

# %%
for state in states[:1]:
    tic = time.time()
    print(state)
# Out:
# TX

# %%
for state in states[:1]:
    tic = time.time()
    print(state)
    new_avm_df_state = new_avm_df[new_avm_df['state']==state]
    result = noun_sentences.df_column_noun_sentences_no_embedding(new_avm_df_state.reset_index(), column, 'new_avmerror', 'listingPrice', 
                                                 'transprice', 'avmvalue')
    
    noun_sentence_df = pd.DataFrame([result[0], result[1], result[2], result[3], result[4], result[5]])
    
    noun_sentence_df_T = noun_sentence_df.T
    noun_sentence_df_T = noun_sentence_df_T.rename(columns={0: 'count', 1: 'AVM_Error', 2: 'AVM_Error_List', 
                                                        3: 'Listing_Error', 4: 'Listing_Error_List',
                                                        5: 'Listingid_List'})
    
    noun_sentence_df_T['AVM_Error_Average'] = noun_sentence_df_T['AVM_Error'] / noun_sentence_df_T['count']
    noun_sentence_df_T['Listing_Error_Average'] = noun_sentence_df_T['Listing_Error'] / noun_sentence_df_T['count']

    noun_sentence_df_T = noun_sentence_df_T.sort_values(by ='AVM_Error_Average', ascending=False)
    noun_sentence_df_T_filtered = noun_sentence_df_T[noun_sentence_df_T['count'] > 100]
    noun_sentence_df_T_ri = noun_sentence_df_T.reset_index()

    noun_sentence_df_T_ri = noun_sentence_df_T_ri.rename(columns={"index": "noun_sentence"})

    noun_sentence_df_T_ri_filtered = noun_sentence_df_T_ri[noun_sentence_df_T_ri['count'].notna()]

    noun_sentence_df_T_ri_filtered['AVM_Error_Indicators'] = noun_sentence_df_T_ri_filtered['AVM_Error_List'].apply(lambda x: basic_stats_error(x))

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestClassifier

from sklearn.preprocessing import MinMaxScaler

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import top_k_accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score

# %%
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
from itertools import combinations

# %%
import seaborn as sns
sns.set_style("whitegrid")

# %%
state = 'GA'

# %%
file_symptoms_train = '../comments/raw_comments/agent_comments_'+state+\
                        '_filtered_final_joined_selected_columns_use_max_scale_one_df_train.fea'

noun_sentence_state_train = pd.read_feather(file_symptoms_train)

# %%
for col in noun_sentence_state_train.columns:
    print(col)
# Out:
# listingid
# qtr
# cbsa_div
# cbsa
# state
# Transdate
# Transprice
# cj_living_area
# fips_code
# census_tract
# zip
# ListingPrice
# avmValue
# avmerror
# AVM_Error_List
# Listing_Error_List
# AVM_Error_Indicators_0
# AVM_Error_Indicators_1
# AVM_Error_Indicators_2
# AVM_Error_Indicators_3
# AVM_Error_Indicators_4
# AVM_Error_Indicators_5
# AVM_Error_Indicators_6
# AVM_Error_Indicators_7
# AVM_Error_Indicators_8
# AVM_Error_Indicators_9
# AVM_Error_Indicators_10
# AVM_Error_Indicators_11
# AVM_Error_Indicators_scale
# AVM_Error_Indicators_scale_inverse
# Listing_Error_Indicators_0
# Listing_Error_Indicators_1
# Listing_Error_Indicators_2
# Listing_Error_Indicators_3
# Listing_Error_Indicators_4
# Listing_Error_Indicators_5
# Listing_Error_Indicators_6
# Listing_Error_Indicators_7
# Listing_Error_Indicators_8
# Listing_Error_Indicators_9
# Listing_Error_Indicators_10
# Listing_Error_Indicators_11
# transaction_year
# AVM_Error_Indicators_0_max_value
# AVM_Error_Indicators_0_min_value
# AVM_Error_Indicators_0_max_indicator
# AVM_Error_Indicators_0_min_indicator
# AVM_Error_Indicators_0_diff_indicator
# AVM_Error_Indicators_0_diff_value
# AVM_Error_Indicators_0_mean
# AVM_Error_Indicators_10_mean
# seller chooses attorney
# omission and or
# actual plan
# tack room
# utilities inspections
# needs repairs
# seller requests buyer use seller
# new shaker cabinets
# hud home
# new white kitchen
# great fixer
# absolute model home
# perfect fixer
# amp service
# clean property
# great home investors
# cosmetic work
# modern farmhouse
# cash sale
# needs work
# excellent opportunity smart bargain hunter
# new hall bath
# doors drawers
# house needs work
# needs tender loving care
# party approval
# tender loving care home
# price subdivision
# modern renovation
# new top bottom
# builder spouse
# mini farm
# hard money
# great opportunity savvy buyer
# marble island
# buyers as soon as possible
# sweat equity
# needs paint
# tile accents
# handy man
# elbow grease
# needs cosmetic
# wall cabinets
# cash buyer
# zillow inc
# custom vent hood
# subject bank approval
# sellers attorney
# new dock
# contemporary finishes
# carrera marble
# inch home
# beverage center
# as is condition
# stall barn
# price area
# new laundry room
# shaker style cabinets
# property needs
# current condition
# perfect horses
# chicken coop
# needs carpet
# top bottom renovation
# ship lap
# butcher block counter tops
# home lots potential
# new bathrooms
# great opportunity investors
# wolf range
# pizza oven
# modern finishes
# seller requests
# potential home
# interior needs
# as is sale
# new addition
# custom master bath
# as is disclosure
# custom barn doors
# proof funds
# full potential
# private park
# quality renovation
# new vanities
# modern ranch
# barn door
# custom fire pit
# top bottom
# accent wall
# great bones
# great potential
# shiplap walls
# lounge area
# new finishes
# shiplap accents
# new systems
# modern design
# great investor
# as is seller
# quartz counters
# vintage charm
# designer fixtures
# market value
# loads potential
# ready horses
# farmhouse style
# attention investors
# cosmetic updates
# 100k upgrades
# real estate license georgia
# comparison purposes
# new sheetrock
# close drawers
# minor repairs
# hickory floors
# estate sale
# ready renovation
# monday night garage
# outdoor shower
# modern living
# minor tender loving care
# home investor
# new quartz tops
# head toe
# modern touches
# earnest money
# available quick move in
# new cabinetry
# contract instructions
# great investment opportunity
# amazing renovation
# 30day satisfaction
# microwave drawer
# home needs
# duct work
# price neighborhood
# master suite addition
# designer finishes
# new duct work
# investors dream
# modern features
# updates list
# great rental potential
# need storage
# home good bones
# tons potential
# as is sellers disclosure
# fha va
# slice heaven
# market price
# end lake lanier
# rain shower
# great investment property
# pot filler
# new full bath
# new cabs
# lowe windows
# blown insulation
# updates upgrades
# good investment
# due diligence
# new interior doors
# family chef
# custom vanity
# seller disclosures
# frameless glass
# new tubs
# gutter system
# frank betz
# summer kitchen
# full porch
# tenant occupied do disturb
# price tag
# designer home
# subway tile backsplash
# belt line
# check comparisons
# new bathroom vanity
# beautiful salt water pool
# new luxury
# tons restaurants
# highend finishes
# boat house
# inviting pool
# cabinets drawers
# year round enjoyment
# termite letter
# new baths
# beautiful remodel
# new ductwork
# herb garden
# sellers disclosure
# beverage cooler
# right inspect
# new island
# s disclosure
# kind property
# select rooms
# great rental opportunity
# blocks beltline
# great rental property
# new landscape
# hardie board
# true beauty
# details list
# quiet cove
# shiplap wall
# blank canvas
# mercedes benz stadium
# story addition
# top line finishes
# new vanity
# space price
# modern amenities
# kings bay sub base
# perfect investors
# concrete counter tops
# corner home
# designer tile
# den w
# wellkept neighborhood
# you will notice
# home tenant
# conventional cash
# moment drive
# available investors
# perfect investment
# pole barn
# new light
# total rehab
# new construction wardlaw construction
# ready new roof
# new doors
# modern updates
# windows hvac
# new fireplace
# horse farm
# large barn
# electrical fixtures
# entire area  wow
# mans dream
# swim tennis playground community
# new features
# new crown
# property disclosure
# composite deck
# luxury vinyl tile
# private estate
# outdoor kitchen
# property tenant
# outdoor paradise
# incredible location minutes i20
# seer hvac
# nickel fixtures
# unbeatable value
# sure wow
# deep water
# feet island
# disclosure seller
# log home
# new concrete driveway
# water view
# new lvp
# ready beauty
# national register
# feet lake frontage
# modern style
# right buyer
# modern convenience
# open concept designs spaces
# krog street market
# price firm
# induction cooktop
# final opportunity
# new architectural
# wolf appliances
# available property
# exterior walls
# right places
# perfect blend
# new kitchen
# gas lanterns
# epoxy garage floor
# steps beltline
# time outdoors
# custom tile shower
# inner chef
# rich film television history
# antebellum homes
# double driveway
# white development
# entertainers kitchen
# visit house
# new custom
# new bathroom fixtures
# bath cabinets
# new driveway
# designer backsplash
# designer details
# cabinet doors
# piece paradise
# long term tenant place
# rear gardens
# complete rehab
# new garage
# terms conditions
# modern backsplash
# s retreat
# farm house
# classic design
# palm trees
# salt water
# light switches
# piece heaven
# grill area
# paver driveway
# supra lockbox
# new arch roof
# minutes tybee island
# entire property
# exquisite details
# complete custom
# dead gorgeous
# craftsman bungalow
# bessie branham park
# quaint shops
# favorite spot
# perfect balance
# nice size family room
# stone shower
# absolute perfection
# double pane
# exterior boasts
# ready upgrades
# beautiful fixtures
# solid home
# great investment home
# deck fire pit
# estate property
# quick sale
# zoysia grass
# pool spa
# kitchenaid appliances
# i20 i285
# modern light fixtures
# tyler perry studios
# joanna gaines
# master retreat trey
# cabinet lights
# rental investment
# new windows
# glass tile
# rental portfolio
# beautiful creek
# instant equity
# white picket
# coffee station
# anderson windows
# porcelain tile
# lake life
# sale price
# mcintosh school district
# intext paint
# high end kitchen
# zip line
# gray cabinets
# short sale foreclosure
# details home
# new master bathroom
# current tenant
# electric gate
# month month lease
# conventional loans
# electrical service
# new renovation
# forest heights
# custom windows
# natural stone
# walkin master closet master bathroom dual sinks
# rental home
# attention details
# interior designer
# active
# city convenience
# opportunity knocks
# entry doors
# new cement
# high end appliances
# double slip dock
# charm galore
# fulton school district
# mature fruit trees
# new stairs
# grove park
# top line stainless appliances
# easy access truman parkway
# low e windows
# mechanical systems
# 30day buyback
# new items
# waterfront home
# wow home
# rosemont school zone
# spanish moss
# original character
# new pool
# new toilets
# new leaf homes
# private dock
# modern flair
# brick frame
# builder incentives
# big water
# ring doorbell
# view property
# fresh designer paint
# charming sunroom
# historic charm
# pool pump
# leaf guard gutters
# bedrooms brand
# lakefront home
# work bench
# laminate plank
# new insulation
# wood shutters
# top line
# diligence period
# murphy bed
# outdoor speakers
# harmony lakes
# storage building electricity
# new construction george tomas homes
# beautiful decor
# high end stainless steel appliances
# new kitchen cabinets
# softclose cabinets
# new energy
# ready fall
# taxes reflect senior discount
# bosch appliances
# character home
# ready package
# new sinks
# kitchen with custom cabinetry
# shower heads
# home good condition
# custom ranch
# tongue groove ceilings
# lease option
# electrical system
# butcher block island
# floor plan subdivision
# beam ceilings
# luxury vinyl plank
# property vacant
# future beltline
# upscale finishes
# original butlers pantry
# home investment property
# party deck
# island cooktop
# westside reservoir park
# low flow
# boat dock
# new stone
# custom tile work
# custom vanities
# hall neighborhood
# owner occupant purchasers
# yard paradise
# updates galore
# upgrades name
# 3 acres
# custom granite
# sunrise sunsets plan day
# boat slip
# check photos
# marble shower
# lot room
# tons outdoor
# urban oasis
# two story culdesac home
# separate guest house
# chapel hill school district
# great home price
# wine fridge
# floor plan community
# tongue groove
# lake terrace
# nice size kitchen
# kitchen wall
# ready vision
# swim playground community
# dont blink
# custom wet
# story retreat
# investment portfolio
# private paradise
# new tankless
# tons square footage
# inground salt water pool
# seller chooses
# new fans
# vacation home
# video tour
# interior doors
# marble counters
# modern luxury
# new granite counter tops kitchen bathrooms
# perfect gathering
# new shutters
# original heart pine floors
# lake house
# new skylights
# john weiland
# exotic granite
# br2ba home
# fha loan
# beautiful inground pool
# zone hvac
# vessel sinks
# spray foam insulation
# water dock
# glass wine
# new gutters
# new faucets
# brazilian cherry
# tenants place
# ready quick sale
# true master suite
# efficient windows
# you are home
# new light fixtures
# complete remodel
# view pond
# copper gutters
# forsyth park
# thermador appliances
# new deck
# windows roof
# quality craftsmanship
# vegetable garden
# concrete drive
# custom island
# agent manager seller
# solid core doors
# basement cul
# high end
# floorplan neighborhood
# nest thermostat
# new mirrors
# designer upgrades
# park boat
# great rental income
# lush landscape
# tv area
# new designer
# guest house
# model paint color
# mirror lake
# s kitchen
# professional grade appliances
# list upgrades
# country kitchen breakfast area
# stock images
# storm room
# work play
# kitchen brand
# deep water dock
# seamless gutters
# cabinets overlooks family room
# great square footage
# builder contribute
# smoke detectors
# step front door
# one of a kind home
# new double
# lot home money
# amazing finishes
# porch w fireplace
# home energy
# mini fridge
# top line appliances
# custom touches
# zoysia sod
# luxurious finishes
# sits culdesac
# perfect outdoor activities
# country life
# japanese maples
# pottery barn
# year architectural
# high end upgrades
# main gorgeous
# long call
# modern colors
# lots possibilities
# easy walk dock
# formal spaces
# beautiful island
# small barn
# seamless shower door
# low price
# quality finishes
# large bathroom double vanities
# new architectural roof
# ice machine
# granite double vanity
# wonderful traditional home
# complete package
# mosaic tile backsplash
# nice size rooms
# huge reduction
# perfect getaway
# new kit
# covington square
# marble bath
# lazy susan
# new architectural shingles
# friendly subdivision
# electrical panel
# excellent school system
# new fixtures
# double office
# wrap around deck
# water cove
# smart thermostat
# bamboo hardwoods
# sound speakers
# fireplace mantle
# acres homeowner association
# multiple outdoor
# total package
# mile i85
# great swim
# extras home
# custom mantle
# designer kitchen
# frameless glass shower
# great water
# spa shower
# fire pit
# new bath fixtures
# hour fitness center
# stock photo
# ez access
# lots space money
# complete pool
# basketball goal
# acre tract
# firepit area
# market village
# backyard oasis
# private oasis
# historic details
# personal home
# comforts home
# carrara marble
# disturb tenants
# full apartment
# pendant lights
# great value home
# sales center
# multiple pools
# breakfast bar island
# plush carpet
# great house money
# foot doors
# full lawn maintenance included focus life
# energy costs
# porch access
# laurel springs
# travertine shower
# waters edge
# cost incentive
# true oasis
# key condition
# awesome value
# acre pond
# tennis amenities
# blue ridge mountains
# electric car
# private resort
# cobb ranch
# vinyl exterior
# white granite
# georgia tech
# oak handrails wrought
# charleston plan
# painting allowance
# new lights
# incredible curb appeal
# fans light fixtures
# serene privacy
# close ga
# outdoor firepit
# buford highway
# fha appraisal
# period details
# great roswell location
# remote control
# savvy investor
# floor plans neighborhood
# new floorplan
# new door hardware
# road frontage
# new sod
# range hood
# spectacular backyard
# convenient i16
# heart pine
# boat launch
# ready february
# secret garden
# majestic oaks
# new pool liner
# great opportunity purchase
# wine cooler
# frml liv
# game day porch
# light fixtures
# granite fireplace
# convection microwave
# trash compactor
# clean lines
# large seperate
# entertainers dream
# custom cabinets
# fish pond
# great outdoors
# new front porch
# future pool
# owner occupants
# bells whistles
# exterior doors
# water fall
# home level lot
# gourmet kitchen custom cabinetry
# complete kitchenette
# indoor outdoor pools
# serious buyers
# new window
# slip dock
# perfect starter home investment property
# need room
# key home
# homeowner association amenities
# appliances fixtures
# built in surround
# shower bench
# convection oven
# home high ceilings
# lagoon view
# beautiful estate
# convenient shops
# energy efficient windows
# quick walk
# wonderful subdivision
# tile baths laundry room
# new wrought
# rental property
# high quality
# attic insulation
# huge spa bath
# original price
# kind custom
# prof landscape
# ready march
# built in refrigerator
# unique touches
# stainless steel appliance package
# potential buyers
# boat hoist
# impressive owners suite
# whole house water filtration system
# roll doors
# immaculate custom
# pebble tec pool
# recess lights
# quality upgrades
# water fountain
# todays lifestyle
# special property
# life home
# claw foot tub
# custom cabs
# imagination run
# subzero fridge
# modern kitchen
# door hardware
# huge walk shower
# season sun room
# hours notice show
# drive way
# homes area
# room concept
# ready personal touches
# new floors
# perfect mix
# tile backslash
# ceilings w
# garden bed
# fast price
# new floor coverings
# bremen city schools
# multipurpose room
# classic charm
# mid century
# entertainment size
# perfect reading
# luxurious master bedroom
# pack bags
# porch backyard
# foyer powder room
# blueberry bushes
# social activities
# rinnai tankless
# buyers fall
# month month
# energy efficiency
# blocks park
# beauty wont
# new thermal windows
# beautiful countertops
# spacious office
# cool evenings
# gorgeous brand
# bright eat in kitchen
# baths granite counters
# double shower heads
# parks recreation
# phipps plaza
# bonus room master
# old charm
# quieter lifestyle
# electric bill
# suite w
# ranch level lot
# deep backyard
# beautiful floor plan offering
# sty family room
# kitchen master suite
# large balcony
# home property
# good book
# distance neighborhood amenities
# state park
# seller process
# shower glass door
# beautiful lagoon
# professional appliances
# hardwoods everywhere
# replacement windows
# private remarks
# luxury upgrades
# mcdonough square
# master retreat envy
# main level garage
# city cartersville
# you will fall
# heart richmond hill
# custom crown
# solid construction
# bosch driveway
# perfect large gatherings
# new hvac
# stone floors
# callaway gardens
# marble floor
# gwinnett braves
# huntley hills
# size home
# private pond
# state art kitchen
# unique floorplan
# outdoor oasis
# large home
# vacant show
# house culdesac
# new construction kerley family homes
# time summer
# swimming tennis amenities
# perfect personal business needs
# large house
# exceptional quality
# lot space
# tile bathrooms
# new pergola
# closet organizers
# mud area
# part home
# french door refrigerator
# personal retreat
# elegant finishes
# porte cochere
# historic places
# great opportunity
# main custom
# great value
# decorative fireplace
# year americas
# carriage house
# time home
# trim work
# room adjacent
# modern open floor plan
# complete electricity
# min drive
# wow factor
# fine finishes
# new plank
# ceilings crown
# macon location
# recreational vehicle storage
# additional vehicles
# new pump
# beautiful country
# white oak floors
# pool deck
# perfect combination
# swim tennis lake community
# bead board
# original fireplaces
# kitchen remodel
# upgrades everywhere
# fixtures
# new hardware
# home wow factor
# seller needs
# true chefs kitchen
# canton street
# absolute gem
# meticulous home
# price reflects
# smart home
# creek property
# two car carport
# beautiful granite
# deck spans
# space money
# cobb community
# decorators dream
# modern home
# quick drive
# wont disappoint
# backyard entertainers dream
# custom finishes
# upstairs trey
# gourmet kit with island
# pool house
# private bath garden tub
# concrete floor
# top line kitchen
# home approximate
# foyer w
# restaurants
# wonderful family
# glass front cabinets
# kitchen custom
# white cabinets
# todays market
# happy home
# favorite beverage
# moment step
# separate island
# country charm
# grassy yard
# kitchen dream
# fine details
# mill work
# closet systems
# beautiful open concept
# tone paint
# discriminating buyers
# pristine hardwoods
# good home
# sure catch eye
# time home buyers investors
# industrial boulevard
# fit king
# travertine tile
# new home holidays
# nice home
# solid oak
# private acres
# bath beauty
# bedrooms laundry
# vinyl floors
# gorgeous tile
# ready summer
# ready use
# cedar beams
# beauty boasts
# hardwood floors plantation shutters
# shower master bathroom
# new exterior
# area schools
# timeless beauty
# large storage room garage
# extra prewire
# hood vent
# efficient double pane windows
# woodstock roswell
# professional landscape
# triple pane windows
# close amenities
# private outdoor
# level basement
# fantastic neighborhood amenities
# lawn equipment
# endless potential
# distance oakhurst village
# full upgrades
# room wstone fp
# new shower door
# gray paint
# interior colors
# slate floors
# new front
# new cabinet
# double convection ovens
# distance beltline
# space w
# carpet allowance
# ready touch
# gourmet stainless steel appliances hardwood floors
# chefs dream
# entire home
# forsyth neighborhood
# panel doors
# hour security
# high efficiency
# super home
# kitchen eat in breakfast area
# koi pond waterfall
# new bamboo floors
# granite wet
# clean pin
# two story corner home
# room master bath
# stucco home
# stable neighborhood
# separate glass
# privacy need
# vanity master
# additional square footage
# custom fireplace
# immediate sale
# pickiest buyers
# end unit
# community pool clubhouse
# granite baths
# area hardwood floors
# new look
# great price
# chimneys farm
# separate whirlpool tub shower
# primary suite
# new hardiplank
# beautiful clubhouse
# new appliances
# beautiful wrap
# expansive views
# main level owners suite
# lots amenities
# popcorn ceilings
# must see home
# lovely custom
# brick estate
# complete renovation
# corporate relocation
# hardwood entry
# crepe myrtles
# stair rails
# convenient bedrooms
# total privacy
# personal touch
# new front door
# serene views
# interior finishes
# current home
# owners suite w
# golden opportunity
# agent view
# value area
# outdoor spaces
# additional acreage
# easy access parks
# family fun
# hardwoods galore
# designer touches
# new lvt
# yard plenty room
# oakhurst village
# easy freeway access
# sound system
# hall location
# big game
# acre home site
# custom moldings
# luxurious baths
# morning coffee front porch
# new hardwoods
# new liner
# brick accent wall
# island lots counter space kitchen
# new hardy plank
# breakfast area view family room
# lakeside high school district
# wood ceilings
# steps grant park
# public schools
# interior upgrades
# frame home
# true ranch
# extras list
# yard tools
# new black appliances
# large vehicles
# new high school
# plenty outdoor
# stone columns
# perfect empty nesters
# tile wet areas
# classic beauty
# step shower
# community pool tennis courts
# additional building
# lake park
# rental restrictions
# old ac
# new tile
# street lake
# show stopper
# great addition
# dinette area
# solid hardwood
# boat camper
# original oak floors
# s cooler pooler
# beautiful updates
# stone tile
# large master suite closets
# complete brand
# list price
# solid wood doors
# previous owners
# sump pump
# sun city peachtree
# charming move in
# porch wood
# exterior maintenance
# retail district
# rest house
# beautiful craftsman style
# safe neighborhood
# lake arrowhead
# retail stores
# frameless shower
# amenities list
# bedroom plan master suite
# milton hs
# new double pane windows
# tennis teams
# attractive home
# beautiful bath
# positive cash flow
# bath home corner lot
# charm character
# separate toilet room
# pool waterfall
# awesome property
# new updates
# modern cabinets
# grill deck
# steam shower
# peachtree corners
# dramatic ceilings
# great shape
# adorable cottage
# interior walls
# cute house
# yard outdoor
# big screen tv
# time buyer investor
# concept home
# complete wet
# h2o heater
# metal roof
# new vent hood
# spacious brick home
# tasteful upgrades
# espresso cabinets
# long range
# brazilian hardwoods
# special place
# locust grove
# numerous updates
# new water
# hardwoods downstairs
# original charm
# great lot
# kind home
# swim neighborhood
# views lake
# sure fall
# new patio
# time home owner
# village deaton creek
# ez show
# kitchen master bathroom
# dryer refrigerator
# inman park
# owners suite bath
# popular home
# check beauty
# mid century ranch
# separate workshop
# ward park
# new wood
# built in wine rack
# beautiful master bathroom
# true inlaw suite
# main garden tub
# large bdrm
# mobile home
# neighborhood sidewalks
# tile foyer
# future bath
# custom deck
# kitchen bathrooms
# slate roof
# entertainers paradise
# new upgrades
# mst bath
# open concept
# granite counter tops stainless steel appliances
# french doors kitchen
# loft office
# custom closet
# decorative tile
#  stock photos
# countertops appliances
# deck breakfast area
# proud call home
# s pantry
# central hallway
# rare gem
# kitchen you will
# corporate owner
# price reduction
# kids playroom
# areas
# large work island
# air ducts
# legacy park
# convenient neighborhood
# easy access restaurants
# additional patio
# power water
# brick walls
# museum school
# large carport
# separate meter
# loads space
# eat in kit
# screened in deck
# perfect retreat
# keyless entry
# guest cottage
# tenant place
# turnkey home
# hard surface counters
# generous kitchen
# backyard playset
# patio outdoor fireplace
# smith douglas homes
# pleasure show
# bathrooms granite
# multiple upgrades
# year roof
# area pantry
# elegant dinning room
# incredible lake
# agent show
# new countertops
# beautiful heart pine floors
# mall georgia
# floor bedrooms
# beauty home
# regular sale
# playground clubhouse
# huge master trey
# ceilings skylights
# drastic reduction
# full deck
# tub surround
# new home community
# paint in out
# cool matter port 3d virtual tour
# kit w
# great new price
# atlanta zoo
# miles marietta square
# full character
# spectacular home
# tile shower
# entire exterior
# private driveway
# yard firepit
# beauty sits
# new fence
# architectural details
# ultimate privacy
# pocket doors
# hour notice showings
# moment walk
# beautiful custom cabinetry
# gorgeous property
# warm hardwoods
# apple trees
# monthly fee
# perfect everyday living
# bronze hardware
# freedom park
# new carpet bedrooms
# private sanctuary
# cozy sun room
# nice kitchen breakfast area
# lots house money
# tee box
#  loan
# pull drawers
# room kids
# text agent
# master shower
# custom home
# minutes avalon
# year round
# taxes reflect homestead exemption
# quality home
# walkable neighborhood
# convenient lake lanier
# dekalb taxes
# custom millwork
# doors windows
# s dream
# filtration system
# stone countertops
# close lake allatoona
# ready holidays
# 1st time market
# boat recreational vehicle
# w upgrades
# home wow
# home brand
# stainless stove
# wow house
# new gorgeous
# relax pool
# patio pool
# sac home
# woodward academy
# great community amenities
# handsome home
# gorgeous custom home
# burner gas range
# mature plantings
# suntrust park
# private toilet area
# lifetime warranty
# new washer
# upgrades galore
# new construction hallmark homes
# story den
# private virtual tour
# secondary bathrooms
# brookwood school cluster
# beautiful site
# new counter tops
# new stainless steel appliances
# private owner suite
# lots home
# newton county
# seller install
# incentives time
# spacious trey
# emory cdc
# courtyard entry
# ac system
# scenic highway
# focal point
# dont walk
# outdoor storage
# elegant living room
# basement law suite
# true gem
# patio fire pit
# original tile
# bosch dishwasher
# electric fireplace
# step family room
# slate tile
# original wood
# indian hills
# floor retreat
# area owners
# additional upgrades
# large shop
# ready october
# tons curb appeal
# piece crown
# garden tub separate shower
# gutter guards
# separate liv room
# sac neighborhood
# desirable school district
# breakfast areabar
# home inspection
# wood stove
# main level trey
# incredible value
# captivating home
# redone kitchen
# lots closets storage
# vacant supra
# game day
# available sale
# daffin park
# large shower
# lrdr combo
# beautiful cape cod
# lazy river
# casual elegance
# historic bungalow
# picnic pavilion
# home vacant
# new high efficiency hvac
# gorgeous outdoor
# grape vines
# rebuilt deck
# unbelievable price
# true laundry room
# deck master
# spacious open concept
# pecan trees
# close restaurants
# perfect yard
# room custom
# extra windows
# island w
# separate driveway
# dekalb farmers market
# bedrooms stairs
# perkerson park
# madison plan
# minutes parks
# gorgeous acres
# heart buckhead
# minutes marietta square
# long price
# additional information
# deluxe bath
# bottom level
# super location
# media bonus room
# sidewalk community
# area w
# notable features
# mill creek school district
# true master
# peachtree city
# minutes feet stewart
# sugar hill
# whole house attic fan
# star rs mill schools
# end day
# community minutes
# distance chastain park
# acres green space
# family members
# owners suite with trey
# hot water tank
# quiet culdesac location
# stove insert
# beautiful sunset
# stainless steel appliances island
# home welcomes
# floorplan home
# built in pantry
# lot creek
# two car garage
# mountain view school district
# large master suite bath
# upstairs fireplace
# special incentives
# new granite counter tops
# backyard boasts
# available neighborhood
# spacious traditional home
# check virtual tour
# pool lake
# room island
# picturesque setting
# new low flow toilets
# lock box
# heart johns creek
# great income
# efficient appliances
# desirable swim
# spectacular custom
# wine cellar
# quartzite countertops
# entryway greets moment walk
# huge clubhouse
# separate officestudy
# st marys
# complete fire pit
# screen room
# nice size master bedroom
# home checks boxes
# 3d tour
# perfect boat
# private lake
# heart desires
# minutes midtown
# black stainless steel appliances
# space
# pasture land
# cold feet
# chair wrap
# outdoor grill
# nice front
# spacious bedrooms plenty room study
# large brick
# family room with built ins
# amazing pool
# main with walk in closet
# ready w
# porch wfp
# need look
# perfect 10
# upstairs hosts
# new oil
# estate broker
# great gwinnett schools
# ideal pets
# generous rooms
# mature oak trees
# room wcrown
# clos ein location
# counter tops
# completion date
# custom walk closet
# fruit trees
# weight room
# hot tub
# basement potential
# s suite
# private retreat
# interior boasts
# childrens retreat
# new storm doors
# pull attic stairs
# picky buyers
# huge owners
# pool playground
# 9ft ceilings 1st floor
# built in speakers
# hvac system
# selections carpet
# kitchen boasts
# st community
# agent ga
# car garage auto opener
# abundance windows
# study french doors
# master bath renovation
# private space
# designer colors
# blinds windows
# hour notice
# picture window
# tremendous opportunity
# whitewater school district
# park playground
# whirlpool appliances
# overlooks backyard
# new pergo
# st simons
# yr roof
# new vinyl kitchen
# backyard
# solar panels
# sunroom family room
# charming cottage
# electric bills
# water heater
# fitness counter
# room lots
# lawn maintenance
# top list
# walkin shower
# floor plan hardwoods
# office play room
# cup coffee
# jefferson school district
# beautiful home boasts
# speaker system
# gwinnett mall
# vanity
# hardy board
# burner stove
# swim tennis neighborhood
# full time
# big canoe
# pine floors
# hardie plank
# 1 acre
# owner custom
# sure impress
# basement sits
# close i20
# special touches
# bathroom plan
# beautiful pond
# brazilian cherry hardwood floors
# peach trees
# yard play area
# neutral tones
# cambridge plan
# adorable move in
# perfect den
# lot cul
# stone wall
# white cabinets granite counters
# full southern charm
# agent schedule appointment
# kitchen updates
# sewer line
# home disappoint
# true retreat
# deck family room
# tons updates
# bonus room 5th bedroom
# neutral paint carpet
# interior exterior
# home tons storage
# gas fire pit
# acres privacy
# ready downsize
# double gate
# new roof
# fireplace wall windows
# sile stone counter tops
# great family neighborhood
# international horse park
#  ami
# story foyer hardwood
# custom patio
# school year
# gentlemans study
# builder offering
# room furniture
# custom pantry
# coat valet
# serene master suite
# restaurants ashley park
# stainless steel
# main level family room
# lots hardwood
# public library
# starter home
# room with hard wood
# abigail plan
# villa rica
# loganville schools
# custom window treatments
# solid oak hardwood floors
# naval submarine base
# lavish kitchen
# beautiful white cabinets
# basement exterior entry
# quiet time
# large floorplan
# metro atlanta
# wide plank
# water purification system
# buyers loss gain
# homeowner association flood insurance
# mulberry park
# large size
# wooden beams
# gourmet kitchen with breakfast area
# oaks golf course
# homeowner association restrictions
# day discount
# gourmet kitchen wstainless steel appliances
# sun deck
# quick access i75
# distance marietta square
# floor plan boasts
# new storage
# recent renovation
# separate drive
# beautiful new construction home
# spacious loft area
# precious home
# sunroom w
# country style
# new kitchen faucet
# time home buyer
# city jefferson schools
# granite counters
# pool tennis court
# invisible fence
# favorite book
# whole house generator
# garage doors
# available purchase
# dupont commons
# hardwoods family room
# miles cart paths
# bedroom bungalow
# perfect pool
# jackson county
# unbeatable price
# immediate occupancy
# available usda
# fabulous floorplan
# smart home technology
# designer cabinets
# henderson park
# granite tops
# open family
# cash flow
# small workshop
# main gate
# workshopstorage building
# custom walkin closets
# lender attorney
# splash stainless steel appliances
# grand 2story
# city life
# new construction
# quick move in
# spacious master bedroom trey ceilings
# spacious beds
# great in laws
# secondary bedrooms laundry room
# huge workshop
# major systems
# unique custom
# memorial park
# collins hill school district
# piece history
# relax master suite
# mud room
# great school district
# sub zero fridge
# river state park
# crawl space
# full laundry room
# separate patio
# green house
# new garage door
# generous pantry
# creek runs
# time buyers
# garage power
# great colors
# great place kids
# porch family room
# buildable lot
# spacious hall bath
# large master suites
# new window blinds
# great location highway
# atlanta home
# current appraisal
# fabulous pool
# large private bath
# professional pics
# sheet rock
# yard access
# room side
# lake front home
# kiddie pool
# mini kitchen
# contact agent
# efficient hvac
# cottage style home
# natural gas
# heavy crown
# minutes uga
# natural light floods
# drop zone
# agent state georgia
# area backyard
# spacious move in
# wide plank pine floors
# paran homes
# floors bathrooms
# small enclave
# special features
# new kroger
# winter nights
# tile laminate
# suite garden tub
# office with built ins
# ensuite bathroom
# granite kit
# plant shelves
# garden area
# ready june
# stucco exterior
# traditional brick front home
# year architectural shingle roof
# community homeowner association
# young roof
# open concept family room
# due sunday
# kitchen feat
# family room marble fireplace
# separate formal living
# main perfect guests
# photos home plan
# distance high school
# historic acworth
# share jack
# workshop power
# bathroom fixtures
# fireside family
# sugarloaf pkwy
# wide baseboards
# traditional brick
# huge island
# hard wood
# quick response
# hallway bathroom
# suite bathroom
# level front
# large pantry kitchen
# rock fireplace
# tennis community
# atlanta village
# builder close out
# convenient marta
# privacy galore
# walton high school district
# low cobb county taxes
# sip coffee
# large outdoor
# dark hardwood floors
# opportunity home
# club house
# room addition
# new playground
# boatrv storage
# sugarloaf parkway
# large custom
# wrap around porch
# visit builder website contact information
# lux bath
# work island
# space garage
# quiet privacy
# private lot w
# pickle ball
# roof brand
# new interior
# area adjacent
# large lake
# low dekalb taxes
# ready gem
# separate family room fireplace
# area downstairs
# whole house humidifier
# ready imagination
# great floor plan
# italian tile
# deep water access
# open family room breakfast area
# private inground pool
# m homes
# quiet evenings
# alarm code
# rainy days
# mins airport
# private drive
# master bath garden tub
# nice bath
# huge ranch
# hardwood floors crown
# mountain view
# incredible open layout
# available
# oven microwave
# extraordinary home
# private door
# x zone
# a schools
# kitchen baths
# good life
# beautiful great room
# beautiful new hardwoods
# attic fan
# yard fence
# black appliance package
# decorator touches
# homes community
# recreation facilities
# deep trey
# great forsyth schools
# deck master bedroom
# perfect workshop storage
# wet areas
# old appliances
# nice size master
# neighborhood pool
# homes subdivision
# bright open plan
# rental potential
# lake location
# prime corner lot
# share bath
# complete w
# home lots
# travertine floor
# full bath kitchenette
# sounds nature
# yard workshop
# story foyer welcomes home
# secondary baths
# community amenities
# cottage home
# sweet tea
# costs andor prepaids
# similar plan
# basement culdesac
# laurel park
# custom wood
# new
# new counters
# payment assistance
# bedrooms home
# picture frame
# great house
# car driveway
# classic style
# island walkin pantry
# easy walk
# backyard space
# lender credit
# bathrooms laundry
# 2story foyer
# local restaurants
# room opening
# park place avalon
# popular plans
# master suit
# spacious home
# lots daylight
# warm colors
# office craft room
# custom front door
# full charm
# guest brba
# island kit
# desirable location
# flower beds
# spacious dinning room
# quality abounds
# great chance
# chefs kitchen
# upstairs carpet
# kitchen upgrades
# tax credit
# community center
# chefs kitchen with island
# perfect extra storage
# potential commercial
# county records
# deep lot
# dramatic great room
# bath property
# office study
# parkview high school
# room garden
# minutes emory
# convenient mall ga
# bath custom
# construction home
# lovely view
# fabulous owners suite
# ample cabinet
# sty entry
# fans
# neighborhood amenities
# home space
# central school district
# morgan county
# charming craftsman
# large wrap
# area bedrooms
# gorgeous kitchen w
# great community
# hardwoods foyer
# story family
# multiple shower heads
# purchase home
# tennis playground
# kitchen aid appliances
# full suite
# bedroom den
# john with island resale
# large party deck
# separate living room office
# community pool
# formal den
# garage w
# nice size backyard
# family guests
# sun room overlooks
# jackson lake
# long
# main areas
# actual subject property
# lambert school district
# super energy
# active swim tennis lifestyle
# main level guest bedroom
# backyard retreat
# double vanities master bathroom
# spacious master suite fireplace
# 4sides brick
# formal lr dinning room
# active homeowner association
# tile hardwoods
# small kitchenette
# dickerson middle
# wonderful corner lot
# central heat
# fresh exterior
# custom builtins
# picture windows
# porch outdoor
# bedroom plan privacy
# large play area
# heat air
# bronze fixtures
# main guests
# coffee shops
# full sod
# electric oven
# cute cozy
# bath home move in
# fabulous custom
# personal items
# air units
# available rent
# distance community pool
# kennesaw state university
# corner pantry
# savannah plan
# personal tour
# security alarm
# swimming tennis community
# expansive amount
# backyard play
# sales price
# tidal creek
# front porch welcomes home
# beautiful tray
# granite court
# convenient master
# lockbox code
# terrace level basement
# fans bedrooms
# beautiful entry
# home move in condition
# window seat
# thousands market
# spacious home sits
# property boasts
# great area
# dollar view
# oversize master
# spacious kitchen with breakfast area
# rear stairs
# autry mill
# secondary bedrooms lots closet space
# ga realtor
# built in grill
# yard w
# upstairs baths
# swim team
# dallas highway
# country front porch
# low utilities
# prime lot
# new appliance package
# new floor kitchen
# playground area
# estate agent ga
# private fireplace
# koi ponds
# permanent foundation
# perfect setting
# unique features
# large formal living
# ranch bonus room
# hardwoods levels
# price home
# lots builtins
# luxurious master bathroom
# brick stone
# large mud room
# tasteful decor
# friendly backyard
# 5 acres
# forsyth hs
# morning coffee
# dish washer
# great location schools
# street lights
# stone surround
# henry countys
# fantastic level lot
# easy family
# natures beauty
# perfect set
# room eat in kitchen
# clawfoot tub
# huge screened in porch
# privacy fence
# story ceilings
# gas grill
# convenient kitchen
# stone wood
# kitchen stainless steel appliances
# cabinets pantry
# beautiful cul
# safe room
# minutes savannah
#  wont
# bright sunny
# guest bath
# buford city school district
# open living
# price drop
# wont market
# fireplace master
# majority home
# great neighborhood
# custom wood blinds
# active adult community
# floor
# traditional features
# bedroom2 bath
# agent schedule
# traditional ranch home
# home contract
# mint condition
# fresh carpet
# location key
# year shingles
# part property
# microwave vent hood
# spacious w
# light package
# great room corner fireplace
# corner tub
# lot privacy
# floor plan high ceilings
# prime roswell location
# remarkable swim community
# beautiful private lot
# new copper
# suite master bath
# large kit
# free vinyl
# great culdesac location
# huge country kitchen
# time home buyer investment property
# master his hers closets
# packard plan
# wood fence
# concrete patio
# basement endless possibilities
# multiple uses
# walkin closet
# corp property
# hartsfield airport
# den with fireplace
# gorgeous master bath
# pull driveway
# 1210 warranty
# home neighborhood
# huge oak trees
# peace mind
# formal liv
# gas range
# sales office
# roswell address
# gem home
# views backyard
# full ensuite bathroom
# executive office
# garage apartment
# great room with built ins
# great spot
# lush gardens
# need sacrifice
# mature pecan trees
# webb bridge park
# systems roof
# whole house
# terrace level recreation room
# car garage workshop
# alpharetta avalon
# new interior exterior paint
# tree house
# fall evenings
# pickiest buyer
# decorator paint colors
# minute drive
# heart brookhaven
# oversize shower
# kitchen center island
# peaceful retreat
# lease purchase
# savannah airport
# stone front porch
# main floorplan
# easy commute airport
# ideal inlaw suite
# fig tree
# den kitchen
# theater room
# side athens
# low country home
# large open living spaces
# foyer plan
# ready features
# heres opportunity
# gas starter
# bedroom option
# game area
# open land
# sequoyah high school district
# complete double vanities
# side town
# new home warranty
# desirable streets
# new pictures
# agent information
# formal lroffice
# archer high school district
# kitchen lots counter space
# new paint
# beautiful screen porch
# story stone fireplace
# family room overlooks
# porch relax
# savannah pooler
# perfect outdoor
# perimeter mall
# nice pantry
# home wrap moisture barrier
# brickfront home
# cool fall evenings
# minutes shops
# perfect expansion
# huge master bedroom
# lots custom
# entertainment space
# need preview
# cool lovely autumn evenings
# kitchen breakfast
# open door
# brick home master
# beautiful lawn
# seller pay
# private ensuite bath
# perfect 1st time home buyer
# art studio
# local schools
# irrigation system
# perfect man cave
# impeccable home
# house price
# seasonal mountain
# likenew home
# new friends
# bedroom brick home
# quaint neighborhood
# full view
# huge walkin
# perfect entertainment
# functional design
# fulton schools
# main w2
# open floor plan fireplace
# kings bay
# two story foyer
# hotwater heater
# dont pass
# morris brandon
# sod front
# open front door
# sports court
# perfect starter home
# sure check
# prep island
# baths w
# perfect flow
# bathroom vanities
# shower surround
# incredible upgrades
# romantic owners suite
# area pets
# beautiful scenery
# kitchen accents
# stainless appliances breakfast
# local amenities
# easy appointment
# recent updates
# upstairs addition
# easy maintenance vinyl
# unique open floor plan
# future home
# century communities
# new two story garage home
# huge loft
# stone patio
# charming features upgrades
# pergo floors
# king springs
# scenic views
# view home
# patio underneath
# great parties
# convenient upstairs laundry room
# long market
# book tour
# great light
# electrical outlets
# coat closet
# lush lawn
# master bedroom suites
# upper cabinets
# open floorplan hardwoods
# automatic openers
# tons space
# public park
# separate family
# porch addition
# white oak golf course
# new vinyl plank
# plant shutters
# pride ownership shows
# double lot
# frank lloyd wright
# 2car gar
# family room wet
# patio overlooks level
# large trees
# location cant
# schedule visit
# utility bills
# new septic system
# cost use
# study area
# upper level hosts
# kitchen wcherry cabinets
# spiral staircase
# original details
# two story family room fireplace
# desirable master
# separate tub shower double vanity
# porches front
# popular swimming tennis neighborhood
# extra features
# built in china cabinet
# quiet retreat
# beds
# great starter
# sub zero
# custom paint
# house lot
# owners suites
# membership fees
# floor coverings
# yard creek
# separate shower glass surround
# ponce city market
# separate media room
# plenty room pool
# hall bath
# open concept kitchen
# extra crown
# huge bonus
# luxury master suite
# room roam
# doors lead
# electric utilities
# heart pooler
# cobb location
# fault seller
# open loft
# lot storage
# perfect neighborhood
# complete stainless appliances
# seller offering
# splash kitchen
# short bike
# beautiful gardens
# corian tops
# ceilings lots
# 1acre lot
# story brick
# picnic tables
# bedroom home sits
# thermopane windows
# fresh sod
# elegant archways
# area closets
# hartsfield jackson
# large great room brick fireplace
# forsyth community
# level corner lot
# beautiful home w
# recreation center
# transferable termite bond
# plenty room expansion
# sleek kitchen
# seller
# hardwood heater
# perfect relax
# level backyard patio
# ryan plan
# lassiter hs
# builder pay
# park area
# special home
# new trex deck
# home bells
# new backsplash
# full length deck
# great room double
# hamilton mill
# secondary bdrm
# partial kitchen
# small community
# custom shutters
# desirable community
# new hot water heater
# social gatherings
# rental unit
# parks schools
# view lake
# space privacy
# kitchen boasts granite counters
# home good
# peace tranquility
# gorgeous hardwoods
# 3br 2ba
# minutes pinewood studios
# druid hills
# new place
# relax front porch
# private land
# beautiful pergola
# quality construction
# spacious ranch
# garage floor
# hot ashford park
# spacious floor plan
# private stairs
# ready wont
# length house
# corner garden tub
# historic college park
# brick cottage
# excellent schools
# his hers vanity
# formal lr
# room cozy
# separate garage
# photos renderings representative
# brick bungalow
# heart home
# open house sunday
# middle school
# entertainers deck
# restaurants parks
# backyard w deck
# den wfp
# city atlanta
# main wfrench doors
# real wood cabinetry
# cat walk
# great sky
# beautiful front
# bedroom media room
# grant park
# beautiful home culdesac
# open floor plan w
# ga 400
# bonus room kitchen
# cozy sunroom
# true showplace
# spacious lr
# story family room
# large open kitchen
# tons cabinets counter space
# large kitchen appliances
# great amenities
# office nook
# brick paver patio
# master ensuite bath
# marble countertops bathrooms
# home owners association
# hustle bustle
# perfect play room
# open floor plan encompasses
# tennis courts
# formal areas
# formal living room
# new sunroom
# front door
# financial assistance
# darling home
# private backyard storage
# private front
# spacious owner
# remarkable ranch
# small lake
# cozy wood
# side property
# national battlefield park
# separate living room
# ready occupy
# condition home
# cookie cutter
# gas fireplaces
# extras name
# sellers offering
# interior entry
# built in storage
# separate living
# open floor plan family room
# atlanta motor speedway
# short walk pool
# area dogs
# huge kitchen
# cabinets crown
# home youve
# home w
# pill hill
# final touches
# fantastic location
# great flat
# basement custom
# bright breakfast area
# window treatments
# bath cape cod
# optional homeowner association
# corner lot w
# sidewalks street lights
# distance lake allatoona
# home pristine
# yard thats
# gorgeous crown
# luxurious home
# corian ctops
# carpet house
# private area
# main house
# beautiful lot
# stylish home
# craftsman style ranch
# oconee schools
# richmond hill schools
# neat pin
# lot home
# beautiful traditional style home
# full light
# tile surround
# main plan
# bedroom25 baths
# ranchstyle home
# master closet
# avondale estates
# adorable kitchen
# story beauty
# eligible usda
# with connector
# level bonus room
# great room high ceilings
# low utility bills
# botanical gardens
# traditional home
# traditional w
# room expansion
# large study
# beautiful level yard
# family room fireplace builtins
# water softener
# peaceful setting
# 5burner gas cooktop
# marble vanity
# stairs lead
# wood stairs
# relax sunroom
# dishwasher microwave
# stone walkways
# community garden
# volleyball courts
# cobb avenues
# gas stub deck patio
# minute walk
# lakeside hs
# everyday living
# area privacy
# multiple windows
# gorgeous details
# sunny eat in kitchen
# formal living
# magnificent views
# actual home construction
# easy access 400
# mandatory homeowner association
# westside beltline
# custom drapes
# easy entry
# convenient laundry
# open living areas
# tons hardwoods
# new garbage disposal
# story foyer
# beautiful view backyard
# busy day
# primary bedroom
# home gym
# patio pergola
# ceilings cozy fireplace
# with new paint
# elegant 2story foyer
# story great room
# bedrooms wjack
# complete beautiful bathroom
# horse park
# formal entry
# easy access ga
# custom details
# comfortable living room
# easy show
# work room
# mature hardwoods
# dark hardwoods
# billiard area
# cold nights
# abundance cabinetry
# family room with wood
# ga home
# full windows
# new disposal
# cooler pooler
# cozy cottage
# separate tub shower walkin closet
# scrnd porch
# guest retreat
# dramatic entry
# traditional style
# lake neighborhood
# hickory hardwood floors
# brick front
# large kitchen view family room
# fireplace french doors
# price adjustment
# separate showergarden tub
# brick backsplash
# lake mayer
# cobb county schools
# irrigation front
# room hallway
# athletic club
# formal din
# home buyers warranty
# right price
# level ranch
# rare opportunity
# large kitchen lots cabinets
# acre nature
# hard coat stucco
# water access
# room windows
# sac location
# beautiful bungalow
# ton space
# yard work
# clear termite
# short stroll
# cozy den
# large garden area
# basement expansion
# open gr
# expensive homes
# hello gorgeous
# smooth ceilings
# sac street
# tile floor
# area garage
# collier hills
# realtor state georgia
# great location w
# large basement
# friendly culdesac
# shop area
# full kit
# tile patio
# doll house
# room columns
# basement boasts
# library office
# kitchen lots storage
# clean carpets
# formal livingstudy
# private tour
# loftoffice area
# new laminate
# laundry chute
# clean neat
# 1car carport
# murphey candler park
# top notch
# additional office space
# open great room kitchen
# new plan
# dollar homes
# private getaway
# stand shower
# neutral decor
# entry garage
# picket fence
# additional nice size bedrooms
# level cul
# large center island
# golf community
# massive granite island
# great culdesac
# usable space
# traditional floorplan
# office5th bedroom
# house home
# complete wood
# home sits corner lot
# nice appliances
# eat in kitchen
# separate powder room
# open deck
# gem wont
# master suite trey
# quiet peaceful
# neighborhood clubhouse
# ready january
# close schools
# thermal pane windows
# private water closet
# cart paths
# big city
# end culdesac
# large family room fireplace
# small town
# right home
# beautiful wood cabinets
# tile baths
# sty home
# backs greenspace
# ready enjoyment
# new tin roof
# medical facilities
# master boasts
# brick construction
# area bath
# glass windows
# showcase home
# lucky buyer
# main bathroom
# inch blinds
# main level you will
# time family friends
# spacious laundry
# minutes town
# sac lot
# new const
# spacious lots
# spacious deck
# home theater
# appraisal value
# common areas
# inground pool
# large screened in
# appointment show
# transferrable warranty
# historic grant park
# new ac
# ready pool
# 3br2ba ranch
# room access
# space need
# zip code
# level play area
# quiet family
# toco hills
# stove refrigerator
# deck relax
# cozy kitchen
# cherokee county schools
# charming details
# room w bay window
# owners suite tray
# super cute
# perfect bbqs
# time homebuyers
# fin terr level
# open staircase
# room steps
# huge laundry mud room
# abundance space
# brick vinyl
# side porch
# easy access kitchen
# low traffic
# dunwoody home
# marble surround fireplace
# quick access i20
# new thermostat
# master bath walkin shower
# marble tops
# buyers wont
# ceilings tons
# extra den
# room crown
# immaculate home
# area access
# wall windows family room
# convenient i285
# bath ranch bonus room
# fit chef
# georgia gwinnett college
# main entrance
# charming fireplace
# bedrooms w
# specialty ceilings
# beautiful immaculate
# summer days
# open backyard
# entertainment options
# bedroom playroom
# distance top
# school district
# pot rack
# work home
# market fault sellers
# agent appoinment
# new vinyl
# shadow box
# solid rock
# additional bedrooms laundry room
# chain link fence
# local parks
# bath brick front home
# recent appraisal
# fit needs
# tons room
# energy bills
# open main floor
# relax unwind
# large master master bath
# easy walk lake
# large backyard deck
# historic marietta square
# clubhouse fitness center
# laundry shoot
# large eat in kitchen
# swimtennis comm
# man cave
# available show
# great living
# tax record
# spacious family
# summer nights
# floor home
# affordable living
# shower stall
# flexible space
# distance home
# central vacuum system
# fresh market
# ...
# historic roswell
# floor w
# great teen suite
# ideal guests
# main level boasts
# year hsa home warranty
# bedrooms jack and jill bath
# full size
# family dinners
# main wfp
# cathedral ceilings
# room wet
# ranch style
# grand piano
# immaculate move in
# separate study
# heart city
# banquet dinning room
# double porches
# spindles staircase
# energy star
# separate office
# low maint
# pike county
# main level walkin closet
# easy commutes
# easy access i20
# laundry room
# quiet dead end street
# spacious guest suite
# adorable home
# main closets
# bright light
# builders warranty
# spacious bathrooms
# kitchen access
# engineers property
# new whole foods
# additional bedrooms jack jill bath
# ashford park
# double vanity walk closet
# bath cottage
# yard wpatio
# electric range
# clean whistle
# public sewer
# easy commute atlanta
# updates home
# hot neighborhood
# large bedrooms w
# distance amenities
# room w butlers pantry
# open foyer
# circle drive
# rental income
# ernest homes
# private baths
# hardwood floors family room
# large owners suite
# huge laundry room
# highway 316
# new crpt
# separate access
# small kitchen
# home plenty
# functional kitchen
# public water
# lake access
# kids playground
# front house
# trilevel home
# minutes beach
# lake golf club
# area master suite
# hardwoods bedrooms
# affordable luxury
# upstairs family room
# need space
# free exterior
# large vanity
# formal study
# rooms
# tall cabinets
# home boasts hardwood floors
# huge walk closet
# perfect property
# room area
# brookfield country club
# ideal storage
# gourmet kit with granite
# master bdrm
# edward plan
# portion basement
# wild life
# private level
# plenty room garden
# workshop basement
# home sweet home
# versatile floor plan
# personal residence
# popular subdivision
# bedrooms45 baths
# actual home
# deck access
# master bed
# storm shelter
# pine mountain
# new sod front yard
# hard surface
# area workshop
# pool slide
# paint appliances
# interstate access
# chair front
# floor master
# downstairs den
# basement inlaw suite
# bedroom study
# sound prewire
# quiet sd
# whitewater schools
# mother law suite
# floor plan
# bright great room
# master bed bath
# lake dow
# elegant crown
# yard
# palladium window
# exquisite millwork
# charm home
# family room addition
# gorgeous move in
# quaint community
# perfect family
# main level
# charming ranch
# open flrplan
# complete walkin closet
# large playground
# acre cul
# home total
# plenty room kids
# ready property
# ready new carpet
# lots trees
# full length front porch
# plenty room
# open floor plan lots
# circle driveway
# spacious garage
# elementary district
# family room access
# nice closets
# upstairs bedrooms
# great recreation room
# stores restaurants
# room connects
# large deck kitchen
# ranch home basement
# master bedroom ensuite
# french door deck
# property sits
# elegant brick home
# expansive lot
# upstairs boasts
# spacious sunroom
# huge walk pantry
# tons cabinet
# mercer university
# backyard backs
# pool table area
# bay window kitchen
# perfect office
# ac units
# media center
# room seat
# main basement
# beach area
# windows galore
# entire family
# small subdivision
# room floor
# separate bathroom
# hardiplank exterior
# full bath office
# main w fireplace
# jackson school district
# baseball fields
# refrigerator dishwasher
# mary lin
# home wont
# paint colors
# law suite
# 1920s bungalow
# large master suite w
# double door entry
# loads windows
# minutes fletc
# separate living spaces
# rear yd
# jet tub
# streets neighborhood
# appointment view home
# open living room
# large media room
# artist studio
# open family room w fireplace
# wonderful place
# propane tank
# complete island
# large family room lots light
# perfect view
# emory village
# full tile bath
# house shows
# howard school district
# maximum privacy
# city water
# country home
# secondary bedrooms w
# room wood
# sun room
# ready yours
# room tray
# room bathroom
# boat door basement
# huge storage building
# beautiful bamboo
# gourmet kit
# minutes restaurants
# full bath round
# ready design
# powder springs
# separate apartment
# convenient airport
# clayton county
# bright kitchen
# perfect guest
# movie theaters
# double wall ovens
# tier deck
# full fin
# spacious backyard
# hard work
# room office
# new floors paint
# swimming tennis optional
# open lr
# main w
# inlaw teen suite
# smooth cooktop
# plenty closets
# new chandelier
# flat screen
# flr pln
# bkfst room
# minutes hospital
# ready new owner
# separate living quarters
# maple cabinets
# lvp floors
# outlet shoppes atlanta
# daylight terrace level
# bonus sunroom
# ceilings foyer
# basketball court
# backs green space
# abundant cabinets
# stair case
# wide foyer
# drive garage
# basement bonus room
# reasonable price
# kitchen laundry
# large privacy
# additional secondary bedrooms
# shower walkin closet
# double vanities
# additional bedrooms w
# guest bedroom with full bath
# medical center
# car side entry
# spacious large closets
# 10 ceilings
# double vanity
# naval base
# home money
# double tray
# yard privacy
# additional bedroom
# spacious master retreat
# hurry dont
# decorative columns
# contemporary flair
# street subdivision
# spacious living area
# etowah river
# disc golf
# real estate
# wide hand
# space kitchen
# hunter aaf
# adjacent kitchen
# open airy
# main level guest suite
# full bath shower
# main rooms
# fantastic neighbors
# sand volleyball
# piedmont fayette hospital
# complete level
# bonus space
# spacious double vanity
# full baths
# social circle school district
# generous walk closet
# efficient kitchen
# private setting
# flat driveway
# hishers walkin closets
# spacious driveway
# electric appliances
# area master
# etc
# club membership
# rare master
# photos and or renderings representative
# beautiful windows
# large rear yard
# bath with dual vanities
# fresh interior
# convenient access
# isle hope
# master shower seat glass enclosure
# beautiful private yard
# city limits
# contemporary ranch
# brick fireplace
# colonial style home
# large level
# neutral paint
# lovely foyer
# kitchen island breakfast area
# close major highways
# bath dream home
# city decatur
# lovely family room
# inviting home
# big ticket items
# bath rooms
# nice walkin closet
# additional living
# bonus areas
# screened in patio
# fresh air
# patio privacy fence
# room table
# ranch floorplan
# perfect teen in law suite
# area kids
# private flat
# natural surroundings
# downstairs you will
# deer run
# picture frame crown
# main level master retreat
# spacious sun room
# morning room
# quiet street
# hers closets
# formal foyer
# guest bedroom
# private backyard w
# low rise
# acre lake
# ranch home
# new carpets
# views golf course
# easy care
# baths ranch
# richmond hills
# beautiful kitchen island
# built in oven
# chair rails
# separate din room
# laundry areas
# bath gem
# master suite w walkin closet
# comfortable floor plan
# deck fireplace
# outdoor activities
# pinewood studios
# front foyer
# beautiful two story home
# bedroom arrangement
# space basement
# old home
# large home office
# charming home
# min i85
# large secondary bedrooms w
# easy access schools
# kitchen area
# full bath home
# family needs
# separate breakfast area
# car carport
# extra touches
# extensive renovation
# bath walkin closet
# guest suite
# upstairs full bath
# recent hvac
# comfortable family room
# tall ceilings
# whole house blinds
# basement bathroom
# abundance cabinet space
# bath floors
# wide hallway
# bed3 bath
# separate lr dinning room
# end street
# septic tanks
# full bath bonus room
# huge terrace level
# distance parks
# stone front
# bedrooms downstairs
# new roof exterior paint
# quiet mornings
# buyers agent
# comfortable living
# large owners retreat
# porch kitchen
# generous size
# level w
# opportunity pass
# tile carpet
# sunroom overlooks
# easy access i75
# mile i20
# walkup attic
# open design
# quartzite counters
# spacious basement
# magnificent home
# large pantry
# pictures plan
# perfect family gatherings
# great office space
# adjacent lot
# direct access
# plenty street
# upstairs master
# main floor bedrooms
# ball ground
# new microwave
# street park
# entry foyer
# car garage plenty
# recreation room basement
# island granite countertops
# ready show
# fireplace gas logs
# beautiful views lake
# mature neighborhood
# mountain retreat
# original owners
# full daylight
# exquisite moldings
# hard surface countertops
# brick ranch home
# earthcraft home
# large open area
# built in book shelves
# open great room
# ready condition
# small children
# basement theater room
# upstairs room
# distance shops restaurants
# large recreation
# home sits
# additional living space
# beautiful columns
# open ranch plan
# full bathroom hallway
# separate shower water closet
# culinary delights
# min i75
# location
# open kitchen family room
# way home
# gas logs
# br4 bathroom
# master spa suite
# french doors patio
# basement w wet
# front bedroom
# rear home
# open view kitchen
# tall windows
# bonus room closet
# sizable bedrooms
# french drs
# beautiful 4br
# book shelves
# voluntary homeowner association
# oconee county
# huge side yard
# exact representation home
# awesome backyard
# great use space
# beautiful street
# owner pay
# amenities galore
# property line
# formal family room
# walkin attic storage
# upscale community
# large private backyard
# walkout basement
# neighborhood parks
# kitchen island
# spacious master
# large wood deck
# beautiful flowers
# large closet
# main floor
# terrace level with full bath
# entire downstairs
# private bathroom
# formal livingoffice
# spacious master suite boasts
# ceilings gas fireplace
# mature trees
# small family
# backyard building
# feet home
# great cabinets
# inviting living room
# alexander park
# price improvement
# stepin shower
# yard pets
# new subdivision
# rear lot
# luxury kitchen
# upstairs area
# large backyard privacy fence
# acre lot
# options endless
# updates included
# private study
# deck overlooks
# main whis
# jack and jill bathroom
# peaceful neighborhood
# liv room
# golf cart path
# double crown
# main fl
# separate vanity
# baths downstairs
# open kit
# dark cabinetry
# master bedroom
# car kitchen level garage
# utility room
# brook run park
# huge wic
# spacious master closet
# full bathrm
# free home
# home tons
# master suite w fireplace
# atlantic station
# open flow
# large mudroom
# national park
# his hers closet
# island home
# bedroom garage
# home you will
# large light
# dual vanity
# room bedrooms
# terrace level inlaw suite
# free home warranty
# ideal kids
# underground utilities
# lndry room
# nice size closets
# water park
# future expansion
# br2 bathroom ranch
# desirable home
# separate pantry
# 2car garage, family room
# 2car garage, full bath home
# 2car garage, laundry room
# 2car garage, main level
# 2car garage, new carpets
# 2car garage, new granite counter tops
# 2car garage, new hardwood floors
# 2car garage, new stainless steel appliances
# 2car garage, separate shower
# additional bedroom, full bath home
# additional bedroom, main level
# additional bedroom, master suite w
# additional bedroom, new granite counter tops
# additional bedroom, new hardwood floors
# additional bedroom, new stainless steel appliances
# additional bedroom, separate shower
# amazing home, full bath home
# amazing home, main level
# amazing home, new granite counter tops
# amazing home, new hardwood floors
# amazing home, new stainless steel appliances
# bath home, new granite counter tops
# bath home, new stainless steel appliances
# bonus room, new stainless steel appliances
# breakfast room, family room
# breakfast room, full bath home
# breakfast room, main level
# breakfast room, new granite counter tops
# breakfast room, new hardwood floors
# breakfast room, new stainless steel appliances
# breakfast room, separate shower
# double vanity, new stainless steel appliances
# double vanity, separate garden tub
# double vanity, separate shower
# family room, full bath home
# family room, main level
# family room, new granite counter tops
# family room, new hardwood floors
# family room, new stainless steel appliances
# family room, separate shower
# fresh paint, new carpets
# fresh paint, new granite counter tops
# fresh paint, new hardwood floors
# fresh paint, new roof
# fresh paint, new stainless steel appliances
# front porch, new stainless steel appliances
# full bath home, full baths
# full bath home, great room
# full bath home, guest bedrooms
# full bath home, large bedroom
# full bath home, large closet
# full bath home, laundry room
# full bath home, main floor
# full bath home, main level
# full bath home, master bath
# full bath home, master bedroom
# full bath home, master suite w
# full bath home, natural light
# full bath home, new carpets
# full bath home, new granite counter tops
# full bath home, new hardwood floors
# full bath home, new roof
# full bath home, new stainless steel appliances
# full bath home, open concept floor plan
# full bath home, private yard
# full bath home, secondary bedroom
# full bath home, separate garden tub
# full bath home, separate shower
# full bath home, terrace level
# full bath home, walkin closet
# full bathrooms, main level
# full bathrooms, new stainless steel appliances
# full baths, main level
# full baths, new stainless steel appliances
# gas stove, new stainless steel appliances
# granite counters, main level
# granite counters, new hardwood floors
# granite counters, new stainless steel appliances
# granite countertops kitchen, new stainless steel appliances
# great room, main level
# great room, new granite counter tops
# great room, new hardwood floors
# great room, new stainless steel appliances
# huge island, new stainless steel appliances
# large bedroom, main level
# large bedroom, new stainless steel appliances
# large closet, main level
# large closet, master bedroom
# large closet, master suite w
# large closet, new granite counter tops
# large closet, new hardwood floors
# large closet, new stainless steel appliances
# large closet, separate garden tub
# large closet, separate shower
# laundry room, main level
# laundry room, new stainless steel appliances
# main floor, new granite counter tops
# main floor, new stainless steel appliances
# main level, master bath
# main level, master bedroom
# main level, master suite w
# main level, natural light
# main level, new carpets
# main level, new granite counter tops
# main level, new hardwood floors
# main level, new roof
# main level, new stainless steel appliances
# main level, open concept floor plan
# main level, private yard
# main level, secondary bedroom
# main level, separate garden tub
# main level, separate shower
# main level, story foyer
# main level, terrace level
# master bath, new granite counter tops
# master bath, new hardwood floors
# master bath, new stainless steel appliances
# master bath, separate shower
# master bedroom, new granite counter tops
# master bedroom, new hardwood floors
# master bedroom, new stainless steel appliances
# master bedroom, separate shower
# master suite w, new granite counter tops
# master suite w, new hardwood floors
# master suite w, new stainless steel appliances
# master suite w, separate shower
# natural light, new granite counter tops
# natural light, new hardwood floors
# natural light, new stainless steel appliances
# new carpets, new granite counter tops
# new carpets, new hardwood floors
# new carpets, new paint
# new carpets, new roof
# new carpets, new stainless steel appliances
# new granite counter tops, new hardwood floors
# new granite counter tops, new kitchen cabinets
# new granite counter tops, new paint
# new granite counter tops, new roof
# new granite counter tops, new stainless steel appliances
# new granite counter tops, open concept floor plan
# new granite counter tops, separate garden tub
# new granite counter tops, separate shower
# new granite counter tops, tile floor
# new granite counter tops, walkin closet
# new granite counter tops, white cabinets
# new hardwood floors, new paint
# new hardwood floors, new roof
# new hardwood floors, new stainless steel appliances
# new hardwood floors, open concept floor plan
# new hardwood floors, private yard
# new hardwood floors, separate shower
# new hvac, new roof
# new hvac, new stainless steel appliances
# new hvac, water heater
# new kitchen cabinets, new stainless steel appliances
# new paint, new roof
# new paint, new stainless steel appliances
# new roof, new stainless steel appliances
# new roof, water heater
# new stainless steel appliances, open concept floor plan
# new stainless steel appliances, private yard
# new stainless steel appliances, secondary bedroom
# new stainless steel appliances, separate garden tub
# new stainless steel appliances, separate shower
# new stainless steel appliances, stone fireplace
# new stainless steel appliances, story foyer
# new stainless steel appliances, tile floor
# new stainless steel appliances, walkin closet
# new stainless steel appliances, water heater
# new stainless steel appliances, white cabinets
# separate garden tub, separate shower
# separate garden tub, walkin closet
# separate shower, walkin closet
# main level, new granite counter tops, new stainless steel appliances
# new granite counter tops, new hardwood floors, new stainless steel appliances

# %%
file_symptoms_test = '../comments/raw_comments/agent_comments_'+state+\
                        '_filtered_final_joined_selected_columns_use_max_scale_one_df_test.fea'
noun_sentence_state_test = pd.read_feather(file_symptoms_test)

# %%
noun_sentence_state_test_transdate_train = noun_sentence_state_train.groupby('Transdate').mean()[['avmerror']].reset_index()
noun_sentence_state_test_transdate_train = noun_sentence_state_test_transdate_train.rename(columns={"avmerror": "avmerror_mean"})

# %%
noun_sentence_state_test_transdate_test = noun_sentence_state_test.groupby('Transdate').mean()[['avmerror']].reset_index()
noun_sentence_state_test_transdate_test = noun_sentence_state_test_transdate_test.rename(columns={"avmerror": "avmerror_mean"})

# %%
noun_sentence_state_train = noun_sentence_state_train.merge(noun_sentence_state_test_transdate_train,
                                                         how='left', left_on='Transdate', right_on='Transdate')

# %%
noun_sentence_state_test = noun_sentence_state_test.merge(noun_sentence_state_test_transdate_test,
                                                         how='left', left_on='Transdate', right_on='Transdate')

# %%
#selcted_columns = selcted_columns + list(noun_sentence_state_train.columns[51:-1])

# %%
all_combinations = [['avmValue','cbsa'],
                    ['avmValue','cbsa', 'cj_living_area'],
                    ['avmValue','cbsa', 'cj_living_area', 'census_tract'],
                    ['avmValue','cbsa', 'cj_living_area', 'census_tract', 'Transdate'],
                    ['avmValue','cbsa', 'cj_living_area', 'census_tract',
                   'AVM_Error_Indicators_0', 'AVM_Error_Indicators_1',
                   'AVM_Error_Indicators_2', 'AVM_Error_Indicators_3',
                   'AVM_Error_Indicators_4', 'AVM_Error_Indicators_5',
                   'AVM_Error_Indicators_6', 'AVM_Error_Indicators_7',
                   'AVM_Error_Indicators_8', 'AVM_Error_Indicators_9',
                   'AVM_Error_Indicators_10', 'AVM_Error_Indicators_11',
                   'AVM_Error_Indicators_scale', 'AVM_Error_Indicators_scale_inverse',
                   'Listing_Error_Indicators_0', 'Listing_Error_Indicators_1',
                   'Listing_Error_Indicators_2', 'Listing_Error_Indicators_3',
                   'Listing_Error_Indicators_4', 'Listing_Error_Indicators_5',
                   'Listing_Error_Indicators_6', 'Listing_Error_Indicators_7',
                   'Listing_Error_Indicators_8', 'Listing_Error_Indicators_9',
                   'Listing_Error_Indicators_10', 'Listing_Error_Indicators_11',
                   'AVM_Error_Indicators_0_max_value',
                   'AVM_Error_Indicators_0_min_value',
                   'AVM_Error_Indicators_0_max_indicator',
                   'AVM_Error_Indicators_0_min_indicator',
                   'AVM_Error_Indicators_0_diff_indicator',
                   'AVM_Error_Indicators_0_diff_value', 'AVM_Error_Indicators_0_mean','avmerror_mean'] +\
                    list(noun_sentence_state_train.columns[51:-1]),
                    ['avmValue','cbsa', 'cj_living_area',
                   'AVM_Error_Indicators_0', 'AVM_Error_Indicators_1',
                   'AVM_Error_Indicators_2', 'AVM_Error_Indicators_3',
                   'AVM_Error_Indicators_4', 'AVM_Error_Indicators_5',
                   'AVM_Error_Indicators_6', 'AVM_Error_Indicators_7',
                   'AVM_Error_Indicators_8', 'AVM_Error_Indicators_9',
                   'AVM_Error_Indicators_10', 'AVM_Error_Indicators_11',
                   'AVM_Error_Indicators_scale', 'AVM_Error_Indicators_scale_inverse',
                   'Listing_Error_Indicators_0', 'Listing_Error_Indicators_1',
                   'Listing_Error_Indicators_2', 'Listing_Error_Indicators_3',
                   'Listing_Error_Indicators_4', 'Listing_Error_Indicators_5',
                   'Listing_Error_Indicators_6', 'Listing_Error_Indicators_7',
                   'Listing_Error_Indicators_8', 'Listing_Error_Indicators_9',
                   'Listing_Error_Indicators_10', 'Listing_Error_Indicators_11',
                   'AVM_Error_Indicators_0_max_value',
                   'AVM_Error_Indicators_0_min_value',
                   'AVM_Error_Indicators_0_max_indicator',
                   'AVM_Error_Indicators_0_min_indicator',
                   'AVM_Error_Indicators_0_diff_indicator',
                   'AVM_Error_Indicators_0_diff_value', 'AVM_Error_Indicators_0_mean','avmerror_mean'] +\
                    list(noun_sentence_state_train.columns[51:-1]),
                   ['avmValue','cbsa', 'cj_living_area', 'Transdate', 
                   'AVM_Error_Indicators_0', 'AVM_Error_Indicators_1',
                   'AVM_Error_Indicators_2', 'AVM_Error_Indicators_3',
                   'AVM_Error_Indicators_4', 'AVM_Error_Indicators_5',
                   'AVM_Error_Indicators_6', 'AVM_Error_Indicators_7',
                   'AVM_Error_Indicators_8', 'AVM_Error_Indicators_9',
                   'AVM_Error_Indicators_10', 'AVM_Error_Indicators_11',
                   'AVM_Error_Indicators_scale', 'AVM_Error_Indicators_scale_inverse',
                   'Listing_Error_Indicators_0', 'Listing_Error_Indicators_1',
                   'Listing_Error_Indicators_2', 'Listing_Error_Indicators_3',
                   'Listing_Error_Indicators_4', 'Listing_Error_Indicators_5',
                   'Listing_Error_Indicators_6', 'Listing_Error_Indicators_7',
                   'Listing_Error_Indicators_8', 'Listing_Error_Indicators_9',
                   'Listing_Error_Indicators_10', 'Listing_Error_Indicators_11',
                   'AVM_Error_Indicators_0_max_value',
                   'AVM_Error_Indicators_0_min_value',
                   'AVM_Error_Indicators_0_max_indicator',
                   'AVM_Error_Indicators_0_min_indicator',
                   'AVM_Error_Indicators_0_diff_indicator',
                   'AVM_Error_Indicators_0_diff_value', 'AVM_Error_Indicators_0_mean','avmerror_mean'] +\
                    list(noun_sentence_state_train.columns[51:-1]),
                   ['avmValue','cbsa', 'cj_living_area', 'census_tract', 'Transdate', 
                   'AVM_Error_Indicators_0', 'AVM_Error_Indicators_1',
                   'AVM_Error_Indicators_2', 'AVM_Error_Indicators_3',
                   'AVM_Error_Indicators_4', 'AVM_Error_Indicators_5',
                   'AVM_Error_Indicators_6', 'AVM_Error_Indicators_7',
                   'AVM_Error_Indicators_8', 'AVM_Error_Indicators_9',
                   'AVM_Error_Indicators_10', 'AVM_Error_Indicators_11',
                   'AVM_Error_Indicators_scale', 'AVM_Error_Indicators_scale_inverse',
                   'Listing_Error_Indicators_0', 'Listing_Error_Indicators_1',
                   'Listing_Error_Indicators_2', 'Listing_Error_Indicators_3',
                   'Listing_Error_Indicators_4', 'Listing_Error_Indicators_5',
                   'Listing_Error_Indicators_6', 'Listing_Error_Indicators_7',
                   'Listing_Error_Indicators_8', 'Listing_Error_Indicators_9',
                   'Listing_Error_Indicators_10', 'Listing_Error_Indicators_11',
                   'AVM_Error_Indicators_0_max_value',
                   'AVM_Error_Indicators_0_min_value',
                   'AVM_Error_Indicators_0_max_indicator',
                   'AVM_Error_Indicators_0_min_indicator',
                   'AVM_Error_Indicators_0_diff_indicator',
                   'AVM_Error_Indicators_0_diff_value', 'AVM_Error_Indicators_0_mean','avmerror_mean'] +\
                    list(noun_sentence_state_train.columns[51:-1])]

# %%
all_combinations_names = ['avmValue-cbsa', 
                          'avmValue-cbsa-cj_living_area',
                          'avmValue-cbsa-cj_living_area-census_tract',
                          'avmValue-cbsa-cj_living_area-census_tract-Transdate',
                          'avmValue-cbsa-cj_living_area-census_tract-comments',
                          'avmValue-cbsa-cj_living_area-comments',
                          'avmValue-cbsa-cj_living_area-comments-Transdate',
                          'avmValue-cbsa-cj_living_area-comments-census_tract-Transdate']

# %%
list(noun_sentence_state_train.columns[51:-1])[-1]
# Out:
# 'new granite counter tops, new hardwood floors, new stainless steel appliances'

# %%
#for list_preds in all_combinations:
#    print(list(list_preds))

# %%
from lightgbm import LGBMRegressor

# %%
for idd,list_preds in enumerate(all_combinations):
    if idd>4:
        print(list(list_preds))
# Out:
# ['avmValue', 'cbsa', 'cj_living_area', 'AVM_Error_Indicators_0', 'AVM_Error_Indicators_1', 'AVM_Error_Indicators_2', 'AVM_Error_Indicators_3', 'AVM_Error_Indicators_4', 'AVM_Error_Indicators_5', 'AVM_Error_Indicators_6', 'AVM_Error_Indicators_7', 'AVM_Error_Indicators_8', 'AVM_Error_Indicators_9', 'AVM_Error_Indicators_10', 'AVM_Error_Indicators_11', 'AVM_Error_Indicators_scale', 'AVM_Error_Indicators_scale_inverse', 'Listing_Error_Indicators_0', 'Listing_Error_Indicators_1', 'Listing_Error_Indicators_2', 'Listing_Error_Indicators_3', 'Listing_Error_Indicators_4', 'Listing_Error_Indicators_5', 'Listing_Error_Indicators_6', 'Listing_Error_Indicators_7', 'Listing_Error_Indicators_8', 'Listing_Error_Indicators_9', 'Listing_Error_Indicators_10', 'Listing_Error_Indicators_11', 'AVM_Error_Indicators_0_max_value', 'AVM_Error_Indicators_0_min_value', 'AVM_Error_Indicators_0_max_indicator', 'AVM_Error_Indicators_0_min_indicator', 'AVM_Error_Indicators_0_diff_indicator', 'AVM_Error_Indicators_0_diff_value', 'AVM_Error_Indicators_0_mean', 'avmerror_mean', 'seller chooses attorney', 'omission and or', 'actual plan', 'tack room', 'utilities inspections', 'needs repairs', 'seller requests buyer use seller', 'new shaker cabinets', 'hud home', 'new white kitchen', 'great fixer', 'absolute model home ', 'perfect fixer', 'amp service', 'clean property', 'great home investors', 'cosmetic work', 'modern farmhouse', 'cash sale', 'needs work', 'excellent opportunity smart bargain hunter', 'new hall bath', 'doors drawers', 'house needs work', 'needs tender loving care', 'party approval', 'tender loving care home', 'price subdivision', 'modern renovation', 'new top bottom', 'builder spouse', 'mini farm', 'hard money', 'great opportunity savvy buyer', 'marble island', 'buyers as soon as possible', 'sweat equity', 'needs paint', 'tile accents', 'handy man', 'elbow grease', 'needs cosmetic', 'wall cabinets', 'cash buyer', 'zillow inc', 'custom vent hood', 'subject bank approval', 'sellers attorney', 'new dock', 'contemporary finishes', 'carrera marble', 'inch home', 'beverage center', 'as is condition', 'stall barn', 'price area', 'new laundry room', 'shaker style cabinets', 'property needs', 'current condition', 'perfect horses', 'chicken coop', 'needs carpet', 'top bottom renovation', 'ship lap', 'butcher block counter tops', 'home lots potential', 'new bathrooms', 'great opportunity investors', 'wolf range', 'pizza oven', 'modern finishes', 'seller requests', 'potential home', 'interior needs', 'as is sale', 'new addition', 'custom master bath', 'as is disclosure', 'custom barn doors', 'proof funds', 'full potential', 'private park', 'quality renovation', 'new vanities', 'modern ranch', 'barn door', 'custom fire pit', 'top bottom', 'accent wall', 'great bones', 'great potential', 'shiplap walls', 'lounge area', 'new finishes', 'shiplap accents', 'new systems', 'modern design', 'great investor', 'as is seller', 'quartz counters', 'vintage charm', 'designer fixtures', 'market value', 'loads potential', 'ready horses', 'farmhouse style', 'attention investors', 'cosmetic updates', '100k upgrades', 'real estate license georgia', 'comparison purposes', 'new sheetrock', 'close drawers', 'minor repairs', 'hickory floors', 'estate sale', 'ready renovation', 'monday night garage', 'outdoor shower', 'modern living', 'minor tender loving care', 'home investor', 'new quartz tops ', 'head toe', 'modern touches', 'earnest money', 'available quick move in', 'new cabinetry', 'contract instructions', 'great investment opportunity', 'amazing renovation', '30day satisfaction', 'microwave drawer', 'home needs', 'duct work', 'price neighborhood', 'master suite addition', 'designer finishes', 'new duct work', 'investors dream', 'modern features', 'updates list', 'great rental potential', 'need storage', 'home good bones', 'tons potential', 'as is sellers disclosure', 'fha va', 'slice heaven', 'market price', 'end lake lanier', 'rain shower', 'great investment property', 'p ...
# ['avmValue', 'cbsa', 'cj_living_area', 'Transdate', 'AVM_Error_Indicators_0', 'AVM_Error_Indicators_1', 'AVM_Error_Indicators_2', 'AVM_Error_Indicators_3', 'AVM_Error_Indicators_4', 'AVM_Error_Indicators_5', 'AVM_Error_Indicators_6', 'AVM_Error_Indicators_7', 'AVM_Error_Indicators_8', 'AVM_Error_Indicators_9', 'AVM_Error_Indicators_10', 'AVM_Error_Indicators_11', 'AVM_Error_Indicators_scale', 'AVM_Error_Indicators_scale_inverse', 'Listing_Error_Indicators_0', 'Listing_Error_Indicators_1', 'Listing_Error_Indicators_2', 'Listing_Error_Indicators_3', 'Listing_Error_Indicators_4', 'Listing_Error_Indicators_5', 'Listing_Error_Indicators_6', 'Listing_Error_Indicators_7', 'Listing_Error_Indicators_8', 'Listing_Error_Indicators_9', 'Listing_Error_Indicators_10', 'Listing_Error_Indicators_11', 'AVM_Error_Indicators_0_max_value', 'AVM_Error_Indicators_0_min_value', 'AVM_Error_Indicators_0_max_indicator', 'AVM_Error_Indicators_0_min_indicator', 'AVM_Error_Indicators_0_diff_indicator', 'AVM_Error_Indicators_0_diff_value', 'AVM_Error_Indicators_0_mean', 'avmerror_mean', 'seller chooses attorney', 'omission and or', 'actual plan', 'tack room', 'utilities inspections', 'needs repairs', 'seller requests buyer use seller', 'new shaker cabinets', 'hud home', 'new white kitchen', 'great fixer', 'absolute model home ', 'perfect fixer', 'amp service', 'clean property', 'great home investors', 'cosmetic work', 'modern farmhouse', 'cash sale', 'needs work', 'excellent opportunity smart bargain hunter', 'new hall bath', 'doors drawers', 'house needs work', 'needs tender loving care', 'party approval', 'tender loving care home', 'price subdivision', 'modern renovation', 'new top bottom', 'builder spouse', 'mini farm', 'hard money', 'great opportunity savvy buyer', 'marble island', 'buyers as soon as possible', 'sweat equity', 'needs paint', 'tile accents', 'handy man', 'elbow grease', 'needs cosmetic', 'wall cabinets', 'cash buyer', 'zillow inc', 'custom vent hood', 'subject bank approval', 'sellers attorney', 'new dock', 'contemporary finishes', 'carrera marble', 'inch home', 'beverage center', 'as is condition', 'stall barn', 'price area', 'new laundry room', 'shaker style cabinets', 'property needs', 'current condition', 'perfect horses', 'chicken coop', 'needs carpet', 'top bottom renovation', 'ship lap', 'butcher block counter tops', 'home lots potential', 'new bathrooms', 'great opportunity investors', 'wolf range', 'pizza oven', 'modern finishes', 'seller requests', 'potential home', 'interior needs', 'as is sale', 'new addition', 'custom master bath', 'as is disclosure', 'custom barn doors', 'proof funds', 'full potential', 'private park', 'quality renovation', 'new vanities', 'modern ranch', 'barn door', 'custom fire pit', 'top bottom', 'accent wall', 'great bones', 'great potential', 'shiplap walls', 'lounge area', 'new finishes', 'shiplap accents', 'new systems', 'modern design', 'great investor', 'as is seller', 'quartz counters', 'vintage charm', 'designer fixtures', 'market value', 'loads potential', 'ready horses', 'farmhouse style', 'attention investors', 'cosmetic updates', '100k upgrades', 'real estate license georgia', 'comparison purposes', 'new sheetrock', 'close drawers', 'minor repairs', 'hickory floors', 'estate sale', 'ready renovation', 'monday night garage', 'outdoor shower', 'modern living', 'minor tender loving care', 'home investor', 'new quartz tops ', 'head toe', 'modern touches', 'earnest money', 'available quick move in', 'new cabinetry', 'contract instructions', 'great investment opportunity', 'amazing renovation', '30day satisfaction', 'microwave drawer', 'home needs', 'duct work', 'price neighborhood', 'master suite addition', 'designer finishes', 'new duct work', 'investors dream', 'modern features', 'updates list', 'great rental potential', 'need storage', 'home good bones', 'tons potential', 'as is sellers disclosure', 'fha va', 'slice heaven', 'market price', 'end lake lanier', 'rain shower', 'great investment  ...
# ['avmValue', 'cbsa', 'cj_living_area', 'census_tract', 'Transdate', 'AVM_Error_Indicators_0', 'AVM_Error_Indicators_1', 'AVM_Error_Indicators_2', 'AVM_Error_Indicators_3', 'AVM_Error_Indicators_4', 'AVM_Error_Indicators_5', 'AVM_Error_Indicators_6', 'AVM_Error_Indicators_7', 'AVM_Error_Indicators_8', 'AVM_Error_Indicators_9', 'AVM_Error_Indicators_10', 'AVM_Error_Indicators_11', 'AVM_Error_Indicators_scale', 'AVM_Error_Indicators_scale_inverse', 'Listing_Error_Indicators_0', 'Listing_Error_Indicators_1', 'Listing_Error_Indicators_2', 'Listing_Error_Indicators_3', 'Listing_Error_Indicators_4', 'Listing_Error_Indicators_5', 'Listing_Error_Indicators_6', 'Listing_Error_Indicators_7', 'Listing_Error_Indicators_8', 'Listing_Error_Indicators_9', 'Listing_Error_Indicators_10', 'Listing_Error_Indicators_11', 'AVM_Error_Indicators_0_max_value', 'AVM_Error_Indicators_0_min_value', 'AVM_Error_Indicators_0_max_indicator', 'AVM_Error_Indicators_0_min_indicator', 'AVM_Error_Indicators_0_diff_indicator', 'AVM_Error_Indicators_0_diff_value', 'AVM_Error_Indicators_0_mean', 'avmerror_mean', 'seller chooses attorney', 'omission and or', 'actual plan', 'tack room', 'utilities inspections', 'needs repairs', 'seller requests buyer use seller', 'new shaker cabinets', 'hud home', 'new white kitchen', 'great fixer', 'absolute model home ', 'perfect fixer', 'amp service', 'clean property', 'great home investors', 'cosmetic work', 'modern farmhouse', 'cash sale', 'needs work', 'excellent opportunity smart bargain hunter', 'new hall bath', 'doors drawers', 'house needs work', 'needs tender loving care', 'party approval', 'tender loving care home', 'price subdivision', 'modern renovation', 'new top bottom', 'builder spouse', 'mini farm', 'hard money', 'great opportunity savvy buyer', 'marble island', 'buyers as soon as possible', 'sweat equity', 'needs paint', 'tile accents', 'handy man', 'elbow grease', 'needs cosmetic', 'wall cabinets', 'cash buyer', 'zillow inc', 'custom vent hood', 'subject bank approval', 'sellers attorney', 'new dock', 'contemporary finishes', 'carrera marble', 'inch home', 'beverage center', 'as is condition', 'stall barn', 'price area', 'new laundry room', 'shaker style cabinets', 'property needs', 'current condition', 'perfect horses', 'chicken coop', 'needs carpet', 'top bottom renovation', 'ship lap', 'butcher block counter tops', 'home lots potential', 'new bathrooms', 'great opportunity investors', 'wolf range', 'pizza oven', 'modern finishes', 'seller requests', 'potential home', 'interior needs', 'as is sale', 'new addition', 'custom master bath', 'as is disclosure', 'custom barn doors', 'proof funds', 'full potential', 'private park', 'quality renovation', 'new vanities', 'modern ranch', 'barn door', 'custom fire pit', 'top bottom', 'accent wall', 'great bones', 'great potential', 'shiplap walls', 'lounge area', 'new finishes', 'shiplap accents', 'new systems', 'modern design', 'great investor', 'as is seller', 'quartz counters', 'vintage charm', 'designer fixtures', 'market value', 'loads potential', 'ready horses', 'farmhouse style', 'attention investors', 'cosmetic updates', '100k upgrades', 'real estate license georgia', 'comparison purposes', 'new sheetrock', 'close drawers', 'minor repairs', 'hickory floors', 'estate sale', 'ready renovation', 'monday night garage', 'outdoor shower', 'modern living', 'minor tender loving care', 'home investor', 'new quartz tops ', 'head toe', 'modern touches', 'earnest money', 'available quick move in', 'new cabinetry', 'contract instructions', 'great investment opportunity', 'amazing renovation', '30day satisfaction', 'microwave drawer', 'home needs', 'duct work', 'price neighborhood', 'master suite addition', 'designer finishes', 'new duct work', 'investors dream', 'modern features', 'updates list', 'great rental potential', 'need storage', 'home good bones', 'tons potential', 'as is sellers disclosure', 'fha va', 'slice heaven', 'market price', 'end lake lanier', 'rain shower', 'g ...

# %%
for idd,list_preds in enumerate(all_combinations):
    if idd>=0:
        print(list(list_preds))

        selcted_columns = list_preds
        symptoms_df = noun_sentence_state_train.loc[:,selcted_columns]
        symptoms_df_test = noun_sentence_state_test.loc[:,selcted_columns]

        Predictors = symptoms_df.to_numpy()
        X_test = symptoms_df_test.to_numpy()
        X_train = Predictors

        y_train_regressor = noun_sentence_state_train.avmerror.values
        y_test_regressor = noun_sentence_state_test.avmerror.values

        model_regressor = LGBMRegressor(max_depth = 10, n_estimators = 150, num_leaves = 700, colsample_bytree=0.4) 
        model_regressor.fit(X_train, y_train_regressor)

        predictions_train_Regressor = model_regressor.predict(X_train)
        predictions_test_Regressor = model_regressor.predict(X_test)


        avmValue_test = noun_sentence_state_test['avmValue']
        avmValue_train = noun_sentence_state_train['avmValue']

        transprice_test = noun_sentence_state_test['Transprice']
        transprice_train = noun_sentence_state_train['Transprice']

        predictions_test_valueR = avmValue_test/(1-predictions_test_Regressor)
        predictions_train_valueR = avmValue_train/(1-predictions_train_Regressor)


        print('') 
        print('Testing')
        print(np.mean(np.abs(transprice_test-predictions_test_valueR)/\
                  (transprice_test)))
        print(np.mean(np.abs(transprice_test - avmValue_test)/\
                      (transprice_test)))

        print('') 
        print('Training') 
        print(np.mean(np.abs(transprice_train-predictions_train_valueR)/\
                  (transprice_train)))
        print(np.mean(np.abs(transprice_train - avmValue_train)/\
                      (transprice_train)))   

        import joblib
        filename = 'LGBM_regressor_additive_'+state+'_'+str(idd)+'.sav'
        joblib.dump(model_regressor,filename)
        print(' ')
# Out:
# ['avmValue', 'cbsa']
#
# Testing
# 0.12134246437769816
# 0.12229332212976805
#
# Training
# 0.12098626641249688
# 0.1231317624967694
#
# ['avmValue', 'cbsa', 'cj_living_area']
#
# Testing
# 0.1214740694849983
# 0.12229332212976805
#
# Training
# 0.11844139986129625
# 0.1231317624967694
#
# ['avmValue', 'cbsa', 'cj_living_area', 'census_tract']
#
# Testing
# 0.12167450718255876
# 0.12229332212976805
#
# Training
# 0.11690579825239045
# 0.1231317624967694
#
# ['avmValue', 'cbsa', 'cj_living_area', 'census_tract', 'Transdate']
#
# Testing
# 0.11807198514082021
# 0.12229332212976805
#
# Training
# 0.10989735928369528
# 0.1231317624967694
#
# ['avmValue', 'cbsa', 'cj_living_area', 'census_tract', 'AVM_Error_Indicators_0', 'AVM_Error_Indicators_1', 'AVM_Error_Indicators_2', 'AVM_Error_Indicators_3', 'AVM_Error_Indicators_4', 'AVM_Error_Indicators_5', 'AVM_Error_Indicators_6', 'AVM_Error_Indicators_7', 'AVM_Error_Indicators_8', 'AVM_Error_Indicators_9', 'AVM_Error_Indicators_10', 'AVM_Error_Indicators_11', 'AVM_Error_Indicators_scale', 'AVM_Error_Indicators_scale_inverse', 'Listing_Error_Indicators_0', 'Listing_Error_Indicators_1', 'Listing_Error_Indicators_2', 'Listing_Error_Indicators_3', 'Listing_Error_Indicators_4', 'Listing_Error_Indicators_5', 'Listing_Error_Indicators_6', 'Listing_Error_Indicators_7', 'Listing_Error_Indicators_8', 'Listing_Error_Indicators_9', 'Listing_Error_Indicators_10', 'Listing_Error_Indicators_11', 'AVM_Error_Indicators_0_max_value', 'AVM_Error_Indicators_0_min_value', 'AVM_Error_Indicators_0_max_indicator', 'AVM_Error_Indicators_0_min_indicator', 'AVM_Error_Indicators_0_diff_indicator', 'AVM_Error_Indicators_0_diff_value', 'AVM_Error_Indicators_0_mean', 'avmerror_mean', 'seller chooses attorney', 'omission and or', 'actual plan', 'tack room', 'utilities inspections', 'needs repairs', 'seller requests buyer use seller', 'new shaker cabinets', 'hud home', 'new white kitchen', 'great fixer', 'absolute model home ', 'perfect fixer', 'amp service', 'clean property', 'great home investors', 'cosmetic work', 'modern farmhouse', 'cash sale', 'needs work', 'excellent opportunity smart bargain hunter', 'new hall bath', 'doors drawers', 'house needs work', 'needs tender loving care', 'party approval', 'tender loving care home', 'price subdivision', 'modern renovation', 'new top bottom', 'builder spouse', 'mini farm', 'hard money', 'great opportunity savvy buyer', 'marble island', 'buyers as soon as possible', 'sweat equity', 'needs paint', 'tile accents', 'handy man', 'elbow grease', 'needs cosmetic', 'wall cabinets', 'cash buyer', 'zillow inc', 'custom vent hood', 'subject bank approval', 'sellers attorney', 'new dock', 'contemporary finishes', 'carrera marble', 'inch home', 'beverage center', 'as is condition', 'stall barn', 'price area', 'new laundry room', 'shaker style cabinets', 'property needs', 'current condition', 'perfect horses', 'chicken coop', 'needs carpet', 'top bottom renovation', 'ship lap', 'butcher block counter tops', 'home lots potential', 'new bathrooms', 'great opportunity investors', 'wolf range', 'pizza oven', 'modern finishes', 'seller requests', 'potential home', 'interior needs', 'as is sale', 'new addition', 'custom master bath', 'as is disclosure', 'custom barn doors', 'proof funds', 'full potential', 'private park', 'quality renovation', 'new vanities', 'modern ranch', 'barn door', 'custom fire pit', 'top bottom', 'accent wall', 'great bones', 'great potential', 'shiplap walls', 'lounge area', 'new finishes', 'shiplap accents', 'new systems', 'modern design', 'great investor', 'as is seller', 'quartz counters', 'vintage charm', 'designer fixtures', 'market value', 'loads potential', 'ready horses', 'farmhouse style', 'attention investors', 'cosmetic updates', '100k upgrades', 'real estate license georgia', 'comparison purposes', 'new sheetrock', 'close drawers', 'minor repairs', 'hickory floors', 'estate sale', 'ready renovation', 'monday night garage', 'outdoor shower', 'modern living', 'minor tender loving care', 'home investor', 'new quartz tops ', 'head toe', 'modern touches', 'earnest money', 'available quick move in', 'new cabinetry', 'contract instructions', 'great investment opportunity', 'amazing renovation', '30day satisfaction', 'microwave drawer', 'home needs', 'duct work', 'price neighborhood', 'master suite addition', 'designer finishes', 'new duct work', 'investors dream', 'modern features', 'updates list', 'great rental potential', 'need storage', 'home good bones', 'tons potential', 'as is sellers disclosure', 'fha va', 'slice heaven', 'market price', 'end lake lanier', 'rain shower', 'great investme ...
# Testing
# 0.10816138149425895
# 0.12229332212976805
#
# Training
# 0.09473224030396642
# 0.1231317624967694
#
# ['avmValue', 'cbsa', 'cj_living_area', 'AVM_Error_Indicators_0', 'AVM_Error_Indicators_1', 'AVM_Error_Indicators_2', 'AVM_Error_Indicators_3', 'AVM_Error_Indicators_4', 'AVM_Error_Indicators_5', 'AVM_Error_Indicators_6', 'AVM_Error_Indicators_7', 'AVM_Error_Indicators_8', 'AVM_Error_Indicators_9', 'AVM_Error_Indicators_10', 'AVM_Error_Indicators_11', 'AVM_Error_Indicators_scale', 'AVM_Error_Indicators_scale_inverse', 'Listing_Error_Indicators_0', 'Listing_Error_Indicators_1', 'Listing_Error_Indicators_2', 'Listing_Error_Indicators_3', 'Listing_Error_Indicators_4', 'Listing_Error_Indicators_5', 'Listing_Error_Indicators_6', 'Listing_Error_Indicators_7', 'Listing_Error_Indicators_8', 'Listing_Error_Indicators_9', 'Listing_Error_Indicators_10', 'Listing_Error_Indicators_11', 'AVM_Error_Indicators_0_max_value', 'AVM_Error_Indicators_0_min_value', 'AVM_Error_Indicators_0_max_indicator', 'AVM_Error_Indicators_0_min_indicator', 'AVM_Error_Indicators_0_diff_indicator', 'AVM_Error_Indicators_0_diff_value', 'AVM_Error_Indicators_0_mean', 'avmerror_mean', 'seller chooses attorney', 'omission and or', 'actual plan', 'tack room', 'utilities inspections', 'needs repairs', 'seller requests buyer use seller', 'new shaker cabinets', 'hud home', 'new white kitchen', 'great fixer', 'absolute model home ', 'perfect fixer', 'amp service', 'clean property', 'great home investors', 'cosmetic work', 'modern farmhouse', 'cash sale', 'needs work', 'excellent opportunity smart bargain hunter', 'new hall bath', 'doors drawers', 'house needs work', 'needs tender loving care', 'party approval', 'tender loving care home', 'price subdivision', 'modern renovation', 'new top bottom', 'builder spouse', 'mini farm', 'hard money', 'great opportunity savvy buyer', 'marble island', 'buyers as soon as possible', 'sweat equity', 'needs paint', 'tile accents', 'handy man', 'elbow grease', 'needs cosmetic', 'wall cabinets', 'cash buyer', 'zillow inc', 'custom vent hood', 'subject bank approval', 'sellers attorney', 'new dock', 'contemporary finishes', 'carrera marble', 'inch home', 'beverage center', 'as is condition', 'stall barn', 'price area', 'new laundry room', 'shaker style cabinets', 'property needs', 'current condition', 'perfect horses', 'chicken coop', 'needs carpet', 'top bottom renovation', 'ship lap', 'butcher block counter tops', 'home lots potential', 'new bathrooms', 'great opportunity investors', 'wolf range', 'pizza oven', 'modern finishes', 'seller requests', 'potential home', 'interior needs', 'as is sale', 'new addition', 'custom master bath', 'as is disclosure', 'custom barn doors', 'proof funds', 'full potential', 'private park', 'quality renovation', 'new vanities', 'modern ranch', 'barn door', 'custom fire pit', 'top bottom', 'accent wall', 'great bones', 'great potential', 'shiplap walls', 'lounge area', 'new finishes', 'shiplap accents', 'new systems', 'modern design', 'great investor', 'as is seller', 'quartz counters', 'vintage charm', 'designer fixtures', 'market value', 'loads potential', 'ready horses', 'farmhouse style', 'attention investors', 'cosmetic updates', '100k upgrades', 'real estate license georgia', 'comparison purposes', 'new sheetrock', 'close drawers', 'minor repairs', 'hickory floors', 'estate sale', 'ready renovation', 'monday night garage', 'outdoor shower', 'modern living', 'minor tender loving care', 'home investor', 'new quartz tops ', 'head toe', 'modern touches', 'earnest money', 'available quick move in', 'new cabinetry', 'contract instructions', 'great investment opportunity', 'amazing renovation', '30day satisfaction', 'microwave drawer', 'home needs', 'duct work', 'price neighborhood', 'master suite addition', 'designer finishes', 'new duct work', 'investors dream', 'modern features', 'updates list', 'great rental potential', 'need storage', 'home good bones', 'tons potential', 'as is sellers disclosure', 'fha va', 'slice heaven', 'market price', 'end lake lanier', 'rain shower', 'great investment property', 'p ...
# Testing
# 0.10972554971392609
# 0.12229332212976805
#
# Training
# 0.09780436560352783
# 0.1231317624967694
#
# ['avmValue', 'cbsa', 'cj_living_area', 'Transdate', 'AVM_Error_Indicators_0', 'AVM_Error_Indicators_1', 'AVM_Error_Indicators_2', 'AVM_Error_Indicators_3', 'AVM_Error_Indicators_4', 'AVM_Error_Indicators_5', 'AVM_Error_Indicators_6', 'AVM_Error_Indicators_7', 'AVM_Error_Indicators_8', 'AVM_Error_Indicators_9', 'AVM_Error_Indicators_10', 'AVM_Error_Indicators_11', 'AVM_Error_Indicators_scale', 'AVM_Error_Indicators_scale_inverse', 'Listing_Error_Indicators_0', 'Listing_Error_Indicators_1', 'Listing_Error_Indicators_2', 'Listing_Error_Indicators_3', 'Listing_Error_Indicators_4', 'Listing_Error_Indicators_5', 'Listing_Error_Indicators_6', 'Listing_Error_Indicators_7', 'Listing_Error_Indicators_8', 'Listing_Error_Indicators_9', 'Listing_Error_Indicators_10', 'Listing_Error_Indicators_11', 'AVM_Error_Indicators_0_max_value', 'AVM_Error_Indicators_0_min_value', 'AVM_Error_Indicators_0_max_indicator', 'AVM_Error_Indicators_0_min_indicator', 'AVM_Error_Indicators_0_diff_indicator', 'AVM_Error_Indicators_0_diff_value', 'AVM_Error_Indicators_0_mean', 'avmerror_mean', 'seller chooses attorney', 'omission and or', 'actual plan', 'tack room', 'utilities inspections', 'needs repairs', 'seller requests buyer use seller', 'new shaker cabinets', 'hud home', 'new white kitchen', 'great fixer', 'absolute model home ', 'perfect fixer', 'amp service', 'clean property', 'great home investors', 'cosmetic work', 'modern farmhouse', 'cash sale', 'needs work', 'excellent opportunity smart bargain hunter', 'new hall bath', 'doors drawers', 'house needs work', 'needs tender loving care', 'party approval', 'tender loving care home', 'price subdivision', 'modern renovation', 'new top bottom', 'builder spouse', 'mini farm', 'hard money', 'great opportunity savvy buyer', 'marble island', 'buyers as soon as possible', 'sweat equity', 'needs paint', 'tile accents', 'handy man', 'elbow grease', 'needs cosmetic', 'wall cabinets', 'cash buyer', 'zillow inc', 'custom vent hood', 'subject bank approval', 'sellers attorney', 'new dock', 'contemporary finishes', 'carrera marble', 'inch home', 'beverage center', 'as is condition', 'stall barn', 'price area', 'new laundry room', 'shaker style cabinets', 'property needs', 'current condition', 'perfect horses', 'chicken coop', 'needs carpet', 'top bottom renovation', 'ship lap', 'butcher block counter tops', 'home lots potential', 'new bathrooms', 'great opportunity investors', 'wolf range', 'pizza oven', 'modern finishes', 'seller requests', 'potential home', 'interior needs', 'as is sale', 'new addition', 'custom master bath', 'as is disclosure', 'custom barn doors', 'proof funds', 'full potential', 'private park', 'quality renovation', 'new vanities', 'modern ranch', 'barn door', 'custom fire pit', 'top bottom', 'accent wall', 'great bones', 'great potential', 'shiplap walls', 'lounge area', 'new finishes', 'shiplap accents', 'new systems', 'modern design', 'great investor', 'as is seller', 'quartz counters', 'vintage charm', 'designer fixtures', 'market value', 'loads potential', 'ready horses', 'farmhouse style', 'attention investors', 'cosmetic updates', '100k upgrades', 'real estate license georgia', 'comparison purposes', 'new sheetrock', 'close drawers', 'minor repairs', 'hickory floors', 'estate sale', 'ready renovation', 'monday night garage', 'outdoor shower', 'modern living', 'minor tender loving care', 'home investor', 'new quartz tops ', 'head toe', 'modern touches', 'earnest money', 'available quick move in', 'new cabinetry', 'contract instructions', 'great investment opportunity', 'amazing renovation', '30day satisfaction', 'microwave drawer', 'home needs', 'duct work', 'price neighborhood', 'master suite addition', 'designer finishes', 'new duct work', 'investors dream', 'modern features', 'updates list', 'great rental potential', 'need storage', 'home good bones', 'tons potential', 'as is sellers disclosure', 'fha va', 'slice heaven', 'market price', 'end lake lanier', 'rain shower', 'great investment  ...
# Testing
# 0.10883877168978806
# 0.12229332212976805
#
# Training
# 0.09709510086366872
# 0.1231317624967694
#
# ['avmValue', 'cbsa', 'cj_living_area', 'census_tract', 'Transdate', 'AVM_Error_Indicators_0', 'AVM_Error_Indicators_1', 'AVM_Error_Indicators_2', 'AVM_Error_Indicators_3', 'AVM_Error_Indicators_4', 'AVM_Error_Indicators_5', 'AVM_Error_Indicators_6', 'AVM_Error_Indicators_7', 'AVM_Error_Indicators_8', 'AVM_Error_Indicators_9', 'AVM_Error_Indicators_10', 'AVM_Error_Indicators_11', 'AVM_Error_Indicators_scale', 'AVM_Error_Indicators_scale_inverse', 'Listing_Error_Indicators_0', 'Listing_Error_Indicators_1', 'Listing_Error_Indicators_2', 'Listing_Error_Indicators_3', 'Listing_Error_Indicators_4', 'Listing_Error_Indicators_5', 'Listing_Error_Indicators_6', 'Listing_Error_Indicators_7', 'Listing_Error_Indicators_8', 'Listing_Error_Indicators_9', 'Listing_Error_Indicators_10', 'Listing_Error_Indicators_11', 'AVM_Error_Indicators_0_max_value', 'AVM_Error_Indicators_0_min_value', 'AVM_Error_Indicators_0_max_indicator', 'AVM_Error_Indicators_0_min_indicator', 'AVM_Error_Indicators_0_diff_indicator', 'AVM_Error_Indicators_0_diff_value', 'AVM_Error_Indicators_0_mean', 'avmerror_mean', 'seller chooses attorney', 'omission and or', 'actual plan', 'tack room', 'utilities inspections', 'needs repairs', 'seller requests buyer use seller', 'new shaker cabinets', 'hud home', 'new white kitchen', 'great fixer', 'absolute model home ', 'perfect fixer', 'amp service', 'clean property', 'great home investors', 'cosmetic work', 'modern farmhouse', 'cash sale', 'needs work', 'excellent opportunity smart bargain hunter', 'new hall bath', 'doors drawers', 'house needs work', 'needs tender loving care', 'party approval', 'tender loving care home', 'price subdivision', 'modern renovation', 'new top bottom', 'builder spouse', 'mini farm', 'hard money', 'great opportunity savvy buyer', 'marble island', 'buyers as soon as possible', 'sweat equity', 'needs paint', 'tile accents', 'handy man', 'elbow grease', 'needs cosmetic', 'wall cabinets', 'cash buyer', 'zillow inc', 'custom vent hood', 'subject bank approval', 'sellers attorney', 'new dock', 'contemporary finishes', 'carrera marble', 'inch home', 'beverage center', 'as is condition', 'stall barn', 'price area', 'new laundry room', 'shaker style cabinets', 'property needs', 'current condition', 'perfect horses', 'chicken coop', 'needs carpet', 'top bottom renovation', 'ship lap', 'butcher block counter tops', 'home lots potential', 'new bathrooms', 'great opportunity investors', 'wolf range', 'pizza oven', 'modern finishes', 'seller requests', 'potential home', 'interior needs', 'as is sale', 'new addition', 'custom master bath', 'as is disclosure', 'custom barn doors', 'proof funds', 'full potential', 'private park', 'quality renovation', 'new vanities', 'modern ranch', 'barn door', 'custom fire pit', 'top bottom', 'accent wall', 'great bones', 'great potential', 'shiplap walls', 'lounge area', 'new finishes', 'shiplap accents', 'new systems', 'modern design', 'great investor', 'as is seller', 'quartz counters', 'vintage charm', 'designer fixtures', 'market value', 'loads potential', 'ready horses', 'farmhouse style', 'attention investors', 'cosmetic updates', '100k upgrades', 'real estate license georgia', 'comparison purposes', 'new sheetrock', 'close drawers', 'minor repairs', 'hickory floors', 'estate sale', 'ready renovation', 'monday night garage', 'outdoor shower', 'modern living', 'minor tender loving care', 'home investor', 'new quartz tops ', 'head toe', 'modern touches', 'earnest money', 'available quick move in', 'new cabinetry', 'contract instructions', 'great investment opportunity', 'amazing renovation', '30day satisfaction', 'microwave drawer', 'home needs', 'duct work', 'price neighborhood', 'master suite addition', 'designer finishes', 'new duct work', 'investors dream', 'modern features', 'updates list', 'great rental potential', 'need storage', 'home good bones', 'tons potential', 'as is sellers disclosure', 'fha va', 'slice heaven', 'market price', 'end lake lanier', 'rain shower', 'g ...
# Testing
# 0.10680183268702594
# 0.12229332212976805
#
# Training
# 0.0930551278264114
# 0.1231317624967694

# %%
for idd,list_preds in enumerate(all_combinations):
    print(list(list_preds))
    
    selcted_columns = list_preds
    symptoms_df = noun_sentence_state_train.loc[:,selcted_columns]
    symptoms_df_test = noun_sentence_state_test.loc[:,selcted_columns]
    
    Predictors = symptoms_df.to_numpy()
    X_test = symptoms_df_test.to_numpy()
    X_train = Predictors
    predictand = noun_sentence_state_train.category_predictand.values
    y_train = predictand
    y_test = noun_sentence_state_test.category_predictand.values
    
    y_train_regressor = noun_sentence_state_train.Transprice.values
    
    model_regressor = LGBMRegressor(max_depth = 10, n_estimators = 150, num_leaves = 700, colsample_bytree=0.4) 

    model_regressor.fit(X_train, y_train_regressor)
    
    predictions_train_valueR = model_regressor.predict(X_train)
    predictions_test_valueR = model_regressor.predict(X_test)
    
    y_test_regressor = noun_sentence_state_test.Transprice.values
    
    avmValue_test = noun_sentence_state_test['avmValue']
    avmValue_train = noun_sentence_state_train['avmValue']

    transprice_test = noun_sentence_state_test['Transprice']
    transprice_train = noun_sentence_state_train['Transprice']
   
    
    print('') 
    print('Testing')
    print(np.mean(np.abs(transprice_test-predictions_test_valueR)/\
              (transprice_test)))
    print(np.mean(np.abs(transprice_test - avmValue_test)/\
                  (transprice_test)))

    print('') 
    print('Training') 
    print(np.mean(np.abs(transprice_train-predictions_train_valueR)/\
              (transprice_train)))
    print(np.mean(np.abs(transprice_train - avmValue_train)/\
                  (transprice_train)))   
    
    import joblib
    filename = 'LGBM_regressor_additive_'+state+'_'+str(idd)+'_Transprice.sav'
    joblib.dump(model_regressor,filename)
    print(' ')

# %%
for idd,list_preds in enumerate(all_combinations):
    print(list(list_preds))

    selcted_columns = list(list_preds) + ['ListingPrice'] 
    symptoms_df = noun_sentence_state_train.loc[:,selcted_columns]
    symptoms_df_test = noun_sentence_state_test.loc[:,selcted_columns]
    
    Predictors = symptoms_df.to_numpy()
    X_test = symptoms_df_test.to_numpy()
    X_train = Predictors
    predictand = noun_sentence_state_train.category_predictand.values
    y_train = predictand
    y_test = noun_sentence_state_test.category_predictand.values
    
    y_train_regressor = noun_sentence_state_train.avmerror.values
    
    model_regressor = LGBMRegressor(max_depth = 10, n_estimators = 150, num_leaves = 700, colsample_bytree=0.4) 

    model_regressor.fit(X_train, y_train_regressor)
    
    predictions_train_Regressor = model_regressor.predict(X_train)
    predictions_test_Regressor = model_regressor.predict(X_test)
    
    y_test_regressor = noun_sentence_state_test.avmerror.values
    
    avmValue_test = noun_sentence_state_test['avmValue']
    avmValue_train = noun_sentence_state_train['avmValue']

    transprice_test = noun_sentence_state_test['Transprice']
    transprice_train = noun_sentence_state_train['Transprice']

    predictions_test_valueR = avmValue_test/(1-predictions_test_Regressor)
    predictions_train_valueR = avmValue_train/(1-predictions_train_Regressor)
    
    
    print('') 
    print('Testing')
    print(np.mean(np.abs(transprice_test-predictions_test_valueR)/\
              (transprice_test)))
    print(np.mean(np.abs(transprice_test - avmValue_test)/\
                  (transprice_test)))

    print('') 
    print('Training') 
    print(np.mean(np.abs(transprice_train-predictions_train_valueR)/\
              (transprice_train)))
    print(np.mean(np.abs(transprice_train - avmValue_train)/\
                  (transprice_train)))   
    
    import joblib
    filename = 'LGBM_regressor_NOCOMMENTS_with_listing'+state+'_'+str(idd)+'.sav'
    joblib.dump(model_regressor,filename)

# %%
for idd,list_preds in enumerate(all_combinations):
    print(list(list_preds))

    selcted_columns = list(list_preds) + ['avmerror_mean'] 
    symptoms_df = noun_sentence_state_train.loc[:,selcted_columns]
    symptoms_df_test = noun_sentence_state_test.loc[:,selcted_columns]
    
    Predictors = symptoms_df.to_numpy()
    X_test = symptoms_df_test.to_numpy()
    X_train = Predictors
    predictand = noun_sentence_state_train.category_predictand.values
    y_train = predictand
    y_test = noun_sentence_state_test.category_predictand.values
    
    y_train_regressor = noun_sentence_state_train.avmerror.values
    
    model_regressor = LGBMRegressor(max_depth = 10, n_estimators = 150, num_leaves = 700, colsample_bytree=0.4) 

    model_regressor.fit(X_train, y_train_regressor)
    
    predictions_train_Regressor = model_regressor.predict(X_train)
    predictions_test_Regressor = model_regressor.predict(X_test)
    
    y_test_regressor = noun_sentence_state_test.avmerror.values
    
    avmValue_test = noun_sentence_state_test['avmValue']
    avmValue_train = noun_sentence_state_train['avmValue']

    transprice_test = noun_sentence_state_test['Transprice']
    transprice_train = noun_sentence_state_train['Transprice']

    predictions_test_valueR = avmValue_test/(1-predictions_test_Regressor)
    predictions_train_valueR = avmValue_train/(1-predictions_train_Regressor)
    
    
    print('') 
    print('Testing')
    print(np.mean(np.abs(transprice_test-predictions_test_valueR)/\
              (transprice_test)))
    print(np.mean(np.abs(transprice_test - avmValue_test)/\
                  (transprice_test)))

    print('') 
    print('Training') 
    print(np.mean(np.abs(transprice_train-predictions_train_valueR)/\
              (transprice_train)))
    print(np.mean(np.abs(transprice_train - avmValue_train)/\
                  (transprice_train)))   
    
    import joblib
    filename = 'LGBM_regressor_NOCOMMENTS_with_avmerror_mean'+state+'_'+str(idd)+'.sav'
    joblib.dump(model_regressor,filename)

# %%
from matplotlib import colors
plt.hist2d(predictions_train_Regressor, y_train_regressor, bins=10, cmap = "RdYlGn_r",
           norm = colors.LogNorm())
plt.plot(y_train_regressor,y_train_regressor)

# %%
plt.hist2d(predictions_test_Regressor, y_test_regressor, bins=10, cmap = "RdYlGn_r",
           norm = colors.LogNorm())
plt.plot(y_test_regressor,y_test_regressor)

# %%
print('') 
fig = plt.figure()
plt.plot(predictions_test_valueR, 
     transprice_test,'o')
plt.plot(predictions_test_valueR,predictions_test_valueR)

# %%
len(noun_sentence_state_train)

# %%
len(symptoms_df)

# %%
symptoms_df['ListingPrice'] = noun_sentence_state_train['ListingPrice']
symptoms_df_test['ListingPrice'] = noun_sentence_state_test['ListingPrice']

# %%
symptoms_df['AVM-LISTING'] = symptoms_df['avmValue']-symptoms_df['ListingPrice']
symptoms_df_test['AVM-LISTING'] = symptoms_df_test['avmValue']-symptoms_df_test['ListingPrice']

# %%
X_test_trial3 = symptoms_df_test[trial_columns+['ListingPrice','AVM-LISTING']].to_numpy()
X_train_trial3 = symptoms_df[trial_columns+['ListingPrice','AVM-LISTING']].to_numpy()
y_train_trial3 = noun_sentence_state_train.category_predictand.values
y_test_trial3 = noun_sentence_state_test.category_predictand.values
y_train_trial_regressor3 = noun_sentence_state_train.avmerror.values
y_test_trial_regressor3 = noun_sentence_state_test.avmerror.values

# %%
model_regressor_trial3 = LGBMRegressor(max_depth = 7, n_estimators = 500, num_leaves = 100, colsample_bytree=0.6)

# %%
model_regressor_trial3.fit(X_train_trial3, y_train_trial_regressor3)

# %%
predictions_train_Regressor_trial3 = model_regressor_trial3.predict(X_train_trial3)

# %%
predictions_test_Regressor_trial3 = model_regressor_trial3.predict(X_test_trial3)

# %%
predictions_test_valueR_trail3 = avmValue_test/(1-predictions_test_Regressor_trial3)
predictions_train_valueR_trail3 = avmValue_train/(1-predictions_train_Regressor_trial3)

# %%
listingprice_test = noun_sentence_state_test['ListingPrice']
listingprice_train = noun_sentence_state_train['ListingPrice']

# %%
print('') 
print('Testing')
print(np.mean(np.abs(transprice_test-predictions_test_valueR_trail3)/\
          (transprice_test)))
print(np.mean(np.abs(transprice_test - avmValue_test)/\
              (transprice_test)))
print(np.mean(np.abs(transprice_test - listingprice_test)/\
              (transprice_test)))

print('') 
print('Training') 
print(np.mean(np.abs(transprice_train-predictions_train_valueR_trail3)/\
          (transprice_train)))
print(np.mean(np.abs(transprice_train - avmValue_train)/\
              (transprice_train)))  
print(np.mean(np.abs(transprice_train - listingprice_train)/\
              (transprice_train)))

# %% [markdown]
# ## DATA FOR THU

# %%
noun_sentence_state_test['Train/Test'] = 'Test'
noun_sentence_state_train['Train/Test'] = 'Train'

# %%
predictions_test_valueR

# %%
noun_sentence_state_test['avmvalue_modified02'] = predictions_test_valueR
noun_sentence_state_train['avmvalue_modified02'] = predictions_train_valueR

# %%
noun_sentence_state_test['avmvalue_modified01'] = predictions_test_valueR_trail
noun_sentence_state_train['avmvalue_modified01'] = predictions_train_valueR_trail

# %%
noun_sentence_state_test['avmvalue_withListingPrice'] = predictions_test_valueR_trail3
noun_sentence_state_train['avmvalue_withListingPrice'] = predictions_train_valueR_trail3

# %%
noun_sentence_state_full = noun_sentence_state_train.copy(deep=True)

# %%
noun_sentence_state_full = noun_sentence_state_full.append(noun_sentence_state_test)

# %%
len(noun_sentence_state_full)

# %%
noun_sentence_state_full = noun_sentence_state_full.sort_values('Transdate')

# %%
noun_sentence_state_full.columns[:17]

# %%
df_Thu = noun_sentence_state_full[['listingid', 'qtr', 'cbsa_div', 'cbsa', 'state', 'Transdate',
       'Transprice', 'cj_living_area', 'fips_code', 'census_tract', 'zip',
       'ListingPrice', 'avmValue', 'avmerror','Train/Test','avmvalue_modified01','avmvalue_modified02',
                         'avmvalue_withListingPrice']]

# %%
file_symptoms = 'comments/raw_comments/agent_comments_'+state+\
                        '_for_Thu_01.fea'
df_Thu.reset_index().to_feather(file_symptoms)

# %%
file_symptoms = 'comments/raw_comments/agent_comments_'+state+\
                        '_for_Thu_01.csv'
df_Thu.reset_index().to_csv(file_symptoms)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
import seaborn as sns
sns.set_style("whitegrid")

# %%
str_state = 'GA'
file = 'agent_comments_sales_'+str_state

# %%
df_sales_predictors = pd.read_feather(file + '_model03.fea') 
df_Predictand = pd.read_feather(file + '_predictand.fea')

# %%
predictor_array = df_sales_predictors.to_numpy()
transform_predictors = MinMaxScaler(feature_range=(-1, 1)).fit(predictor_array)
predictor_array_transformed = transform_predictors.transform(predictor_array)
#predictor_array_transformed2 = transform_predictors.transform(predictor_array)
#predictor_array_transformed = predictor_array

# %%
Predictand = df_Predictand['Transprice'].values

# %%
predictor_array_transformed.shape
# Out:
# (534378, 107)

# %%
plt.plot(Predictand)

# %%
transform_predictand = MinMaxScaler(feature_range=(-1, 1)).fit(Predictand.reshape(-1, 1))
Predictand_transformed = transform_predictand.transform(Predictand.reshape(-1, 1))

# %%
train_samples = 100000  # Samples used for training the models
X_train, X_test, y_train, y_test = train_test_split(
    predictor_array_transformed,
    Predictand_transformed,
    shuffle=False,
    test_size=len(Predictand_transformed) - train_samples,
)

# %%
plt.plot(y_train)

# %%
X_train.shape
# Out:
# (100000, 107)

# %%
plt.plot(X_train[:,106])

# %%
plt.plot(X_train[:,106],y_train,'o')
plt.plot(y_train,y_train)

# %%
plt.plot(X_test[:,106],y_test,'o')
plt.plot(y_test,y_test)

# %%
#model = RandomForestRegressor(n_estimators = 20,  min_samples_leaf=2)
model = RandomForestRegressor(n_estimators = 80,  min_samples_leaf=5)

# %%
X_train.shape
# Out:
# (100000, 107)

# %%
model.fit(X_train, y_train.reshape(len(y_train)))
# Out:
# RandomForestRegressor(min_samples_leaf=5, n_estimators=80)

# %%
predictions = model.predict(X_train)

# %%
plt.plot(predictions.reshape(len(y_train)), y_train.reshape(len(y_train)),'o')
#plt.plot(y_train.reshape(len(y_train)), y_train.reshape(len(y_train)))

# %%
predictions_test = model.predict(X_test)

# %%
plt.plot(predictions_test.reshape(len(y_test)), y_test.reshape(len(y_test)),'o')
#plt.plot(y_train.reshape(len(y_train)), y_train.reshape(len(y_train)))
plt.plot(X_test[:,106],y_test,'o')
plt.plot(y_test,y_test)

# %%
plt.plot(transform_predictand.inverse_transform(predictions_test.reshape([-1,1])), 
         transform_predictand.inverse_transform(y_test),'o')

plt.plot(transform_predictors.inverse_transform(X_test)[:,-1], 
         transform_predictand.inverse_transform(y_test),'o')

plt.plot(transform_predictand.inverse_transform(y_test),transform_predictand.inverse_transform(y_test))

# %%
# Create model
model = RandomForestRegressor()
model.fit(X_train, y_train.reshape(len(y_train)))

# %%
cov_1 = np.dot(array.T, array) 
print(cov_1.shape)

# %%
from scipy import linalg as la
e_vals_1, e_vecs_1 = la.eig (cov_1)

# %%
sum_evals_1 = np.sum(e_vals_1)
var_exp_1 = (e_vals_1 / sum_evals_1) * 100

# %%
plt.plot(var_exp_1[0:5])

# %%
plt.plot(np.cumsum(var_exp_1)[0:300])

# %%
pc_mat_1 = np.dot(predictor_array_transformed, e_vecs_1.T)

# %%
pc_mat_2 = np.dot(predictor_array_transformed, e_vecs_1)

# %%
pc_mat_1.shape

# %%
pc_mat_2.shape

# %%
plt.plot(pc_mat)

# %%
X.shape

# %%
type(X)

# %%
plt.plot(y)

# %%
regr = RandomForestRegressor(n_estimators = 200, criterion = 'absolute_error', min_samples_leaf=2)

# %%
regr

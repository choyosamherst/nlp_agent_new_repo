# %%
from importlib import reload
import pandas as pd
import time

# %%
import numpy as np
import spacy
from wordcloud import WordCloud


import matplotlib.pyplot as plt

# %%
import nltk
#nltk.download('stopwords')

# %%
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer

# %%
import sklearn.feature_extraction.text as text

# %%
import nlp_pandas_functions as npf
#dir(npf)
# Out:
# 2022-03-01 13:35:27,658 loading file /home/cdsw/.flair/models/sentiment-en-mix-distillbert_4.pt

# %%
#pip3 install pyarrow
#pip3 install spacy
#pip3 install wordcloud
#pip3 install nltk
#pip3 install sklearn
#pip3 install ipdb

# %%
str_state = 'GA'
file = 'agent_comments_sales_'+str_state
#file = 'agent_comments_testdf'
#READ THE SALES DATA - STATE
df_sales = pd.read_feather(file + '_sentencecomposition.fea')
#df_sales = pd.read_feather(file + '_withsentiment.fea')
#df_sales = pd.read_feather(file+'_processed.fea')

# %%
df_sales_save = df_sales

# %%
df_sales = df_sales_save#.head(10)

# %%
df_sales
# Out:
#         listingid    asgpropid     qtr  tax_year cbsa_div   cbsa state  \
# 0       226661582   27649366.0  202008    2020.0    23580  23580    GA
# 1       226786904   27628370.0  202008    2020.0    29300  29300    GA
# 2       226142320   27963359.0  202005    2020.0    27600  27600    GA
# 3       226738459   27516267.0  202008    2020.0    29300  29300    GA
# 4       226850183   27791872.0  202008    2020.0    23580  23580    GA
# ...           ...          ...     ...       ...      ...    ...   ...
# 633866   77898274  106321613.0  200708    2013.0    27600  27600    GA
# 633867   77863520  131534737.0  200705    2013.0    23580  23580    GA
# 633868   77900119  131589092.0  200708    2013.0    23580  23580    GA
# 633869   77861631  131589103.0  200702    2013.0    23580  23580    GA
# 633870   77883696  131589105.0  200705    2013.0    23580  23580    GA
#
#         Transdate  Transprice  bedrooms  ...  \
# 0        20200811    359000.0       4.0  ...
# 1        20200925    265000.0       4.0  ...
# 2        20200624    239900.0       4.0  ...
# 3        20200713    130900.0       3.0  ...
# 4        20200702    406000.0       4.0  ...
# ...           ...         ...       ...  ...
# 633866   20070719    163900.0       NaN  ...
# 633867   20070430    292300.0       3.0  ...
# 633868   20070831    181000.0       3.0  ...
# 633869   20070214    179800.0       3.0  ...
# 633870   20070420    185000.0       3.0  ...
#
#                               publicremarks_vaderpolarity  \
# 0       {'compound': 0.9627, 'neg': 0.0, 'neu': 0.86, ...
# 1       {'compound': 0.9939, 'neg': 0.015, 'neu': 0.70...
# 2       {'compound': 0.8528, 'neg': 0.0, 'neu': 0.893,...
# 3       {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos...
# 4       {'compound': 0.8829, 'neg': 0.0, 'neu': 0.877,...
# ...                                                   ...
# 633866  {'compound': 0.7684, 'neg': 0.0, 'neu': 0.832,...
# 633867  {'compound': 0.8741, 'neg': 0.0, 'neu': 0.764,...
# 633868  {'compound': 0.8779, 'neg': 0.0, 'neu': 0.684,...
# 633869  {'compound': 0.6341, 'neg': 0.0, 'neu': 0.881,...
# 633870  {'compound': 0.9613, 'neg': 0.0, 'neu': 0.673,...
#
#                         clean_publicremarks_vaderpolarity  \
# 0       {'compound': 0.9627, 'neg': 0.0, 'neu': 0.781,...
# 1       {'compound': 0.9898, 'neg': 0.013, 'neu': 0.70...
# 2       {'compound': 0.8221, 'neg': 0.0, 'neu': 0.853,...
# 3       {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos...
# 4       {'compound': 0.8829, 'neg': 0.0, 'neu': 0.849,...
# ...                                                   ...
# 633866  {'compound': 0.6351, 'neg': 0.0, 'neu': 0.834,...
# 633867  {'compound': 0.8741, 'neg': 0.0, 'neu': 0.736,...
# 633868  {'compound': 0.8779, 'neg': 0.0, 'neu': 0.605,...
# 633869  {'compound': 0.6341, 'neg': 0.0, 'neu': 0.862,...
# 633870  {'compound': 0.939, 'neg': 0.0, 'neu': 0.658, ...
#
#         clean_publicremarks_additional_words_vaderpolarity  \
# 0       {'compound': 0.9401, 'neg': 0.0, 'neu': 0.803,...
# 1       {'compound': 0.9876, 'neg': 0.015, 'neu': 0.70...
# 2       {'compound': 0.8221, 'neg': 0.0, 'neu': 0.851,...
# 3       {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos...
# 4       {'compound': 0.8309, 'neg': 0.0, 'neu': 0.878,...
# ...                                                   ...
# 633866  {'compound': 0.6351, 'neg': 0.0, 'neu': 0.822,...
# 633867  {'compound': 0.8741, 'neg': 0.0, 'neu': 0.728,...
# 633868  {'compound': 0.8779, 'neg': 0.0, 'neu': 0.59, ...
# 633869  {'compound': 0.6341, 'neg': 0.0, 'neu': 0.857,...
# 633870  {'compound': 0.939, 'neg': 0.0, 'neu': 0.649, ...
#
#                 clean_publicremarks_nopunct_vaderpolarity  \
# 0       {'compound': 0.9578, 'neg': 0.0, 'neu': 0.786,...
# 1       {'compound': 0.9889, 'neg': 0.014, 'neu': 0.69...
# 2       {'compound': 0.8074, 'neg': 0.0, 'neu': 0.858,...
# 3       {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos...
# 4       {'compound': 0.8658, 'neg': 0.0, 'neu': 0.857,...
# ...                                                   ...
# 633866  {'compound': 0.5574, 'neg': 0.0, 'neu': 0.85, ...
# 633867  {'compound': 0.8316, 'neg': 0.0, 'neu': 0.762,...
# 633868  {'compound': 0.8779, 'neg': 0.0, 'neu': 0.605,...
# 633869  {'compound': 0.5106, 'neg': 0.0, 'neu': 0.887,...
# 633870  {'compound': 0.9287, 'neg': 0.0, 'neu': 0.655,...
#
#         clean_publicremarks_nopunct_additional_words_vaderpolarity  \
# 0       {'compound': 0.93, 'neg': 0.0, 'neu': 0.81, 'p...
# 1       {'compound': 0.9864, 'neg': 0.016, 'neu': 0.7,...
# 2       {'compound': 0.8074, 'neg': 0.0, 'neu': 0.855,...
# 3       {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos...
# 4       {'compound': 0.802, 'neg': 0.0, 'neu': 0.886, ...
# ...                                                   ...
# 633866  {'compound': 0.5574, 'neg': 0.0, 'neu': 0.839,...
# 633867  {'compound': 0.8316, 'neg': 0.0, 'neu': 0.755,...
# 633868  {'compound': 0.8779, 'neg': 0.0, 'neu': 0.59, ...
# 633869  {'compound': 0.5106, 'neg': 0.0, 'neu': 0.883,...
# 633870  {'compound': 0.9287, 'neg': 0.0, 'neu': 0.646,...
#
#                 clean_publicremarks_stemmed_vaderpolarity  \
# 0       {'compound': 0.6486, 'neg': 0.0, 'neu': 0.936,...
# 1       {'compound': 0.9732, 'neg': 0.0, 'neu': 0.801,...
# 2       {'compound': 0.3182, 'neg': 0.0, 'neu': 0.958,...
# 3       {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos...
# 4       {'compound': 0.5106, 'neg': 0.0, 'neu': 0.932,...
# ...                                                   ...
# 633866  {'compound': 0.5574, 'neg': 0.0, 'neu': 0.85, ...
# 633867  {'compound': 0.6249, 'neg': 0.0, 'neu': 0.864,...
# 633868  {'compound': 0.7506, 'neg': 0.0, 'neu': 0.748,...
# 633869  {'compound': 0.3612, 'neg': 0.0, 'neu': 0.912,...
# 633870  {'compound': 0.8481, 'neg': 0.0, 'neu': 0.773,...
#
#         clean_publicremarks_stemmed_additional_words_vaderpolarity  \
# 0       {'compound': 0.4939, 'neg': 0.0, 'neu': 0.954,...
# 1       {'compound': 0.9686, 'neg': 0.0, 'neu': 0.799,...
# 2       {'compound': 0.3182, 'neg': 0.0, 'neu': 0.957,...
# 3       {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos...
# 4       {'compound': 0.2023, 'neg': 0.0, 'neu': 0.969,...
# ...                                                   ...
# 633866  {'compound': 0.5574, 'neg': 0.0, 'neu': 0.839,...
# 633867  {'compound': 0.6249, 'neg': 0.0, 'neu': 0.859,...
# 633868  {'compound': 0.7506, 'neg': 0.0, 'neu': 0.738,...
# 633869  {'compound': 0.3612, 'neg': 0.0, 'neu': 0.909,...
# 633870  {'compound': 0.8481, 'neg': 0.0, 'neu': 0.767,...
#
#              clean_publicremarks_lemmatized_vaderpolarity  \
# 0       {'compound': 0.9578, 'neg': 0.0, 'neu': 0.786,...
# 1       {'compound': 0.9875, 'neg': 0.014, 'neu': 0.70...
# 2       {'compound': 0.8074, 'neg': 0.0, 'neu': 0.858,...
# 3       {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos...
# 4       {'compound': 0.802, 'neg': 0.0, 'neu': 0.876, ...
# ...                                                   ...
# 633866  {'compound': 0.5574, 'neg': 0.0, 'neu': 0.85, ...
# 633867  {'compound': 0.8316, 'neg': 0.0, 'neu': 0.762,...
# 633868  {'compound': 0.8779, 'neg': 0.0, 'neu': 0.605,...
# 633869  {'compound': 0.5106, 'neg': 0.0, 'neu': 0.887,...
# 633870  {'compound': 0.9287, 'neg': 0.0, 'neu': 0.655,...
#
#         clean_publicremarks_lemmatized_additional_words_vaderpolarity  \
# 0       {'compound': 0.93, 'neg': 0.0, 'neu': 0.81, 'p...
# 1       {'compound': 0.9844, 'neg': 0.016, 'neu': 0.70...
# 2       {'compound': 0.8074, 'neg': 0.0, 'neu': 0.855,...
# 3       {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos...
# 4       {'compound': 0.6908, 'neg': 0.0, 'neu': 0.908,...
# ...                                                   ...
# 633866  {'compound': 0.5574, 'neg': 0.0, 'neu': 0.839,...
# 633867  {'compound': 0.8316, 'neg': 0.0, 'neu': 0.755,...
# 633868  {'compound': 0.8779, 'neg': 0.0, 'neu': 0.59, ...
# 633869  {'compound': 0.5106, 'neg': 0.0, 'neu': 0.883,...
# 633870  {'compound': 0.9287, 'neg': 0.0, 'neu': 0.646,...
#
#                                      sentence_composition
# 0       [55.00000000000001, 13.750000000000002, 17.5, ...
# 1       [60.18518518518518, 13.88888888888889, 18.5185...
# 2       [60.37735849056604, 9.433962264150944, 24.5283...
# 3       [53.84615384615385, 7.6923076923076925, 38.461...
# 4       [65.57377049180327, 13.114754098360656, 11.475...
# ...                                                   ...
# 633866  [57.14285714285714, 17.857142857142858, 14.285...
# 633867  [48.148148148148145, 11.11111111111111, 25.925...
# 633868  [52.38095238095239, 9.523809523809524, 38.0952...
# 633869  [60.0, 6.666666666666667, 33.33333333333333, 0...
# 633870  [56.666666666666664, 16.666666666666664, 26.66...
#
# [633871 rows x 70 columns]

# %%
df_sales['transaction_year'] = np.floor(np.array((df_sales['Transdate'].values/10000)))

# %%
df_sales.columns
# Out:
# Index(['listingid', 'asgpropid', 'qtr', 'tax_year', 'cbsa_div', 'cbsa',
#        'state', 'Transdate', 'Transprice', 'bedrooms', 'total_value',
#        'cj_living_area', 'basement', 'has_pool', 'parking', 'is_poor',
#        'is_good', 'HAS_VIEW', 'has_golf', 'has_water', 'has_woods', 'has_hill',
#        'fips_code', 'census_tract', 'zip', 'effective_year_built', 'story',
#        'ListingPrice', 'publicremarks', 'avmValue', 'avmerror', 'rentsale',
#        'publicremarks_prepared', 'publicremarks_prepared_unicode',
#        'clean_publicremarks', 'clean_publicremarks_additional_words',
#        'clean_publicremarks_nopunct',
#        'clean_publicremarks_nopunct_additional_words',
#        'clean_publicremarks_stemmed',
#        'clean_publicremarks_stemmed_additional_words',
#        'clean_publicremarks_lemmatized',
#        'clean_publicremarks_lemmatized_additional_words',
#        'publicremarks_nltkpolarity', 'clean_publicremarks_nltkpolarity',
#        'clean_publicremarks_additional_words_nltkpolarity',
#        'clean_publicremarks_nopunct_nltkpolarity',
#        'clean_publicremarks_nopunct_additional_words_nltkpolarity',
#        'clean_publicremarks_stemmed_nltkpolarity',
#        'clean_publicremarks_stemmed_additional_words_nltkpolarity',
#        'clean_publicremarks_lemmatized_nltkpolarity',
#        'clean_publicremarks_lemmatized_additional_words_nltkpolarity',
#        'publicremarks_textblobpolarity',
#        'clean_publicremarks_textblobpolarity',
#        'clean_publicremarks_additional_words_textblobpolarity',
#        'clean_publicremarks_nopunct_textblobpolarity',
#        'clean_publicremarks_nopunct_additional_words_textblobpolarity',
#        'clean_publicremarks_stemmed_textblobpolarity',
#        'clean_publicremarks_stemmed_additional_words_textblobpolarity',
#        'clean_publicremarks_lemmatized_textblobpolarity',
#        'clean_publicremarks_lemmatized_additional_words_textblobpolarity',
#        'publicremarks_vaderpolarity', 'clean_publicremarks_vaderpolarity',
#        'clean_publicremarks_additional_words_vaderpolarity',
#        'clean_publicremarks_nopunct_vaderpolarity',
#        'clean_publicremarks_nopunct_additional_words_vaderpolarity',
#        'clean_publicremarks_stemmed_vaderpolarity',
#        'clean_publicremarks_stemmed_additional_words_vaderpolarity',
#        'clean_publicremarks_lemmatized_vaderpolarity',
#        'clean_publicremarks_lemmatized_additional_words_vaderpolarity',
#        'sentence_composition', 'transaction_year'],
#       dtype='object')

# %%
print(df_sales['transaction_year'].min())
print(df_sales['transaction_year'].max())
# Out:
# 2006.0
# 2021.0

# %%
df_sales_train = df_sales[df_sales['transaction_year']<=2020]

# %%
df_sales_train
# Out:
#         listingid    asgpropid     qtr  tax_year cbsa_div   cbsa state  \
# 0       226661582   27649366.0  202008    2020.0    23580  23580    GA
# 1       226786904   27628370.0  202008    2020.0    29300  29300    GA
# 2       226142320   27963359.0  202005    2020.0    27600  27600    GA
# 3       226738459   27516267.0  202008    2020.0    29300  29300    GA
# 4       226850183   27791872.0  202008    2020.0    23580  23580    GA
# ...           ...          ...     ...       ...      ...    ...   ...
# 633866   77898274  106321613.0  200708    2013.0    27600  27600    GA
# 633867   77863520  131534737.0  200705    2013.0    23580  23580    GA
# 633868   77900119  131589092.0  200708    2013.0    23580  23580    GA
# 633869   77861631  131589103.0  200702    2013.0    23580  23580    GA
# 633870   77883696  131589105.0  200705    2013.0    23580  23580    GA
#
#         Transdate  Transprice  bedrooms  ...  \
# 0        20200811    359000.0       4.0  ...
# 1        20200925    265000.0       4.0  ...
# 2        20200624    239900.0       4.0  ...
# 3        20200713    130900.0       3.0  ...
# 4        20200702    406000.0       4.0  ...
# ...           ...         ...       ...  ...
# 633866   20070719    163900.0       NaN  ...
# 633867   20070430    292300.0       3.0  ...
# 633868   20070831    181000.0       3.0  ...
# 633869   20070214    179800.0       3.0  ...
# 633870   20070420    185000.0       3.0  ...
#
#                         clean_publicremarks_vaderpolarity  \
# 0       {'compound': 0.9627, 'neg': 0.0, 'neu': 0.781,...
# 1       {'compound': 0.9898, 'neg': 0.013, 'neu': 0.70...
# 2       {'compound': 0.8221, 'neg': 0.0, 'neu': 0.853,...
# 3       {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos...
# 4       {'compound': 0.8829, 'neg': 0.0, 'neu': 0.849,...
# ...                                                   ...
# 633866  {'compound': 0.6351, 'neg': 0.0, 'neu': 0.834,...
# 633867  {'compound': 0.8741, 'neg': 0.0, 'neu': 0.736,...
# 633868  {'compound': 0.8779, 'neg': 0.0, 'neu': 0.605,...
# 633869  {'compound': 0.6341, 'neg': 0.0, 'neu': 0.862,...
# 633870  {'compound': 0.939, 'neg': 0.0, 'neu': 0.658, ...
#
#         clean_publicremarks_additional_words_vaderpolarity  \
# 0       {'compound': 0.9401, 'neg': 0.0, 'neu': 0.803,...
# 1       {'compound': 0.9876, 'neg': 0.015, 'neu': 0.70...
# 2       {'compound': 0.8221, 'neg': 0.0, 'neu': 0.851,...
# 3       {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos...
# 4       {'compound': 0.8309, 'neg': 0.0, 'neu': 0.878,...
# ...                                                   ...
# 633866  {'compound': 0.6351, 'neg': 0.0, 'neu': 0.822,...
# 633867  {'compound': 0.8741, 'neg': 0.0, 'neu': 0.728,...
# 633868  {'compound': 0.8779, 'neg': 0.0, 'neu': 0.59, ...
# 633869  {'compound': 0.6341, 'neg': 0.0, 'neu': 0.857,...
# 633870  {'compound': 0.939, 'neg': 0.0, 'neu': 0.649, ...
#
#                 clean_publicremarks_nopunct_vaderpolarity  \
# 0       {'compound': 0.9578, 'neg': 0.0, 'neu': 0.786,...
# 1       {'compound': 0.9889, 'neg': 0.014, 'neu': 0.69...
# 2       {'compound': 0.8074, 'neg': 0.0, 'neu': 0.858,...
# 3       {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos...
# 4       {'compound': 0.8658, 'neg': 0.0, 'neu': 0.857,...
# ...                                                   ...
# 633866  {'compound': 0.5574, 'neg': 0.0, 'neu': 0.85, ...
# 633867  {'compound': 0.8316, 'neg': 0.0, 'neu': 0.762,...
# 633868  {'compound': 0.8779, 'neg': 0.0, 'neu': 0.605,...
# 633869  {'compound': 0.5106, 'neg': 0.0, 'neu': 0.887,...
# 633870  {'compound': 0.9287, 'neg': 0.0, 'neu': 0.655,...
#
#         clean_publicremarks_nopunct_additional_words_vaderpolarity  \
# 0       {'compound': 0.93, 'neg': 0.0, 'neu': 0.81, 'p...
# 1       {'compound': 0.9864, 'neg': 0.016, 'neu': 0.7,...
# 2       {'compound': 0.8074, 'neg': 0.0, 'neu': 0.855,...
# 3       {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos...
# 4       {'compound': 0.802, 'neg': 0.0, 'neu': 0.886, ...
# ...                                                   ...
# 633866  {'compound': 0.5574, 'neg': 0.0, 'neu': 0.839,...
# 633867  {'compound': 0.8316, 'neg': 0.0, 'neu': 0.755,...
# 633868  {'compound': 0.8779, 'neg': 0.0, 'neu': 0.59, ...
# 633869  {'compound': 0.5106, 'neg': 0.0, 'neu': 0.883,...
# 633870  {'compound': 0.9287, 'neg': 0.0, 'neu': 0.646,...
#
#                 clean_publicremarks_stemmed_vaderpolarity  \
# 0       {'compound': 0.6486, 'neg': 0.0, 'neu': 0.936,...
# 1       {'compound': 0.9732, 'neg': 0.0, 'neu': 0.801,...
# 2       {'compound': 0.3182, 'neg': 0.0, 'neu': 0.958,...
# 3       {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos...
# 4       {'compound': 0.5106, 'neg': 0.0, 'neu': 0.932,...
# ...                                                   ...
# 633866  {'compound': 0.5574, 'neg': 0.0, 'neu': 0.85, ...
# 633867  {'compound': 0.6249, 'neg': 0.0, 'neu': 0.864,...
# 633868  {'compound': 0.7506, 'neg': 0.0, 'neu': 0.748,...
# 633869  {'compound': 0.3612, 'neg': 0.0, 'neu': 0.912,...
# 633870  {'compound': 0.8481, 'neg': 0.0, 'neu': 0.773,...
#
#         clean_publicremarks_stemmed_additional_words_vaderpolarity  \
# 0       {'compound': 0.4939, 'neg': 0.0, 'neu': 0.954,...
# 1       {'compound': 0.9686, 'neg': 0.0, 'neu': 0.799,...
# 2       {'compound': 0.3182, 'neg': 0.0, 'neu': 0.957,...
# 3       {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos...
# 4       {'compound': 0.2023, 'neg': 0.0, 'neu': 0.969,...
# ...                                                   ...
# 633866  {'compound': 0.5574, 'neg': 0.0, 'neu': 0.839,...
# 633867  {'compound': 0.6249, 'neg': 0.0, 'neu': 0.859,...
# 633868  {'compound': 0.7506, 'neg': 0.0, 'neu': 0.738,...
# 633869  {'compound': 0.3612, 'neg': 0.0, 'neu': 0.909,...
# 633870  {'compound': 0.8481, 'neg': 0.0, 'neu': 0.767,...
#
#              clean_publicremarks_lemmatized_vaderpolarity  \
# 0       {'compound': 0.9578, 'neg': 0.0, 'neu': 0.786,...
# 1       {'compound': 0.9875, 'neg': 0.014, 'neu': 0.70...
# 2       {'compound': 0.8074, 'neg': 0.0, 'neu': 0.858,...
# 3       {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos...
# 4       {'compound': 0.802, 'neg': 0.0, 'neu': 0.876, ...
# ...                                                   ...
# 633866  {'compound': 0.5574, 'neg': 0.0, 'neu': 0.85, ...
# 633867  {'compound': 0.8316, 'neg': 0.0, 'neu': 0.762,...
# 633868  {'compound': 0.8779, 'neg': 0.0, 'neu': 0.605,...
# 633869  {'compound': 0.5106, 'neg': 0.0, 'neu': 0.887,...
# 633870  {'compound': 0.9287, 'neg': 0.0, 'neu': 0.655,...
#
#         clean_publicremarks_lemmatized_additional_words_vaderpolarity  \
# 0       {'compound': 0.93, 'neg': 0.0, 'neu': 0.81, 'p...
# 1       {'compound': 0.9844, 'neg': 0.016, 'neu': 0.70...
# 2       {'compound': 0.8074, 'neg': 0.0, 'neu': 0.855,...
# 3       {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos...
# 4       {'compound': 0.6908, 'neg': 0.0, 'neu': 0.908,...
# ...                                                   ...
# 633866  {'compound': 0.5574, 'neg': 0.0, 'neu': 0.839,...
# 633867  {'compound': 0.8316, 'neg': 0.0, 'neu': 0.755,...
# 633868  {'compound': 0.8779, 'neg': 0.0, 'neu': 0.59, ...
# 633869  {'compound': 0.5106, 'neg': 0.0, 'neu': 0.883,...
# 633870  {'compound': 0.9287, 'neg': 0.0, 'neu': 0.646,...
#
#                                      sentence_composition  transaction_year
# 0       [55.00000000000001, 13.750000000000002, 17.5, ...            2020.0
# 1       [60.18518518518518, 13.88888888888889, 18.5185...            2020.0
# 2       [60.37735849056604, 9.433962264150944, 24.5283...            2020.0
# 3       [53.84615384615385, 7.6923076923076925, 38.461...            2020.0
# 4       [65.57377049180327, 13.114754098360656, 11.475...            2020.0
# ...                                                   ...               ...
# 633866  [57.14285714285714, 17.857142857142858, 14.285...            2007.0
# 633867  [48.148148148148145, 11.11111111111111, 25.925...            2007.0
# 633868  [52.38095238095239, 9.523809523809524, 38.0952...            2007.0
# 633869  [60.0, 6.666666666666667, 33.33333333333333, 0...            2007.0
# 633870  [56.666666666666664, 16.666666666666664, 26.66...            2007.0
#
# [600278 rows x 71 columns]

# %%
d_temp = df_sales_train.loc[df_sales['clean_publicremarks'].str.contains("illustrate potential.", case=False)]

# %%
d_temp['clean_publicremarks']
# Out:
# 161326    snellville two-story corner home offers firepl...
# 211870    atlanta two-story home offers loft, granite co...
# Name: clean_publicremarks, dtype: object

# %%
from nlp_pandas_functions import ngram_analysis
reload(ngram_analysis)
dir(ngram_analysis)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'bigrams_join',
#  'count_n_grams',
#  'defaultdict',
#  'df_get_n_grams_count',
#  'df_lambda_ngram',
#  'generate_n_grams',
#  'get_imp',
#  'get_n_grams_count',
#  'get_n_grams_probability',
#  'kg',
#  'ngrams',
#  'np',
#  'pd',
#  'text']

# %%
column = 'clean_publicremarks_nopunct'

# %%
unigram_df = pd.read_feather('ngrams/' + file + '_withsentiment_' + column + '_unigram.fea')
bigram_df = pd.read_feather('ngrams/' + file + '_withsentiment_' + column + '_bigram.fea')
trigram_df = pd.read_feather('ngrams/' + file + '_withsentiment_' + column + '_trigram.fea')
fourgram_df = pd.read_feather('ngrams/' + file + '_withsentiment_' + column + '_fourgram.fea')

# %%
df_sales_train[column].values[0]
# Out:
# 'welcome gorgeous basement home desired braselton community riverstone park upon entry find formal dining room office complete french doors open floor plan boasts kitchen large island  breakfast area overlooking living room open staircase DIGITnd floor master main master suite upstairs along walkin closets every bedroom wind day screened back porch gaze well manicured back lawn meticulously cared home lot offer waiting you riverstone park social neighborhood many activities year also access life path easy golf cart ride away favorite eateries'

# %%
import time
from textblob import TextBlob
from collections import defaultdict

# %%
def get_n_grams_cumulative_error(df, column_name, ngram,
                            noun_sentences_dict_listingid_list,
                            noun_sentences_dict_error_list):
    
    tic = time.clock()
    #print((df[column_name].values))
    for idd,strsample in enumerate(df[column_name].values):
       
        textblob_temp = TextBlob(strsample)
        #print(idd, len(df[column_name].values),df['listingid'].values[idd])
        if len(textblob_temp.words)>=4:
            #print(strsample)
            #print(textblob_temp.words)
            df_ngram = ngram_analysis.get_n_grams_count(strsample,ngram)
            #print(df_ngram)
            #print(df_ngram)
            #print(df_ngram.empty)
            if df_ngram.empty==False: 
                df_ngram = df_ngram.rename({0: 'ngram', 1: 'count'}, axis='columns')
                df_ngram['error'] = df_ngram['count']*df['avmerror'].values[idd]
                df_ngram = df_ngram.set_index('ngram')

                error_temp = df_ngram.loc[list(df_ngram.index)]['error'].values
                #print(error_temp)
                #print(ngram_error.loc[list(df_ngram.index)]['error'].values)
                #new_error_list = list(ngram_error.loc[list(df_ngram.index)]['error'].values + 
                #                      error_temp)
                #print(new_error_list)
                #ngram_error.loc[list(df_ngram.index), ['error']] = new_error_list
                for idngram,strngram in enumerate(list(df_ngram.index)):
                    #print(strngram, error_temp[idngram],df['listingid'].values[idd])
                    temp_list_listing = noun_sentences_dict_listingid_list[strngram]
                    temp_list_listing.append(df['listingid'].values[idd])
                    temp_list_error = noun_sentences_dict_error_list[strngram]
                    temp_list_error.append(error_temp[idngram])

                    #print(temp_list_error)
                    noun_sentences_dict_listingid_list[strngram] = temp_list_listing
                    noun_sentences_dict_error_list[strngram] = temp_list_error
            if (idd%20000 == 0): 
                print(idd, len(df[column_name].values))
                print(time.clock() - tic)
            #if (idd%100 == 0): print(idd, len(df[column_name].values))

    return noun_sentences_dict_listingid_list, noun_sentences_dict_error_list

# %%
bigram_df_error = bigram_df
bigram_df_error = bigram_df_error.set_index('ngram')
noun_sentences_dict_listingid_list = dict(zip(list(bigram_df_error.index), [[] for i in range(len(bigram_df['probability']))]))
noun_sentences_dict_error_list = dict(zip(list(bigram_df_error.index), [[] for i in range(len(bigram_df['probability']))]))
bigram_df_error['error'] = bigram_df_error['probability']*0.
bigram_df_error.head(3)
# Out:
#                   count  probability  error
# ngram
# family room      156048     0.004727    0.0
# dining room      115262     0.003492    0.0
# hardwood floors  113450     0.003437    0.0

# %%
noun_sentences_dict_error_list
# Out:
# {'family room': [],
#  'dining room': [],
#  'hardwood floors': [],
#  'master suite': [],
#  'floor plan': [],
#  'living room': [],
#  'main level': [],
#  'full bath': [],
#  'master bath': [],
#  'back yard': [],
#  'great room': [],
#  'stainless steel': [],
#  'DIGIT bedrooms': [],
#  'DIGIT bedroom': [],
#  'open floor': [],
#  'master bedroom': [],
#  'steel appliances': [],
#  'front porch': [],
#  'formal dining': [],
#  'finished basement': [],
#  'must see': [],
#  'fenced backyard': [],
#  'new carpet': [],
#  'car garage': [],
#  'DIGIT car': [],
#  'granite countertops': [],
#  'breakfast area': [],
#  'walkin closet': [],
#  'bonus room': [],
#  'master main': [],
#  'new roof': [],
#  'DIGIT story': [],
#  'garden tub': [],
#  'laundry room': [],
#  'large master': [],
#  'home features': [],
#  'counter tops': [],
#  'bedroom DIGIT': [],
#  'school district': [],
#  'bedrooms DIGIT': [],
#  'secondary bedrooms': [],
#  'private backyard': [],
#  'room fireplace': [],
#  'screened porch': [],
#  'terrace level': [],
#  'move ready': [],
#  'brand new': [],
#  'granite counters': [],
#  'DIGIT bath': [],
#  'separate dining': [],
#  'bath home': [],
#  'granite counter': [],
#  'formal living': [],
#  'stainless appliances': [],
#  'walk closet': [],
#  'well maintained': [],
#  'DIGIT full': [],
#  'separate shower': [],
#  'sitting area': [],
#  'new paint': [],
#  'kitchen granite': [],
#  'water heater': [],
#  'ranch home': [],
#  'fenced yard': [],
#  'ss appliances': [],
#  'gourmet kitchen': [],
#  'floors throughout': [],
#  'double vanity': [],
#  'main floor': [],
#  'fenced back': [],
#  'updated kitchen': [],
#  'corner lot': [],
#  'movein ready': [],
#  'open kitchen': [],
#  'breakfast bar': [],
#  'stone fireplace': [],
#  'DIGITDIGIT bath': [],
#  'kitchen w': [],
#  'dont miss': [],
#  'room kitchen': [],
#  'owners suite': [],
#  'brick ranch': [],
#  'brick home': [],
#  'vaulted ceilings': [],
#  'home located': [],
#  'freshly painted': [],
#  'two story': [],
#  'room large': [],
#  'full baths': [],
#  'eatin kitchen': [],
#  'bedroom full': [],
#  'natural light': [],
#  'tile backsplash': [],
#  'fresh paint': [],
#  'private fenced': [],
#  'tub separate': [],
#  'kitchen breakfast': [],
#  'last long': [],
#  'great location': [],
#  'rocking chair': [],
#  'easy access': [],
#  'back deck': [],
#  'trey ceiling': [],
#  'paint new': [],
#  'living dining': [],
#  'spacious master': [],
#  'perfect entertaining': [],
#  'beautiful home': [],
#  'family rm': [],
#  'chair front': [],
#  'sitting room': [],
#  'unfinished basement': [],
#  'culdesac lot': [],
#  'throughout main': [],
#  'large family': [],
#  'wont last': [],
#  'home DIGIT': [],
#  'room w': [],
#  'DIGITth bedroom': [],
#  'vaulted ceiling': [],
#  'kitchen features': [],
#  'full basement': [],
#  'story foyer': [],
#  'additional bedrooms': [],
#  'huge master': [],
#  'bath main': [],
#  'breakfast room': [],
#  'large kitchen': [],
#  'media room': [],
#  'room dining': [],
#  'open concept': [],
#  'lower level': [],
#  'much more': [],
#  'hardwood flooring': [],
#  'french doors': [],
#  'level lot': [],
#  'sided brick': [],
#  'keeping room': [],
#  'new hvac': [],
#  'full finished': [],
#  'finished terrace': [],
#  'dining area': [],
#  'chefs kitchen': [],
#  'acre lot': [],
#  'cabinets granite': [],
#  'walking distance': [],
#  'suite main': [],
#  'welcome home': [],
#  'new flooring': [],
#  'dining rm': [],
#  'home offers': [],
#  'hardwoods throughout': [],
#  'large deck': [],
#  'tile floors': [],
#  'living area': [],
#  'eat kitchen': [],
#  'home great': [],
#  'new kitchen': [],
#  'interior paint': [],
#  'spacious kitchen': [],
#  'living space': [],
#  'walkin closets': [],
#  'appliances granite': [],
#  'DIGIT additional': [],
#  'split bedroom': [],
#  'style home': [],
#  'kitchen new': [],
#  'DIGIT sided': [],
#  'large bedrooms': [],
#  'de sac': [],
#  'floors main': [],
#  'light fixtures': [],
#  'cul de': [],
#  'new stainless': [],
#  'room master': [],
#  'double vanities': [],
#  'roof new': [],
#  'beautiful DIGIT': [],
#  'DIGIT years': [],
#  'tub shower': [],
#  'bedroom DIGITDIGIT': [],
#  'private back': [],
#  'DIGITDIGIT acre': [],
#  'conveniently located': [],
#  'inlaw suite': [],
#  'spacious bedrooms': [],
#  'DIGIT baths': [],
#  'private wooded': [],
#  'swim tennis': [],
#  'oversized master': [],
#  'shopping restaurants': [],
#  'bedroom main': [],
#  'maintained home': [],
#  'deck overlooking': [],
#  'open floorplan': [],
#  'open family': [],
#  'bedrooms upstairs': [],
#  'features DIGIT': [],
#  'inside out': [],
#  'upper level': [],
#  'come see': [],
#  'swimtennis community': [],
#  'DIGITDIGIT baths': [],
#  'golf course': [],
#  'DIGIT acre': [],
#  'new granite': [],
#  'room DIGIT': [],
#  'master bathroom': [],
#  'fireside family': [],
#  'room open': [],
#  'back porch': [],
#  'kitchen open': [],
#  'DIGIT large': [],
#  'full bathroom': [],
#  'custom built': [],
#  'large walkin': [],
#  'DIGIT bed': [],
#  'kitchen island': [],
#  'room separate': [],
#  'side entry': [],
#  'great home': [],
#  'appliances new': [],
#  'rec room': [],
#  'room family': [],
#  'half bath': [],
#  'trey ceilings': [],
#  'shopping dining': [],
#  'carpet new': [],
#  'wooded lot': [],
#  'separate living': [],
#  'bedroom plan': [],
#  'daylight basement': [],
#  'large fenced': [],
#  'hardwoods main': [],
#  'new home': [],
#  'high school': [],
#  'soaking tub': [],
#  'kitchen stainless': [],
#  'new appliances': [],
#  'home large': [],
#  'room upstairs': [],
#  'great entertaining': [],
#  'award winning': [],
#  'priced sell': [],
#  'years old': [],
#  'throughout home': [],
#  'jetted tub': [],
#  'suite w': [],
#  'large level': [],
#  'flooring throughout': [],
#  'DIGIT br': [],
#  'features include': [],
#  'wet bar': [],
#  'plantation shutters': [],
#  'newer roof': [],
#  'close shopping': [],
#  'covered patio': [],
#  'room formal': [],
#  'stained cabinets': [],
#  'large open': [],
#  'quiet neighborhood': [],
#  'stacked stone': [],
#  'bath large': [],
#  'plenty room': [],
#  'large private': [],
#  'home new': [],
#  'private bath': [],
#  'bath DIGIT': [],
#  'hot water': [],
#  'bedrooms full': [],
#  'renovated kitchen': [],
#  'paint throughout': [],
#  'large secondary': [],
#  'new construction': [],
#  'granite kitchen': [],
#  'walkin pantry': [],
#  'DIGIT DIGITDIGIT': [],
#  'home sits': [],
#  'ready move': [],
#  'home sought': [],
#  'recently renovated': [],
#  'wood floors': [],
#  'guest suite': [],
#  'crown molding': [],
#  'quiet culdesac': [],
#  'exterior paint': [],
#  'screen porch': [],
#  'new windows': [],
#  'entry garage': [],
#  'high ceilings': [],
#  'brick front': [],
#  'deck overlooks': [],
#  'two car': [],
#  'bedrooms DIGITDIGIT': [],
#  'story home': [],
#  'storage space': [],
#  'white cabinets': [],
#  'private lot': [],
#  'like new': [],
#  'level features': [],
#  'level backyard': [],
#  'full unfinished': [],
#  'family home': [],
#  'tennis courts': [],
#  'overlooking private': [],
#  'walk closets': [],
#  'DIGIT acres': [],
#  'suite sitting': [],
#  'kitchen large': [],
#  'great schools': [],
#  'level fenced': [],
#  'new interior': [],
#  'room spacious': [],
#  'bath double': [],
#  'renovated home': [],
#  'great rm': [],
#  'DIGITcar garage': [],
#  'kitchen opens': [],
#  'sun room': [],
#  'covered porch': [],
#  'room full': [],
#  'floors new': [],
#  'fire pit': [],
#  'ready home': [],
#  'countertops stainless': [],
#  'spacious family': [],
#  'beautiful hardwood': [],
#  'completely renovated': [],
#  'home office': [],
#  'features large': [],
#  'wall windows': [],
#  'split level': [],
#  'gas fireplace': [],
#  'bedroom bath': [],
#  'location location': [],
#  'covered front': [],
#  'bath w': [],
#  'craftsman style': [],
#  'tile shower': [],
#  'large walk': [],
#  'story family': [],
#  'meticulously maintained': [],
#  'partially finished': [],
#  'large living': [],
#  'spa bath': [],
#  'DIGITDIGITDIGIT acres': [],
#  'kitchen wgranite': [],
#  'paint inside': [],
#  'room vaulted': [],
#  'area large': [],
#  'bath ranch': [],
#  'first time': [],
#  'newly renovated': [],
#  'living rm': [],
#  'DIGITDIGIT acres': [],
#  'back splash': [],
#  'room great': [],
#  'wood burning': [],
#  'curb appeal': [],
#  'double ovens': [],
#  'short sale': [],
#  'custom cabinets': [],
#  'dining rooms': [],
#  'brick fireplace': [],
#  'east cobb': [],
#  'traditional home': [],
#  'room office': [],
#  'lake lanier': [],
#  'fam rm': [],
#  'new hardwood': [],
#  'sides brick': [],
#  'rm w': [],
#  'guest bedroom': [],
#  'bright open': [],
#  'throughout new': [],
#  'level home': [],
#  'new tile': [],
#  'large island': [],
#  'tile flooring': [],
#  'spacious secondary': [],
#  'master retreat': [],
#  'low maintenance': [],
#  'DIGIT spacious': [],
#  'home beautiful': [],
#  'DIGIT sides': [],
#  'home warranty': [],
#  'washer dryer': [],
#  'ceiling fans': [],
#  'wooded backyard': [],
#  'outdoor living': [],
#  'interior exterior': [],
#  'tiled shower': [],
#  'closet space': [],
#  'coffered ceiling': [],
#  'w fireplace': [],
#  'kitchen cabinets': [],
#  'home open': [],
#  'closet master': [],
#  'upstairs DIGIT': [],
#  'dual vanities': [],
#  'move in': [],
#  'bed DIGIT': [],
#  'separate tub': [],
#  'room main': [],
#  'hot tub': [],
#  'professionally landscaped': [],
#  'fireplace large': [],
#  'w granite': [],
#  'room wfireplace': [],
#  'large lot': [],
#  'home perfect': [],
#  'spacious home': [],
#  'bath separate': [],
#  'room living': [],
#  'tons storage': [],
#  'jack jill': [],
#  'level DIGIT': [],
#  'counter space': [],
#  'highly sought': [],
#  'hall bath': [],
#  'DIGITsided brick': [],
#  'home quiet': [],
#  'sold asis': [],
#  'bay window': [],
#  'back market': [],
#  'kitchen appliances': [],
#  'garage door': [],
#  'open living': [],
#  'home full': [],
#  'back patio': [],
#  'room huge': [],
#  'view family': [],
#  'lots storage': [],
#  'cozy fireplace': [],
#  'large laundry': [],
#  'living areas': [],
#  'location close': [],
#  'large bonus': [],
#  'bedrooms large': [],
#  'great neighborhood': [],
#  'front yard': [],
#  'tile floor': [],
#  'solid surface': [],
#  'front back': [],
#  'schools shopping': [],
#  'plenty storage': [],
#  'flooring new': [],
#  'area master': [],
#  'storage building': [],
#  'fully fenced': [],
#  'kitchen dining': [],
#  'covered back': [],
#  'granite stainless': [],
#  'overlooks private': [],
#  'butlers pantry': [],
#  'huge walkin': [],
#  'main DIGIT': [],
#  'kitchen baths': [],
#  'shower garden': [],
#  'plenty space': [],
#  'coffered ceilings': [],
#  'perfect home': [],
#  'many upgrades': [],
#  'loft area': [],
#  'new water': [],
#  'vaulted family': [],
#  'shower double': [],
#  'room new': [],
#  'paint carpet': [],
#  'pool tennis': [],
#  'cabinet space': [],
#  'suite features': [],
#  'ranch style': [],
#  'spacious DIGIT': [],
#  'front door': [],
#  'home boasts': [],
#  'carpet paint': [],
#  'new deck': [],
#  'two additional': [],
#  'DIGIT year': [],
#  'hvac system': [],
#  'home w': [],
#  'main living': [],
#  'roof DIGIT': [],
#  'sep shower': [],
#  'year old': [],
#  'great opportunity': [],
#  'bedroom home': [],
#  'ranch full': [],
#  'home well': [],
#  'home ready': [],
#  'home must': [],
#  'en suite': [],
#  'porch overlooking': [],
#  'one level': [],
#  'DIGITstory foyer': [],
#  'new light': [],
#  'sold is': [],
#  'high end': [],
#  'new cabinets': [],
#  'quiet street': [],
#  'second floor': [],
#  'established neighborhood': [],
#  'call today': [],
#  'two bedrooms': [],
#  'convenient location': [],
#  'center island': [],
#  'spacious living': [],
#  'home move': [],
#  'room hardwood': [],
#  'storage shed': [],
#  'fenced private': [],
#  'backyard perfect': [],
#  'extra storage': [],
#  'extra large': [],
#  'bathroom home': [],
#  'sq ft': [],
#  'three bedrooms': [],
#  'vaulted great': [],
#  'bath upstairs': [],
#  'room features': [],
#  'kitchen master': [],
#  'room opens': [],
#  'area kitchen': [],
#  'ceramic tile': [],
#  'model home': [],
#  'fireplace kitchen': [],
#  'roof hvac': [],
#  'br DIGIT': [],
#  'less DIGIT': [],
#  'detached garage': [],
#  'gorgeous home': [],
#  'appliances including': [],
#  'whirlpool tub': [],
#  'counters stainless': [],
#  'inground pool': [],
#  'DIGITDIGITDIGITDIGIT new': [],
#  'home also': [],
#  'lots natural': [],
#  'miss one': [],
#  'room perfect': [],
#  'teen suite': [],
#  'vanity separate': [],
#  'room breakfast': [],
#  'beautifully landscaped': [],
#  'rear deck': [],
#  'plan DIGIT': [],
#  'closet DIGIT': [],
#  'minutes downtown': [],
#  'features new': [],
#  'island breakfast': [],
#  'swimming pool': [],
#  'room bedroom': [],
#  'burning fireplace': [],
#  'updated home': [],
#  'fully renovated': [],
#  'bath new': [],
#  'carpet throughout': [],
#  'fresh interior': [],
#  'open plan': [],
#  'located near': [],
#  'ready new': [],
#  'first floor': [],
#  'wrap around': [],
#  'bedrooms main': [],
#  'fireplace master': [],
#  'dining living': [],
#  'basement DIGIT': [],
#  'game room': [],
#  'room home': [],
#  'country club': [],
#  'island granite': [],
#  'opens family': [],
#  'upstairs master': [],
#  'DIGITnd floor': [],
#  'walk pantry': [],
#  'time home': [],
#  'level large': [],
#  'beautifully renovated': [],
#  'DIGIT bathroom': [],
#  'within walking': [],
#  'large back': [],
#  'full daylight': [],
#  'home situated': [],
#  'tub sep': [],
#  'custom cabinetry': [],
#  'recessed lighting': [],
#  'painted interior': [],
#  'large dining': [],
#  'spacious open': [],
#  'story great': [],
#  'kitchen family': [],
#  'room beautiful': [],
#  'large great': [],
#  'ceiling master': [],
#  'separate formal': [],
#  'bonus rm': [],
#  'see home': [],
#  'appliances breakfast': [],
#  'appliances large': [],
#  'gated community': [],
#  'located quiet': [],
#  'DIGITDIGIT minutes': [],
#  'fireplace separate': [],
#  'finished bonus': [],
#  'jill bath': [],
#  'laundry rm': [],
#  'room could': [],
#  'DIGIT bedroomDIGIT': [],
#  'features granite': [],
#  'countertops tile': [],
#  'gas logs': [],
#  'cabinets stainless': [],
#  'large backyard': [],
#  'hard find': [],
#  'beautifully maintained': [],
#  'privacy fence': [],
#  'bedrooms two': [],
#  'room basement': [],
#  'plan large': [],
#  'minutes away': [],
#  'level private': [],
#  'suite large': [],
#  'tennis community': [],
#  'storage room': [],
#  'w full': [],
#  'motivated seller': [],
#  'w DIGIT': [],
#  'starter home': [],
#  'backyard great': [],
#  'DIGIT miles': [],
#  'dream home': [],
#  'countertops new': [],
#  'lot home': [],
#  'renovated DIGIT': [],
#  'porch large': [],
#  'fireplace family': [],
#  'access iDIGITDIGIT': [],
#  'master closet': [],
#  'updated master': [],
#  'irrigation system': [],
#  'carpet bedrooms': [],
#  'split foyer': [],
#  'front home': [],
#  'upstairs features': [],
#  'entry foyer': [],
#  'huge kitchen': [],
#  'landscaped yard': [],
#  'tops stainless': [],
#  'features open': [],
#  'full bathrooms': [],
#  'island kitchen': [],
#  'make home': [],
#  'shower large': [],
#  'fixtures new': [],
#  'well kept': [],
#  'floors kitchen': [],
#  'home private': [],
#  'nice size': [],
#  'hvac new': [],
#  'kitchen boasts': [],
#  'covered deck': [],
#  'fireplace open': [],
#  'restaurants shopping': [],
#  'new garage': [],
#  'level yard': [],
#  'maintained DIGIT': [],
#  'out new': [],
#  'white kitchen': [],
#  'home culdesac': [],
#  'tile back': [],
#  'wfull bath': [],
#  'shops restaurants': [],
#  'minutes iDIGITDIGIT': [],
#  'energy efficient': [],
#  'huge bonus': [],
#  'lot fenced': [],
#  'side brick': [],
#  'new lighting': [],
#  'beautiful ranch': [],
#  'windows new': [],
#  'soaring ceilings': [],
#  'bath huge': [],
#  'vanity garden': [],
#  'DIGITDIGITDIGIT acre': [],
#  'area DIGIT': [],
#  'DIGIT secondary': [],
#  'better new': [],
#  'offers DIGIT': [],
#  'lovely home': [],
#  'home nestled': [],
#  'foyer formal': [],
#  'cabinets new': [],
#  'garage doors': [],
#  'gas cooktop': [],
#  'huge fenced': [],
#  'kitchen includes': [],
#  'suite trey': [],
#  'floors granite': [],
#  'features hardwood': [],
#  'gas range': [],
#  'vanities separate': [],
#  'backyard large': [],
#  'twocar garage': [],
#  'kitchen bathrooms': [],
#  'backsplash stainless': [],
#  'new fixtures': [],
#  'breakfast nook': [],
#  'beautiful brick': [],
#  'stepless ranch': [],
#  'bath features': [],
#  'basement w': [],
#  'plan features': [],
#  'keeping rm': [],
#  'huge deck': [],
#  'level living': [],
#  'executive home': [],
#  'DIGIT ba': [],
#  'room stone': [],
#  'could used': [],
#  'porch deck': [],
#  'room gas': [],
#  'gleaming hardwood': [],
#  'painted inside': [],
#  'room cozy': [],
#  'bath laundry': [],
#  'level master': [],
#  'fall love': [],
#  'large corner': [],
#  'new exterior': [],
#  'floor ceiling': [],
#  'deck perfect': [],
#  'culdesac street': [],
#  'full kitchen': [],
#  'built home': [],
#  'private yard': [],
#  'ga DIGITDIGITDIGIT': [],
#  'newly painted': [],
#  'built DIGITDIGITDIGITDIGIT': [],
#  'private level': [],
#  'hwy DIGITDIGITDIGIT': [],
#  'kitchen offers': [],
#  'dual vanity': [],
#  'charming home': [],
#  'porch overlooks': [],
#  'huge walk': [],
#  'wsitting area': [],
#  'stone patio': [],
#  'bedroom large': [],
#  'shows like': [],
#  'additional bedroom': [],
#  'move right': [],
#  'main large': [],
#  'rear yard': [],
#  'refinished hardwood': [],
#  'beautiful kitchen': [],
#  'DIGIT side': [],
#  'hwy DIGITDIGIT': [],
#  'sac lot': [],
#  'heater new': [],
#  'convenient shopping': [],
#  'exercise room': [],
#  'luxurious master': [],
#  'private culdesac': [],
#  'fully finished': [],
#  'one wont': [],
#  'also features': [],
#  'master w': [],
#  'w new': [],
#  'closing costs': [],
#  'bath garden': [],
#  'roof DIGITDIGITDIGITDIGIT': [],
#  'open great': [],
#  'w sitting': [],
#  'spa like': [],
#  'DIGIT yrs': [],
#  'new ac': [],
#  'laminate flooring': [],
#  'light filled': [],
#  'bathrooms new': [],
#  'light bright': [],
#  'great investment': [],
#  'totally renovated': [],
#  'oversized deck': [],
#  'private deck': [],
#  'area open': [],
#  'DIGITDIGITDIGITDIGIT sq': [],
#  'sep dining': [],
#  'mud room': [],
#  'quartz countertops': [],
#  'home home': [],
#  'great price': [],
#  'stubbed bath': [],
#  'subway tile': [],
#  'tub double': [],
#  'gorgeous DIGIT': [],
#  'closet large': [],
#  'tons natural': [],
#  'walking trails': [],
#  'custom home': [],
#  'beautifully updated': [],
#  'include new': [],
#  'basement large': [],
#  'home all': [],
#  'room private': [],
#  'DIGIT fireplaces': [],
#  'DIGIT bathrooms': [],
#  'main w': [],
#  'master br': [],
#  'home one': [],
#  'lot DIGIT': [],
#  'shopping schools': [],
#  'man cave': [],
#  'morning coffee': [],
#  'half acre': [],
#  'gas stove': [],
#  'upgraded kitchen': [],
#  'huge family': [],
#  'kitchen overlooks': [],
#  'perfect family': [],
#  'bedrooms spacious': [],
#  'tray ceiling': [],
#  'screened back': [],
#  'sprinkler system': [],
#  'newer hvac': [],
#  'basement ready': [],
#  'floors large': [],
#  'cape cod': [],
#  'room garage': [],
#  'lr dr': [],
#  'square footage': [],
#  'double oven': [],
#  'home DIGITDIGIT': [],
#  'new ss': [],
#  'great family': [],
#  'yard large': [],
#  'youll love': [],
#  'home desirable': [],
#  'home spacious': [],
#  'second level': [],
#  'jacuzzi tub': [],
#  'bright kitchen': [],
#  'family friends': [],
#  'renovated new': [],
#  'fireplace formal': [],
#  'call agent': [],
#  'baths new': [],
#  'located minutes': [],
#  'ranch DIGIT': [],
#  'hardwood floor': [],
#  'suite DIGIT': [],
#  'kitchen area': [],
#  'appliances kitchen': [],
#  'large DIGIT': [],
#  'storage area': [],
#  'culdesac home': [],
#  'backyard patio': [],
#  'yard great': [],
#  'master sitting': [],
#  'recently updated': [],
#  'amenities include': [],
#  'vinyl siding': [],
#  'renovated ranch': [],
#  'home buyer': [],
#  'downtown atlanta': [],
#  'surround sound': [],
#  'renovated master': [],
#  'area great': [],
#  'suite wsitting': [],
#  'countertops kitchen': [],
#  'lot private': [],
#  'powder room': [],
#  'charming DIGIT': [],
#  'lots space': [],
#  'rare find': [],
#  'cathedral ceiling': [],
#  'ground pool': [],
#  'wonderful home': [],
#  'immaculate home': [],
#  'deck patio': [],
#  'basement stubbed': [],
#  'plan offers': [],
#  'kitchen separate': [],
#  'living spaces': [],
#  'tub large': [],
#  'kitchen lots': [],
#  'shower DIGIT': [],
#  'neutral paint': [],
#  'tile baths': [],
#  'one owner': [],
#  'top rated': [],
#  'large breakfast': [],
#  'media rm': [],
#  'DIGIT bedDIGIT': [],
#  'granite tile': [],
#  'professional landscaping': [],
#  'upstairs find': [],
#  'wood cabinets': [],
#  'miss opportunity': [],
#  'level offers': [],
#  'wood flooring': [],
#  'level new': [],
#  'want miss': [],
#  'DIGITDIGITDIGIT financing': [],
#  'w large': [],
#  'DIGITDIGIT ba': [],
#  'swimtennis neighborhood': [],
#  'bedrooms share': [],
#  'guest room': [],
#  'counters tile': [],
#  'call home': [],
#  'home master': [],
#  'wrought iron': [],
#  'kitchen DIGIT': [],
#  'garage large': [],
#  'bedroom sitting': [],
#  'flat backyard': [],
#  'tile kitchen': [],
#  'private master': [],
#  'stunning home': [],
#  'kitchen updated': [],
#  'basement home': [],
#  'large eatin': [],
#  'new hardwoods': [],
#  'beautiful hardwoods': [],
#  'cabinetry granite': [],
#  'large rooms': [],
#  'basement finished': [],
#  'bedroomDIGIT bath': [],
#  'great value': [],
#  'plus DIGIT': [],
#  'basement full': [],
#  'space large': [],
#  'winning schools': [],
#  'kitchen great': [],
#  'home movein': [],
#  'suite full': [],
#  'full ba': [],
#  'garden area': [],
#  'golf cart': [],
#  'open spacious': [],
#  'DIGIT minutes': [],
#  'one kind': [],
#  'tiled backsplash': [],
#  'granite island': [],
#  'built ins': [],
#  'peachtree city': [],
#  'wtrey ceiling': [],
#  'yard perfect': [],
#  'upstairs large': [],
#  'vanities garden': [],
#  'property sold': [],
#  'lot great': [],
#  'granite tops': [],
#  'car side': [],
#  'top line': [],
#  'carpet upstairs': [],
#  'remodeled kitchen': [],
#  'kitchen custom': [],
#  'eating area': [],
#  'x DIGITDIGIT': [],
#  'play area': [],
#  'level w': [],
#  'owners retreat': [],
#  'location minutes': [],
#  'lots cabinets': [],
#  'area separate': [],
#  'baths large': [],
#  'closets master': [],
#  'entire home': [],
#  'fire place': [],
#  'opens large': [],
#  'area family': [],
#  'additional storage': [],
#  'bath two': [],
#  'johns creek': [],
#  'home last': [],
#  'new hot': [],
#  'room oversized': [],
#  'walkin shower': [],
#  'elementary school': [],
#  'fireplace spacious': [],
#  'gleaming hardwoods': [],
#  'open bright': [],
#  'office space': [],
#  'room two': [],
#  'fireplace gas': [],
#  'youll find': [],
#  'sized bedrooms': [],
#  'plan master': [],
#  'close everything': [],
#  'bath walkin': [],
#  'bedrooms master': [],
#  'builtin bookcases': [],
#  'plan w': [],
#  'kitchen living': [],
#  'kitchen white': [],
#  'salt water': [],
#  'gorgeous kitchen': [],
#  'outdoor entertaining': [],
#  ...}

# %%
noun_sentences_dict_listingid_list, noun_sentences_dict_error_list  = get_n_grams_cumulative_error(df_sales_train, column, 2,
                            noun_sentences_dict_listingid_list,
                            noun_sentences_dict_error_list)

bigram_df_error.head(10)
# Out:
# 0 600278
# 0.01860600000000545
# 20000 600278
# 101.940834
# 40000 600278
# 200.86110299999999
# 60000 600278
# 299.66176199999995
# 80000 600278
# 403.57562600000006
# 100000 600278
# 502.47248
# 120000 600278
# 602.405036
# 140000 600278
# 706.1305649999999
# 160000 600278
# 819.583339
# 180000 600278
# 932.6235760000001
# 200000 600278
# 1045.394948
# 220000 600278
# 1155.239767
# 240000 600278
# 1262.791968
# 260000 600278
# 1373.8798780000002
# 280000 600278
# 1483.744705
# 300000 600278
# 1593.241792
# 320000 600278
# 1703.3923550000002
# 340000 600278
# 1813.2300480000001
# 360000 600278
# 1922.460749
# 380000 600278
# 2030.647214
# 400000 600278
# 2140.237256
# 420000 600278
# 2247.248746
# 440000 600278
# 2352.779476
# 460000 600278
# 2458.274176
# 480000 600278
# 2564.291374
# 500000 600278
# 2669.7780310000003
# 520000 600278
# 2773.356362
# 540000 600278
# 2876.663634
# 560000 600278
# 2979.57507
# 580000 600278
# 3088.635256
# 600000 600278
# 3198.248309
#                   count  probability  error
# ngram
# family room      156048     0.004727    0.0
# dining room      115262     0.003492    0.0
# hardwood floors  113450     0.003437    0.0
# master suite      97489     0.002953    0.0
# floor plan        84674     0.002565    0.0
# living room       82696     0.002505    0.0
# main level        79375     0.002405    0.0
# full bath         74061     0.002244    0.0
# master bath       68088     0.002063    0.0
# back yard         63846     0.001934    0.0

# %%
dict_keys = list(noun_sentences_dict_error_list.keys())

# %%
dict_keys
# Out:
# ['family room',
#  'dining room',
#  'hardwood floors',
#  'master suite',
#  'floor plan',
#  'living room',
#  'main level',
#  'full bath',
#  'master bath',
#  'back yard',
#  'great room',
#  'stainless steel',
#  'DIGIT bedrooms',
#  'DIGIT bedroom',
#  'open floor',
#  'master bedroom',
#  'steel appliances',
#  'front porch',
#  'formal dining',
#  'finished basement',
#  'must see',
#  'fenced backyard',
#  'new carpet',
#  'car garage',
#  'DIGIT car',
#  'granite countertops',
#  'breakfast area',
#  'walkin closet',
#  'bonus room',
#  'master main',
#  'new roof',
#  'DIGIT story',
#  'garden tub',
#  'laundry room',
#  'large master',
#  'home features',
#  'counter tops',
#  'bedroom DIGIT',
#  'school district',
#  'bedrooms DIGIT',
#  'secondary bedrooms',
#  'private backyard',
#  'room fireplace',
#  'screened porch',
#  'terrace level',
#  'move ready',
#  'brand new',
#  'granite counters',
#  'DIGIT bath',
#  'separate dining',
#  'bath home',
#  'granite counter',
#  'formal living',
#  'stainless appliances',
#  'walk closet',
#  'well maintained',
#  'DIGIT full',
#  'separate shower',
#  'sitting area',
#  'new paint',
#  'kitchen granite',
#  'water heater',
#  'ranch home',
#  'fenced yard',
#  'ss appliances',
#  'gourmet kitchen',
#  'floors throughout',
#  'double vanity',
#  'main floor',
#  'fenced back',
#  'updated kitchen',
#  'corner lot',
#  'movein ready',
#  'open kitchen',
#  'breakfast bar',
#  'stone fireplace',
#  'DIGITDIGIT bath',
#  'kitchen w',
#  'dont miss',
#  'room kitchen',
#  'owners suite',
#  'brick ranch',
#  'brick home',
#  'vaulted ceilings',
#  'home located',
#  'freshly painted',
#  'two story',
#  'room large',
#  'full baths',
#  'eatin kitchen',
#  'bedroom full',
#  'natural light',
#  'tile backsplash',
#  'fresh paint',
#  'private fenced',
#  'tub separate',
#  'kitchen breakfast',
#  'last long',
#  'great location',
#  'rocking chair',
#  'easy access',
#  'back deck',
#  'trey ceiling',
#  'paint new',
#  'living dining',
#  'spacious master',
#  'perfect entertaining',
#  'beautiful home',
#  'family rm',
#  'chair front',
#  'sitting room',
#  'unfinished basement',
#  'culdesac lot',
#  'throughout main',
#  'large family',
#  'wont last',
#  'home DIGIT',
#  'room w',
#  'DIGITth bedroom',
#  'vaulted ceiling',
#  'kitchen features',
#  'full basement',
#  'story foyer',
#  'additional bedrooms',
#  'huge master',
#  'bath main',
#  'breakfast room',
#  'large kitchen',
#  'media room',
#  'room dining',
#  'open concept',
#  'lower level',
#  'much more',
#  'hardwood flooring',
#  'french doors',
#  'level lot',
#  'sided brick',
#  'keeping room',
#  'new hvac',
#  'full finished',
#  'finished terrace',
#  'dining area',
#  'chefs kitchen',
#  'acre lot',
#  'cabinets granite',
#  'walking distance',
#  'suite main',
#  'welcome home',
#  'new flooring',
#  'dining rm',
#  'home offers',
#  'hardwoods throughout',
#  'large deck',
#  'tile floors',
#  'living area',
#  'eat kitchen',
#  'home great',
#  'new kitchen',
#  'interior paint',
#  'spacious kitchen',
#  'living space',
#  'walkin closets',
#  'appliances granite',
#  'DIGIT additional',
#  'split bedroom',
#  'style home',
#  'kitchen new',
#  'DIGIT sided',
#  'large bedrooms',
#  'de sac',
#  'floors main',
#  'light fixtures',
#  'cul de',
#  'new stainless',
#  'room master',
#  'double vanities',
#  'roof new',
#  'beautiful DIGIT',
#  'DIGIT years',
#  'tub shower',
#  'bedroom DIGITDIGIT',
#  'private back',
#  'DIGITDIGIT acre',
#  'conveniently located',
#  'inlaw suite',
#  'spacious bedrooms',
#  'DIGIT baths',
#  'private wooded',
#  'swim tennis',
#  'oversized master',
#  'shopping restaurants',
#  'bedroom main',
#  'maintained home',
#  'deck overlooking',
#  'open floorplan',
#  'open family',
#  'bedrooms upstairs',
#  'features DIGIT',
#  'inside out',
#  'upper level',
#  'come see',
#  'swimtennis community',
#  'DIGITDIGIT baths',
#  'golf course',
#  'DIGIT acre',
#  'new granite',
#  'room DIGIT',
#  'master bathroom',
#  'fireside family',
#  'room open',
#  'back porch',
#  'kitchen open',
#  'DIGIT large',
#  'full bathroom',
#  'custom built',
#  'large walkin',
#  'DIGIT bed',
#  'kitchen island',
#  'room separate',
#  'side entry',
#  'great home',
#  'appliances new',
#  'rec room',
#  'room family',
#  'half bath',
#  'trey ceilings',
#  'shopping dining',
#  'carpet new',
#  'wooded lot',
#  'separate living',
#  'bedroom plan',
#  'daylight basement',
#  'large fenced',
#  'hardwoods main',
#  'new home',
#  'high school',
#  'soaking tub',
#  'kitchen stainless',
#  'new appliances',
#  'home large',
#  'room upstairs',
#  'great entertaining',
#  'award winning',
#  'priced sell',
#  'years old',
#  'throughout home',
#  'jetted tub',
#  'suite w',
#  'large level',
#  'flooring throughout',
#  'DIGIT br',
#  'features include',
#  'wet bar',
#  'plantation shutters',
#  'newer roof',
#  'close shopping',
#  'covered patio',
#  'room formal',
#  'stained cabinets',
#  'large open',
#  'quiet neighborhood',
#  'stacked stone',
#  'bath large',
#  'plenty room',
#  'large private',
#  'home new',
#  'private bath',
#  'bath DIGIT',
#  'hot water',
#  'bedrooms full',
#  'renovated kitchen',
#  'paint throughout',
#  'large secondary',
#  'new construction',
#  'granite kitchen',
#  'walkin pantry',
#  'DIGIT DIGITDIGIT',
#  'home sits',
#  'ready move',
#  'home sought',
#  'recently renovated',
#  'wood floors',
#  'guest suite',
#  'crown molding',
#  'quiet culdesac',
#  'exterior paint',
#  'screen porch',
#  'new windows',
#  'entry garage',
#  'high ceilings',
#  'brick front',
#  'deck overlooks',
#  'two car',
#  'bedrooms DIGITDIGIT',
#  'story home',
#  'storage space',
#  'white cabinets',
#  'private lot',
#  'like new',
#  'level features',
#  'level backyard',
#  'full unfinished',
#  'family home',
#  'tennis courts',
#  'overlooking private',
#  'walk closets',
#  'DIGIT acres',
#  'suite sitting',
#  'kitchen large',
#  'great schools',
#  'level fenced',
#  'new interior',
#  'room spacious',
#  'bath double',
#  'renovated home',
#  'great rm',
#  'DIGITcar garage',
#  'kitchen opens',
#  'sun room',
#  'covered porch',
#  'room full',
#  'floors new',
#  'fire pit',
#  'ready home',
#  'countertops stainless',
#  'spacious family',
#  'beautiful hardwood',
#  'completely renovated',
#  'home office',
#  'features large',
#  'wall windows',
#  'split level',
#  'gas fireplace',
#  'bedroom bath',
#  'location location',
#  'covered front',
#  'bath w',
#  'craftsman style',
#  'tile shower',
#  'large walk',
#  'story family',
#  'meticulously maintained',
#  'partially finished',
#  'large living',
#  'spa bath',
#  'DIGITDIGITDIGIT acres',
#  'kitchen wgranite',
#  'paint inside',
#  'room vaulted',
#  'area large',
#  'bath ranch',
#  'first time',
#  'newly renovated',
#  'living rm',
#  'DIGITDIGIT acres',
#  'back splash',
#  'room great',
#  'wood burning',
#  'curb appeal',
#  'double ovens',
#  'short sale',
#  'custom cabinets',
#  'dining rooms',
#  'brick fireplace',
#  'east cobb',
#  'traditional home',
#  'room office',
#  'lake lanier',
#  'fam rm',
#  'new hardwood',
#  'sides brick',
#  'rm w',
#  'guest bedroom',
#  'bright open',
#  'throughout new',
#  'level home',
#  'new tile',
#  'large island',
#  'tile flooring',
#  'spacious secondary',
#  'master retreat',
#  'low maintenance',
#  'DIGIT spacious',
#  'home beautiful',
#  'DIGIT sides',
#  'home warranty',
#  'washer dryer',
#  'ceiling fans',
#  'wooded backyard',
#  'outdoor living',
#  'interior exterior',
#  'tiled shower',
#  'closet space',
#  'coffered ceiling',
#  'w fireplace',
#  'kitchen cabinets',
#  'home open',
#  'closet master',
#  'upstairs DIGIT',
#  'dual vanities',
#  'move in',
#  'bed DIGIT',
#  'separate tub',
#  'room main',
#  'hot tub',
#  'professionally landscaped',
#  'fireplace large',
#  'w granite',
#  'room wfireplace',
#  'large lot',
#  'home perfect',
#  'spacious home',
#  'bath separate',
#  'room living',
#  'tons storage',
#  'jack jill',
#  'level DIGIT',
#  'counter space',
#  'highly sought',
#  'hall bath',
#  'DIGITsided brick',
#  'home quiet',
#  'sold asis',
#  'bay window',
#  'back market',
#  'kitchen appliances',
#  'garage door',
#  'open living',
#  'home full',
#  'back patio',
#  'room huge',
#  'view family',
#  'lots storage',
#  'cozy fireplace',
#  'large laundry',
#  'living areas',
#  'location close',
#  'large bonus',
#  'bedrooms large',
#  'great neighborhood',
#  'front yard',
#  'tile floor',
#  'solid surface',
#  'front back',
#  'schools shopping',
#  'plenty storage',
#  'flooring new',
#  'area master',
#  'storage building',
#  'fully fenced',
#  'kitchen dining',
#  'covered back',
#  'granite stainless',
#  'overlooks private',
#  'butlers pantry',
#  'huge walkin',
#  'main DIGIT',
#  'kitchen baths',
#  'shower garden',
#  'plenty space',
#  'coffered ceilings',
#  'perfect home',
#  'many upgrades',
#  'loft area',
#  'new water',
#  'vaulted family',
#  'shower double',
#  'room new',
#  'paint carpet',
#  'pool tennis',
#  'cabinet space',
#  'suite features',
#  'ranch style',
#  'spacious DIGIT',
#  'front door',
#  'home boasts',
#  'carpet paint',
#  'new deck',
#  'two additional',
#  'DIGIT year',
#  'hvac system',
#  'home w',
#  'main living',
#  'roof DIGIT',
#  'sep shower',
#  'year old',
#  'great opportunity',
#  'bedroom home',
#  'ranch full',
#  'home well',
#  'home ready',
#  'home must',
#  'en suite',
#  'porch overlooking',
#  'one level',
#  'DIGITstory foyer',
#  'new light',
#  'sold is',
#  'high end',
#  'new cabinets',
#  'quiet street',
#  'second floor',
#  'established neighborhood',
#  'call today',
#  'two bedrooms',
#  'convenient location',
#  'center island',
#  'spacious living',
#  'home move',
#  'room hardwood',
#  'storage shed',
#  'fenced private',
#  'backyard perfect',
#  'extra storage',
#  'extra large',
#  'bathroom home',
#  'sq ft',
#  'three bedrooms',
#  'vaulted great',
#  'bath upstairs',
#  'room features',
#  'kitchen master',
#  'room opens',
#  'area kitchen',
#  'ceramic tile',
#  'model home',
#  'fireplace kitchen',
#  'roof hvac',
#  'br DIGIT',
#  'less DIGIT',
#  'detached garage',
#  'gorgeous home',
#  'appliances including',
#  'whirlpool tub',
#  'counters stainless',
#  'inground pool',
#  'DIGITDIGITDIGITDIGIT new',
#  'home also',
#  'lots natural',
#  'miss one',
#  'room perfect',
#  'teen suite',
#  'vanity separate',
#  'room breakfast',
#  'beautifully landscaped',
#  'rear deck',
#  'plan DIGIT',
#  'closet DIGIT',
#  'minutes downtown',
#  'features new',
#  'island breakfast',
#  'swimming pool',
#  'room bedroom',
#  'burning fireplace',
#  'updated home',
#  'fully renovated',
#  'bath new',
#  'carpet throughout',
#  'fresh interior',
#  'open plan',
#  'located near',
#  'ready new',
#  'first floor',
#  'wrap around',
#  'bedrooms main',
#  'fireplace master',
#  'dining living',
#  'basement DIGIT',
#  'game room',
#  'room home',
#  'country club',
#  'island granite',
#  'opens family',
#  'upstairs master',
#  'DIGITnd floor',
#  'walk pantry',
#  'time home',
#  'level large',
#  'beautifully renovated',
#  'DIGIT bathroom',
#  'within walking',
#  'large back',
#  'full daylight',
#  'home situated',
#  'tub sep',
#  'custom cabinetry',
#  'recessed lighting',
#  'painted interior',
#  'large dining',
#  'spacious open',
#  'story great',
#  'kitchen family',
#  'room beautiful',
#  'large great',
#  'ceiling master',
#  'separate formal',
#  'bonus rm',
#  'see home',
#  'appliances breakfast',
#  'appliances large',
#  'gated community',
#  'located quiet',
#  'DIGITDIGIT minutes',
#  'fireplace separate',
#  'finished bonus',
#  'jill bath',
#  'laundry rm',
#  'room could',
#  'DIGIT bedroomDIGIT',
#  'features granite',
#  'countertops tile',
#  'gas logs',
#  'cabinets stainless',
#  'large backyard',
#  'hard find',
#  'beautifully maintained',
#  'privacy fence',
#  'bedrooms two',
#  'room basement',
#  'plan large',
#  'minutes away',
#  'level private',
#  'suite large',
#  'tennis community',
#  'storage room',
#  'w full',
#  'motivated seller',
#  'w DIGIT',
#  'starter home',
#  'backyard great',
#  'DIGIT miles',
#  'dream home',
#  'countertops new',
#  'lot home',
#  'renovated DIGIT',
#  'porch large',
#  'fireplace family',
#  'access iDIGITDIGIT',
#  'master closet',
#  'updated master',
#  'irrigation system',
#  'carpet bedrooms',
#  'split foyer',
#  'front home',
#  'upstairs features',
#  'entry foyer',
#  'huge kitchen',
#  'landscaped yard',
#  'tops stainless',
#  'features open',
#  'full bathrooms',
#  'island kitchen',
#  'make home',
#  'shower large',
#  'fixtures new',
#  'well kept',
#  'floors kitchen',
#  'home private',
#  'nice size',
#  'hvac new',
#  'kitchen boasts',
#  'covered deck',
#  'fireplace open',
#  'restaurants shopping',
#  'new garage',
#  'level yard',
#  'maintained DIGIT',
#  'out new',
#  'white kitchen',
#  'home culdesac',
#  'tile back',
#  'wfull bath',
#  'shops restaurants',
#  'minutes iDIGITDIGIT',
#  'energy efficient',
#  'huge bonus',
#  'lot fenced',
#  'side brick',
#  'new lighting',
#  'beautiful ranch',
#  'windows new',
#  'soaring ceilings',
#  'bath huge',
#  'vanity garden',
#  'DIGITDIGITDIGIT acre',
#  'area DIGIT',
#  'DIGIT secondary',
#  'better new',
#  'offers DIGIT',
#  'lovely home',
#  'home nestled',
#  'foyer formal',
#  'cabinets new',
#  'garage doors',
#  'gas cooktop',
#  'huge fenced',
#  'kitchen includes',
#  'suite trey',
#  'floors granite',
#  'features hardwood',
#  'gas range',
#  'vanities separate',
#  'backyard large',
#  'twocar garage',
#  'kitchen bathrooms',
#  'backsplash stainless',
#  'new fixtures',
#  'breakfast nook',
#  'beautiful brick',
#  'stepless ranch',
#  'bath features',
#  'basement w',
#  'plan features',
#  'keeping rm',
#  'huge deck',
#  'level living',
#  'executive home',
#  'DIGIT ba',
#  'room stone',
#  'could used',
#  'porch deck',
#  'room gas',
#  'gleaming hardwood',
#  'painted inside',
#  'room cozy',
#  'bath laundry',
#  'level master',
#  'fall love',
#  'large corner',
#  'new exterior',
#  'floor ceiling',
#  'deck perfect',
#  'culdesac street',
#  'full kitchen',
#  'built home',
#  'private yard',
#  'ga DIGITDIGITDIGIT',
#  'newly painted',
#  'built DIGITDIGITDIGITDIGIT',
#  'private level',
#  'hwy DIGITDIGITDIGIT',
#  'kitchen offers',
#  'dual vanity',
#  'charming home',
#  'porch overlooks',
#  'huge walk',
#  'wsitting area',
#  'stone patio',
#  'bedroom large',
#  'shows like',
#  'additional bedroom',
#  'move right',
#  'main large',
#  'rear yard',
#  'refinished hardwood',
#  'beautiful kitchen',
#  'DIGIT side',
#  'hwy DIGITDIGIT',
#  'sac lot',
#  'heater new',
#  'convenient shopping',
#  'exercise room',
#  'luxurious master',
#  'private culdesac',
#  'fully finished',
#  'one wont',
#  'also features',
#  'master w',
#  'w new',
#  'closing costs',
#  'bath garden',
#  'roof DIGITDIGITDIGITDIGIT',
#  'open great',
#  'w sitting',
#  'spa like',
#  'DIGIT yrs',
#  'new ac',
#  'laminate flooring',
#  'light filled',
#  'bathrooms new',
#  'light bright',
#  'great investment',
#  'totally renovated',
#  'oversized deck',
#  'private deck',
#  'area open',
#  'DIGITDIGITDIGITDIGIT sq',
#  'sep dining',
#  'mud room',
#  'quartz countertops',
#  'home home',
#  'great price',
#  'stubbed bath',
#  'subway tile',
#  'tub double',
#  'gorgeous DIGIT',
#  'closet large',
#  'tons natural',
#  'walking trails',
#  'custom home',
#  'beautifully updated',
#  'include new',
#  'basement large',
#  'home all',
#  'room private',
#  'DIGIT fireplaces',
#  'DIGIT bathrooms',
#  'main w',
#  'master br',
#  'home one',
#  'lot DIGIT',
#  'shopping schools',
#  'man cave',
#  'morning coffee',
#  'half acre',
#  'gas stove',
#  'upgraded kitchen',
#  'huge family',
#  'kitchen overlooks',
#  'perfect family',
#  'bedrooms spacious',
#  'tray ceiling',
#  'screened back',
#  'sprinkler system',
#  'newer hvac',
#  'basement ready',
#  'floors large',
#  'cape cod',
#  'room garage',
#  'lr dr',
#  'square footage',
#  'double oven',
#  'home DIGITDIGIT',
#  'new ss',
#  'great family',
#  'yard large',
#  'youll love',
#  'home desirable',
#  'home spacious',
#  'second level',
#  'jacuzzi tub',
#  'bright kitchen',
#  'family friends',
#  'renovated new',
#  'fireplace formal',
#  'call agent',
#  'baths new',
#  'located minutes',
#  'ranch DIGIT',
#  'hardwood floor',
#  'suite DIGIT',
#  'kitchen area',
#  'appliances kitchen',
#  'large DIGIT',
#  'storage area',
#  'culdesac home',
#  'backyard patio',
#  'yard great',
#  'master sitting',
#  'recently updated',
#  'amenities include',
#  'vinyl siding',
#  'renovated ranch',
#  'home buyer',
#  'downtown atlanta',
#  'surround sound',
#  'renovated master',
#  'area great',
#  'suite wsitting',
#  'countertops kitchen',
#  'lot private',
#  'powder room',
#  'charming DIGIT',
#  'lots space',
#  'rare find',
#  'cathedral ceiling',
#  'ground pool',
#  'wonderful home',
#  'immaculate home',
#  'deck patio',
#  'basement stubbed',
#  'plan offers',
#  'kitchen separate',
#  'living spaces',
#  'tub large',
#  'kitchen lots',
#  'shower DIGIT',
#  'neutral paint',
#  'tile baths',
#  'one owner',
#  'top rated',
#  'large breakfast',
#  'media rm',
#  'DIGIT bedDIGIT',
#  'granite tile',
#  'professional landscaping',
#  'upstairs find',
#  'wood cabinets',
#  'miss opportunity',
#  'level offers',
#  'wood flooring',
#  'level new',
#  'want miss',
#  'DIGITDIGITDIGIT financing',
#  'w large',
#  'DIGITDIGIT ba',
#  'swimtennis neighborhood',
#  'bedrooms share',
#  'guest room',
#  'counters tile',
#  'call home',
#  'home master',
#  'wrought iron',
#  'kitchen DIGIT',
#  'garage large',
#  'bedroom sitting',
#  'flat backyard',
#  'tile kitchen',
#  'private master',
#  'stunning home',
#  'kitchen updated',
#  'basement home',
#  'large eatin',
#  'new hardwoods',
#  'beautiful hardwoods',
#  'cabinetry granite',
#  'large rooms',
#  'basement finished',
#  'bedroomDIGIT bath',
#  'great value',
#  'plus DIGIT',
#  'basement full',
#  'space large',
#  'winning schools',
#  'kitchen great',
#  'home movein',
#  'suite full',
#  'full ba',
#  'garden area',
#  'golf cart',
#  'open spacious',
#  'DIGIT minutes',
#  'one kind',
#  'tiled backsplash',
#  'granite island',
#  'built ins',
#  'peachtree city',
#  'wtrey ceiling',
#  'yard perfect',
#  'upstairs large',
#  'vanities garden',
#  'property sold',
#  'lot great',
#  'granite tops',
#  'car side',
#  'top line',
#  'carpet upstairs',
#  'remodeled kitchen',
#  'kitchen custom',
#  'eating area',
#  'x DIGITDIGIT',
#  'play area',
#  'level w',
#  'owners retreat',
#  'location minutes',
#  'lots cabinets',
#  'area separate',
#  'baths large',
#  'closets master',
#  'entire home',
#  'fire place',
#  'opens large',
#  'area family',
#  'additional storage',
#  'bath two',
#  'johns creek',
#  'home last',
#  'new hot',
#  'room oversized',
#  'walkin shower',
#  'elementary school',
#  'fireplace spacious',
#  'gleaming hardwoods',
#  'open bright',
#  'office space',
#  'room two',
#  'fireplace gas',
#  'youll find',
#  'sized bedrooms',
#  'plan master',
#  'close everything',
#  'bath walkin',
#  'bedrooms master',
#  'builtin bookcases',
#  'plan w',
#  'kitchen living',
#  'kitchen white',
#  'salt water',
#  'gorgeous kitchen',
#  'outdoor entertaining',
#  ...]

# %%
error_res2 = list(noun_sentences_dict_error_list.values()) 
listingid_res2 = list(noun_sentences_dict_listingid_list.values())

# %%
ngram_df = pd.DataFrame([dict_keys, error_res2, listingid_res2])

# %%
ngram_df = ngram_df.T

# %%
ngram_df
# Out:
#                                         0  \
# 0                             family room
# 1                             dining room
# 2                         hardwood floors
# 3                            master suite
# 4                              floor plan
# ...                                   ...
# 3231964                    shore culdesac
# 3231965                 lotbright kitchen
# 3231966                     sepshower sep
# 3231967        officeprivate backyardconv
# 3231968  backyardconv DIGITDIGITDIGITmall
#
#                                                          1  \
# 0        [0.042625218841183865, -0.07993954198473285, 0...
# 1        [-0.13084281337047354, 0.15489622327131358, 0....
# 2        [0.15489622327131358, -0.03524390588235282, -0...
# 3        [-0.13084281337047354, 0.07612199999999991, 0....
# 4        [-0.13084281337047354, 0.07612199999999991, 0....
# ...                                                    ...
# 3231964                              [0.27443150872391375]
# 3231965                             [-0.07821240266963292]
# 3231966                             [-0.07821240266963292]
# 3231967                             [-0.07821240266963292]
# 3231968                             [-0.07821240266963292]
#
#                                                          2
# 0        [226142320, 226987100, 226870444, 226871633, 2...
# 1        [226661582, 226894550, 226870444, 226095241, 2...
# 2        [226894550, 226871633, 226754150, 226805386, 2...
# 3        [226661582, 226786904, 226894550, 226674193, 7...
# 4        [226661582, 226786904, 226811606, 226754150, 2...
# ...                                                    ...
# 3231964                                         [77863520]
# 3231965                                         [77861631]
# 3231966                                         [77861631]
# 3231967                                         [77861631]
# 3231968                                         [77861631]
#
# [3231969 rows x 3 columns]

# %%
ngram_df = ngram_df.rename(columns={0: 'ngram', 1: 'AVM_Error_List', 
                                                        2: 'Listingid_List'})

# %%
bigram_df_error_ri = bigram_df_error.reset_index()

# %%
bigram_df_error_ri
# Out:
#                                     ngram   count   probability  error
# 0                             family room  156048  4.727295e-03    0.0
# 1                             dining room  115262  3.491730e-03    0.0
# 2                         hardwood floors  113450  3.436838e-03    0.0
# 3                            master suite   97489  2.953317e-03    0.0
# 4                              floor plan   84674  2.565102e-03    0.0
# ...                                   ...     ...           ...    ...
# 3231964                    shore culdesac       1  3.029385e-08    0.0
# 3231965                 lotbright kitchen       1  3.029385e-08    0.0
# 3231966                     sepshower sep       1  3.029385e-08    0.0
# 3231967        officeprivate backyardconv       1  3.029385e-08    0.0
# 3231968  backyardconv DIGITDIGITDIGITmall       1  3.029385e-08    0.0
#
# [3231969 rows x 4 columns]

# %%
bigram_df_error_merged = pd.merge(bigram_df_error_ri, ngram_df, on="ngram")

# %%
bigram_df_error_merged = bigram_df_error_merged.drop(columns=['error'])

# %%
bigram_df_error_merged
# Out:
#                                     ngram   count   probability  \
# 0                             family room  156048  4.727295e-03
# 1                             dining room  115262  3.491730e-03
# 2                         hardwood floors  113450  3.436838e-03
# 3                            master suite   97489  2.953317e-03
# 4                              floor plan   84674  2.565102e-03
# ...                                   ...     ...           ...
# 3231964                    shore culdesac       1  3.029385e-08
# 3231965                 lotbright kitchen       1  3.029385e-08
# 3231966                     sepshower sep       1  3.029385e-08
# 3231967        officeprivate backyardconv       1  3.029385e-08
# 3231968  backyardconv DIGITDIGITDIGITmall       1  3.029385e-08
#
#                                             AVM_Error_List  \
# 0        [0.042625218841183865, -0.07993954198473285, 0...
# 1        [-0.13084281337047354, 0.15489622327131358, 0....
# 2        [0.15489622327131358, -0.03524390588235282, -0...
# 3        [-0.13084281337047354, 0.07612199999999991, 0....
# 4        [-0.13084281337047354, 0.07612199999999991, 0....
# ...                                                    ...
# 3231964                              [0.27443150872391375]
# 3231965                             [-0.07821240266963292]
# 3231966                             [-0.07821240266963292]
# 3231967                             [-0.07821240266963292]
# 3231968                             [-0.07821240266963292]
#
#                                             Listingid_List
# 0        [226142320, 226987100, 226870444, 226871633, 2...
# 1        [226661582, 226894550, 226870444, 226095241, 2...
# 2        [226894550, 226871633, 226754150, 226805386, 2...
# 3        [226661582, 226786904, 226894550, 226674193, 7...
# 4        [226661582, 226786904, 226811606, 226754150, 2...
# ...                                                    ...
# 3231964                                         [77863520]
# 3231965                                         [77861631]
# 3231966                                         [77861631]
# 3231967                                         [77861631]
# 3231968                                         [77861631]
#
# [3231969 rows x 5 columns]

# %%
from scipy.stats import moment
from scipy.stats import describe

def basic_stats_error(datalist):
    
    if len(datalist)>1:
        result_describe = list(describe(datalist)[2:])
        result_percentile = result_describe + list(np.percentile(datalist,[10,25,50,75,90]))
        array = np.array(datalist)
        result_percentile = result_percentile+[len(array),len(array[np.where(array>0)[0]])/len(array)*100,
                                               len(array[np.where(array<0)[0]])/len(array)*100]
    else:
        result_percentile = []

    return result_percentile

# %%
bigram_df_error_merged['AVM_Error_Indicators'] = bigram_df_error_merged['AVM_Error_List'].apply(lambda x: basic_stats_error(x))

# %%
bigram_df_error_merged
# Out:
#                                     ngram   count   probability  \
# 0                             family room  156048  4.727295e-03
# 1                             dining room  115262  3.491730e-03
# 2                         hardwood floors  113450  3.436838e-03
# 3                            master suite   97489  2.953317e-03
# 4                              floor plan   84674  2.565102e-03
# ...                                   ...     ...           ...
# 3231964                    shore culdesac       1  3.029385e-08
# 3231965                 lotbright kitchen       1  3.029385e-08
# 3231966                     sepshower sep       1  3.029385e-08
# 3231967        officeprivate backyardconv       1  3.029385e-08
# 3231968  backyardconv DIGITDIGITDIGITmall       1  3.029385e-08
#
#                                             AVM_Error_List  \
# 0        [0.042625218841183865, -0.07993954198473285, 0...
# 1        [-0.13084281337047354, 0.15489622327131358, 0....
# 2        [0.15489622327131358, -0.03524390588235282, -0...
# 3        [-0.13084281337047354, 0.07612199999999991, 0....
# 4        [-0.13084281337047354, 0.07612199999999991, 0....
# ...                                                    ...
# 3231964                              [0.27443150872391375]
# 3231965                             [-0.07821240266963292]
# 3231966                             [-0.07821240266963292]
# 3231967                             [-0.07821240266963292]
# 3231968                             [-0.07821240266963292]
#
#                                             Listingid_List  \
# 0        [226142320, 226987100, 226870444, 226871633, 2...
# 1        [226661582, 226894550, 226870444, 226095241, 2...
# 2        [226894550, 226871633, 226754150, 226805386, 2...
# 3        [226661582, 226786904, 226894550, 226674193, 7...
# 4        [226661582, 226786904, 226811606, 226754150, 2...
# ...                                                    ...
# 3231964                                         [77863520]
# 3231965                                         [77861631]
# 3231966                                         [77861631]
# 3231967                                         [77861631]
# 3231968                                         [77861631]
#
#                                       AVM_Error_Indicators
# 0        [-0.010902237089406125, 0.03138040079712531, -...
# 1        [-0.01080737427866235, 0.02727025580597697, -1...
# 2        [0.009148148479352474, 0.03425091598965587, -0...
# 3        [0.00307385788064346, 0.025518097986844904, -0...
# 4        [0.0003682471771432193, 0.027792711004521038, ...
# ...                                                    ...
# 3231964                                                 []
# 3231965                                                 []
# 3231966                                                 []
# 3231967                                                 []
# 3231968                                                 []
#
# [3231969 rows x 6 columns]

# %%
bigram_df_error_merged.to_feather('ngrams/' + file + '_withsentiment_erros_' + column + '_bigram.fea')

# %%
#bigram_df_error['error_list'] = [[] for i in range(len(bigram_df['probability']))]
#bigram_df_error['listingid_list'] = [[] for i in range(len(bigram_df['probability']))]

# %%
#bigram_df_error.head(10)

# %%
#bigram_df_error[bigram_df_error['ngram']=='illustrate potential.']

# %%
#len(bigram_df_error)

# %%
#bigram_df_error.index

# %%
#slow
#for idd,ngramtemp in enumerate(bigram_df_error.index):
#    print(idd, len(bigram_df_error))
#    bigram_df_error.loc[ngramtemp,'error_list'] = [[np.array(noun_sentences_dict_error_list[ngramtemp])]]
#    bigram_df_error.loc[ngramtemp,'listingid_list'] = [[np.array(noun_sentences_dict_listingid_list[ngramtemp])]]
 
#error_res2 = list(noun_sentences_dict_error_list.values()) 
#listingid_res2 = list(noun_sentences_dict_listingid_list.values())

# %%
#dict_keys = list(noun_sentences_dict_error_list.keys())

# %%
#bigram_df_error = bigram_df_error.reset_index()

# %%
#for idd,ngramtemp in enumerate(bigram_df_error.index):
#    if (idd%20000 == 0): print(idd, len(bigram_df_error))
#    #print('     ',len(error_res2[idd]),np.max(error_res2[idd]))
#    if (len((error_res2[idd]))>0):
#        bigram_df_error.iloc[idd]['error_list'] = [[error_res2[idd]]]
#        bigram_df_error.iloc[idd]['listingid_list'] = [[listingid_res2[idd]]]

# %%
#81132 
#'illustrate potential.'

# %%
#print(len(listingid_res2[idd]))

# %%
#dict_keys[idd]

# %%
#bigram_df_error.loc[0]

# %%
#bigram_df_error.iloc[0]['error_list']

# %%
#len((res[0][1]))

# %%
#len((res2[0]))

# %%
#len((res[0][1]))

# %%
np.array(noun_sentences_dict_error_list['family room']).shape

# %%
d={'a':[1,2,3],'b':['a','b','c']}
list(d.values())[0]

# %%
#list(d.items())[0][1]

# %%
#list(noun_sentences_dict_error_list.items())[0]

# %%
len([np.array(noun_sentences_dict_error_list[ngramtemp])])

# %%
#bigram_df_error.loc[ngramtemp,'error_list'] = [[np.array(noun_sentences_dict_error_list[ngramtemp])]]

# %%
bigram_df_error['average_error'] = bigram_df_error['error'] / bigram_df_error['count']

# %%
bigram_df_error = bigram_df_error.sort_values(by ='average_error', ascending=False)

# %%
bigram_df_error

# %%
bigram_df_error_filtered = bigram_df_error[bigram_df_error['count'] > 100]

# %%
bigram_df_error_filtered.head(30)

# %%
bigram_df_error_filtered.tail(30)

# %%
bigram_df_error_ri = bigram_df_error.reset_index()

# %%
bigram_df_error_ri

# %%
bigram_df_error_ri

# %%
bigram_df_error_ri

# %%
bigram_df_error_ri.to_feather('ngrams/' + file + '_withsentiment_erros_' + column + '_bigram.fea')

# %%
df_sales['avmerror']

# %%
house = 5

# %%
df_ngram = ngram_analysis.get_n_grams_count(df_sales[column].values[house],3)
df_ngram = df_ngram.rename({0: 'ngram', 1: 'count'}, axis='columns')
df_ngram['error'] = df_ngram['count']*df_sales['avmerror'].values[house]
df_ngram = df_ngram.set_index('ngram')
df_ngram

# %%
list(df_ngram.index)

# %%
list(trigram_df_error.loc[list(df_ngram.index)]['error'].values + df_ngram.loc[list(df_ngram.index)]['error'].values)

# %%
new_error_list = list(trigram_df_error.loc[list(df_ngram.index)]['error'].values + df_ngram.loc[list(df_ngram.index)]['error'].values)
trigram_df_error.loc[list(df_ngram.index), ['error']] = new_error_list

# %%
trigram_df_error.loc[list(df_ngram.index)] ['error']

# %%
trigram_df_error.loc[list(df_ngram.index), ['error']]

# %%
list(trigram_df_error.loc[list(df_ngram.index)]['error'].values + df_ngram.loc[list(df_ngram.index)]['error'].values)

# %%
trigram_df_error.loc[list(df_ngram.index)]['error']

# %%
len(trigram_df_error.loc[list(df_ngram.index)]['error'])

# %%
len(df_ngram.loc[list(df_ngram.index)]['error'])

# %%
df_ngram.loc[list(df_ngram.index)]['error']

# %%
trigram_df_error.sort_values(by ='error', ascending=False)
